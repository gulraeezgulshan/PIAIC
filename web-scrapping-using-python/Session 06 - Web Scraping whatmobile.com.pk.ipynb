# %%
#Author : Engr. Gulraeez Gulshan

from builtins import print
import requests
from bs4 import BeautifulSoup
from csv import writer

# variable initialization
url = 'https://www.whatmobile.com.pk/'
uri = ''
brand_uri = ''
brand_list = []
brand_uri_list = []
brands_specs_dict = {}
brands_mobile_list = []


def html_parse(url):
    ''' For parsing html page on given url '''
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    return soup

try:
    div = html_parse(url).find('div', {'class': 'verticalMenu'})
except requests.exceptions.RequestException as e:
    print(e)
else:
    section_search_by_branch = div.find_all('section')[1]
    brands = section_search_by_branch.find('ul').find_all('li')
    for i in brands:
        brand_list.append((i.find('a').string, i.find('a')['href']))
    dict = list(enumerate(brand_list))
    if dict:  # If dictionary is not empty
        print('Choose brand of mobile you want to WebScrap?\n')
        for i in dict:
            print(i[0], ':', i[1][0])
        brand_selection = input('Enter your choice: ')

        for i in range(0, (len(0) - 1)):
            if (brand_list[i][0] == brand_selection.rstrip()):
                uri = url + brand_list[i][1]
                break
        if uri:
            try:
                td = html_parse(uri).find_all('td', {'class': 'BiggerText'})
            except requests.exceptions.RequestException as e:
                print(e)
            else:
                for i in td:
                    brand_uri = url + i.find('a')['href']
                    brand_uri_list.append(brand_uri)
        else:
            print('oops ! something went wrong...')
    else:
        print('oops ! something went wrong...')

if brand_uri_list:
    for i in brand_uri_list:
        try:
            table = html_parse(i).find('table', {'class': 'specs'}) #table for specs
            div_price = html_parse(i).find('div', {'class': 'hdng3'})

            price_text = div_price.text.replace(' ','').replace(',','').strip()
            index_of_usd = price_text.index('U')
            str_to_lst = list(price_text)
            a = str_to_lst.insert(int(index_of_usd),',')
            lst_to_str = ''.join(str_to_lst).split(',')

            #Splitting dollars and rupees in seperate var
            price_rs = lst_to_str[0].replace('Rs.','')
            price_usd = lst_to_str[1].replace('USD$', '')

        except requests.exceptions.RequestException as e:
            print(e)
        else:
            tr = table.find_all('tr')
            for j in tr:
                th = j.select('th')
                td = j.select('th+td')
                for k, brand_specs_list in zip(th, td):
                    spec = k.text.strip()
                    value = brand_specs_list.text.strip()
                    brands_specs_dict[spec] = value
            mobile = i.split('//')
            brands_specs_dict['Brand'] = brand_selection
            brands_specs_dict['Mobile'] = mobile[2]
            brands_specs_dict['Price_RS'] = price_rs
            brands_specs_dict['Price_USD'] = price_usd

            brands_mobile_list.append(brands_specs_dict.copy())
else:
    print('oops ! something went wrong...')
# Set of all unique specifications of all mobiles of selected brand

brand_specs_list = []
all_brands_specs_list = []

if brands_mobile_list:
    specs_set = set()
    for p in brands_mobile_list:
        specs_set = set(p.keys())
        specs_set = specs_set.union(specs_set)
    for i in specs_set:
        for j in brands_mobile_list:
            if i in j.keys():
                brand_specs_list.append(j.get(i))
            else:
                brand_specs_list.append('Not Found')
        brand_specs_list.insert(0, i)
        all_brands_specs_list.append(brand_specs_list.copy())
        brand_specs_list.clear()
else:
    print('oops ! something went wrong...')

# Transponse of list for csv purposes
trans_list = []
if all_brands_specs_list:
    trans_list = list(map(list, zip(*all_brands_specs_list)))
else:
    print('oops ! something went wrong...')

# Saving list in cvs format
filename = brand_selection + '.csv'

if filename:
    try:
        with open(filename, 'w', newline='', encoding='utf-8') as f:
            data_handler = writer(f, delimiter=',')
            for i in trans_list:
                data_handler.writerow(i)
    except IOError as e:
        print(e)
    else:
        print('Congratulations !',brand_selection,'has been scrapped in', filename, 'sucessfully...')
else:
    print('oops ! something went wrong...')
# Out:
# Choose brand of mobile you want to WebScrap?
#
# 0 : Samsung Mobile
# 1 : Huawei Mobile
# 2 : Vivo
# 3 : Honor Mobile
# 4 : OPPO Mobile
# 5 : None
# 6 : Nokia
# 7 : Xiaomi Mobile
# 8 : Infinix Mobile
# 9 : Apple iphone
# 10 : Tecno Mobile
# 11 : QMobile
# 12 : Lenovo Mobile
# 13 : Sony
# 14 : LG Mobile
# 15 : Meizu
# 16 : OnePlus
# 17 : Telenor
# 18 : Alcatel
# 19 : HTC
# 20 : Microsoft Mobile
# 21 : Rivo
# 22 : Haier Mobile
# 23 : Mobilink JazzX
# 24 : Motorola
# 25 : BlackBerry
# 26 : VOICE
# 27 : iNew
# 28 : OPhone
# 29 : Calme
# 30 : GRight
# 31 : G'Five
# 32 : Club Mobile
# 33 : Sony Ericsson
# Enter your choice: Calme
# Congratulations ! Calme has been scrapped in Calme.csv sucessfully...

# %%
from builtins import print
import requests
from bs4 import BeautifulSoup
from csv import writer

# %%
# variable initialization
url = 'https://www.whatmobile.com.pk/'
uri = ''
brand_uri = ''
brand_list = []
brand_uri_list = []
brands_specs_dict = {}
brands_mobile_list = []

# %%
def html_parse(url):
    ''' For parsing html page on given url '''
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    return soup

# %%
soup = html_parse(url)
soup
# Out:
# <html lang="en-US" prefix="og: http://ogp.me/ns#">
# <head>
# <link href="/manifest.json" rel="manifest"/>
# <meta content="BBCXWny4cq7hMjuYiwgOApODrXMcsyjapahWC_RiEjI" name="google-site-verification"/>
# <title>Mobile phone prices - Pakistan's daily updated mobile phone prices Pakistan What Mobile</title>
# <meta content="1f4b6fa75ca4c410" name="y_key"/>
# <meta content="Mobile Prices in Pakistan 2018, Daily Updated Mobile Prices, What Mobile Pakistan, Prices Lg mobile, Nokia Mobile Prices Pakistan HTC Mobile Rates, Huawei Mobile Prices, Samsung Mobile prices, Sony Ericsson Mobile" name="Description"/>
# <meta content="Mobile Prices, Lg Mobile Prices , mobile phone Prices, What, mobile, what mobile, pakistan, mobile phone, Mobile Phone Pakistan, phone, nokia, samsung, sony ericsson, prices, motorola, HTC, zone,  Mobile Zone," name="Keywords"/>
# <meta content="PK" name="sitecode">
# <meta content="2019-11-23" name="last-modified">
# <meta content="WhatMobile" property="fb:admins">
# <meta content="Mobile phone prices - Pakistan's daily updated mobile phone prices Pakistan What Mobile" property="og:title"/>
# <meta content="Mobile Prices in Pakistan 2018, Daily Updated Mobile Prices, What Mobile Pakistan, Prices Lg mobile, Nokia Mobile Prices Pakistan HTC Mobile Rates, Huawei Mobile Prices, Samsung Mobile prices, Sony Ericsson Mobile" property="og:description"/>
# <meta content="1451235568231998" property="fb:app_id"/>
# <meta content="WhatMobile" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="https://www.whatmobile.com.pk" property="og:url"/>
# <script type="text/javascript"> <!--
# document.writeln('<div id="waitDiv" style="position:absolute;left:40%;top:40%;visibility:hidden">');
# document.writeln('<table cellpadding="6" cellspacing="0" border=1 bgcolor=#FFFFFF bordercolor=#88A5E8>');
# document.writeln('<tr><td align="center">');
# document.writeln('<font color="#1E4A84" face=Arial size=4>Loading</font><br><br>');
# document.writeln('<img src="./images/ajax-loader.gif" border="0" alt="">');
# document.writeln('<br><font color="#1E4A84" face=Arial size=2>Please wait..</font>');
# document.writeln('<\/td><\/tr><\/table><\/div>');
# var DHTML = (document.getElementById || document.all || document.layers);
# function ap_getObj(name) {
# if (document.getElementById) {
# return document.getElementById(name).style;
# } else if (document.all) {
# return document.all[name].style;
# } else if (document.layers) {
# return document.layers[name];
# }
# }
# function ap_showWaitMessage(div,flag) {
# if (!DHTML)
# return;
# var x = ap_getObj(div);
# x.visibility = (flag) ? 'visible':'hidden'
# if(! document.getElementById)
# if(document.layers)
# x.left=280/2;
# // return true;
# }
# ap_showWaitMessage('waitDiv', 1);
# //--> </script> <script src="https://apis.google.com/js/plusone.js" type="text/javascript"></script>
# <!-- I-5iZp2m3yuIVcxp4-1P8ldHNOs -->
# <script type="text/javascript">
#             var googletag = googletag || {};
#             googletag.cmd = googletag.cmd || [];
#             (function () {
#                 var gads = document.createElement('script');
#                 gads.async = true;
#                 gads.type = 'text/javascript';
#                 var useSSL = 'https:' == document.location.protocol;
#                 gads.src = (useSSL ? 'https:' : 'http:') +
#                         '//www.googletagservices.com/tag/js/gpt.js';
#                 var node = document.getElementsByTagName('script')[0];
#                 node.parentNode.insertBefore(gads, node);
#             })();
#         </script>
# <script type="text/javascript">
#             googletag.cmd.push(function () {
#                 googletag.defineSlot('/1013266/Overlay650x340', [650, 340], 'div-gpt-ad-1381754936955-0').addService(googletag.pubads());
#                 googletag.defineSlot('/1013266/WhatMobile_Homepage_TopLeft_160x600', [160, 600], 'div-gpt-ad-1377952911391-0').addService(googletag.pubads());
#                 googletag.defineSlot('/1013266/Homepage_160x600_bottom', [160, 600], 'div-gpt-ad-1387525175047-0').addService(googletag.pubads());
#                 googletag.defineSlot('/1013266/home1x1', [1, 1], 'div-gpt-ad-1502454464110-0').addService(googletag.pubads());
#                 googletag.defineSlot('/1013266/1000x150', [1000, 150], 'div-gpt-ad-1523019584917-0').addService(googletag.pubads());
#                 googletag.pubads().enableSingleRequest();
#                 googletag.enableServices();
#             });
#         </script>
# <meta content="170217899693436" property="fb:pages"/>
# <link href="style.css" rel="stylesheet" type="text/css">
# <!-- MA5 Slider -->
# <link href="m5slider/css/ma5slider.min.css" rel="stylesheet" type="text/css"/>
# <style type="text/css">
#
#             .style1 {
#                 color: #FF0000;
#                 font-family: Verdana, Arial, Helvetica, sans-serif;
#                 font-weight: bold;
#                 font-size: 12px;
#             }
#             body {
#                 margin-left: 1px;
#                 margin-top: 0px;
#                 margin-right: 0px;
#                 margin-bottom: 0px;
#             }
#             img {border: none;}
#             a.noborder { border:none;}
#
#             ul.product-list {
#                 display: flex;
#                 flex-wrap: wrap;
#                 list-style: none;
#                 padding: 0;
#             }
#             ul.product-list li {
#                 flex: 1 0 113.33px;
#                 max-width: 113.33px;
#                 display: inline-block;
#                 text-align: center;
#             }
#
#         </style>
# <meta content="827qfNjHBgR9XfZ9QPzILjhRp7FY4vFycOMJ8vwWcSE" name="google-site-verification"/>
# </link></meta></meta></meta></head>
# <!-- BuySellAds Ad Code -->
# <script type="text/javascript">
#         (function () {
#             var bsa = document.createElement('script');
#             bsa.type = 'text/javascript';
#             bsa.async = true;
#             bsa.src = 'https://s3.buysellads.com/ac/bsa.js';
#             (document.getElementsByTagName('head')[0] || document.getElementsByTagName('body')[0]).appendChild(bsa);
#         })();
#     </script>
# <body>
# <!-- End BuySellAds Ad Code -->
# <div style="width:1000px;margin: auto;">
# <div style="width: 100%">
# <link href="css/search.css" rel="stylesheet" type="text/css">
# <style>
# #container {
# margin-top: 10px !important;
# }
# </style>
# <div style="width:1000px;">
# <div itemscope="" itemtype="http://schema.org/Organization">
# <meta content="What Mobile" itemprop="name"/>
# <meta content="https://www.whatmobile.com.pk/" itemprop="url"/>
# <meta content="https://m.whatmobile.com.pk/" itemprop="sameAs"/>
# <meta content="https://www.facebook.com/whatmobile.com.pk/" itemprop="sameAs"/>
# </div>
# <div itemscope="" itemtype="http://schema.org/WebSite">
# <meta content="WhatMobile" itemprop="name"/>
# <meta content="https://www.whatmobile.com.pk/" itemprop="url"/>
# </div>
# <div style="width:998px">
# <div style="width:764px; float:left">
# <img alt="Mobile Prices" border="0" height="137" src="images/header-Left-new2.gif" usemap="#Map" width="764"/>
# <map id="Map" name="Map">
# <area coords="63,116,169,137" href="//www.whatmobile.com.pk" shape="rect"/>
# <area coords="187,115,291,135" href="//www.whatmobile.com.pk/reviews/" shape="rect"/>
# <area coords="306,116,411,148" href="news.php" shape="rect"/>
# <area coords="550,111,655,143" href="outlets.php" shape="rect"/>
# <area coords="427,112,536,135" href="feedback.php" shape="rect"/>
# <!--  <area shape="rect" coords="427,113,536,136" href="feedback.php" />
#                <area shape="rect" coords="550,115,659,135" href="outlets.php" /> -->
# </map>
# </div>
# <div class="main-search" style="width:234px; height:137px; float:left; position:relative;
#         background-image: url('images/header-RightSearch128888.gif'); background-size: 101% 100%;">
# <div style="width:100%;position:absolute; top:25%;">
# <div class="Heading1" id="search">
# <form action="/search.php" autocomplete="off" method="get">
# <input id="searchInput" name="q" placeholder="Search" style="width:90%; height:26px" type="text"/>
# <input style="position: absolute; left: -9999px; width: 1px; height: 1px;" tabindex="-1" type="submit">
# <div class="search-buttons">
# <a href="#" id="go">Go</a>
# <a href="advanceSearch.php">Advanced</a>
# </div>
# </input></form>
# <div class="search-result" style="width:110%">
# <div id="livesearch"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div style="display: inline-block; margin-top: 7px;">
# <!--  /1013266/1000x150 -->
# <div id="div-gpt-ad-1523019584917-0" style="height:150px;">
# <script>
# 				googletag.cmd.push(function() {
# 					googletag.display('div-gpt-ad-1523019584917-0');
# 				});
# 			</script>
# </div>
# </div>
# </div> </link></div>
# <div id="container" style="width:100%;margin-top: 20px">
# <div style="width:165px;float:left">
# <style type="text/css">
# <!--
# .style8 {	font-size: 12px;
# 	font-weight: bold;
# 	font-family: Verdana, Arial, Helvetica, sans-serif;
# 	color: #194073;
# }
# .style9 {
# 	font-size: 3px;
# 	color: #FFFFFF;
# }
# .style56 {
# 	font-family: Verdana, Arial, Helvetica, sans-serif;
# 	font-size: 12px;
# 	color: #FF0000;
# 	text-decoration: underline blink;
# }
# .style10 {font-family: Verdana, Arial, Helvetica, sans-serif}
# -->
# </style>
# <table border="0" cellpadding="0" cellspacing="0">
# <tr valign="top">
# <td align="right" valign="top" width="160">
# <!-- Homepage_160x600_Top -->
# <div id="div-gpt-ad-1377952911391-0" style="width:160px; height:600px;">
# <script type="text/javascript">
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1377952911391-0'); });
# </script>
# </div>
# <br/>
# <!-- Homepage_160x600_bottom -->
# <div id="div-gpt-ad-1387525175047-0" style="width:160px; height:600px;">
# <script type="text/javascript">
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1387525175047-0'); });
# </script>
# </div>
#
#
# </td>
# </tr>
# <tr align="center" valign="bottom">
# <td><script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- home-native -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-1252604155088200" data-ad-slot="6827881177" style="display:inline-block;width:160px;height:600px"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script><br/></td>
# </tr>
# <tr valign="top">
# <td align="right" valign="top"></td>
# </tr>
# </table>
#
#
#                 </div>
# <div style="float:left">
# <div class="ma5slider anim-horizontal horizontal-dots center-dots inside-dots loop-mode" style="width:660px; text-align: center;margin:auto;">
# <div class="slides">
# <!-- children = slides -->
# <h1 style="text-decoration:none; margin-bottom: 5px;margin-top: 0px;">
# <a href="https://secure.adnxs.com/clktrb?id=734736" rel="nofollow" target="_blank">
# <img alt="Daily Updated Mobile Prices in Pakistan - Mobile Phone Prices Pakistan - What Mobile" src="m/sliderImages/PX.gif"/></a></h1>
# <a href="https://secure.adnxs.com/clktrb?id=734736" rel="nofollow" target="_blank">
# <img alt="Daily Updated Mobile Prices in Pakistan - Mobile Phone Prices Pakistan - What Mobile" src="m/sliderImages/PX.gif"/></a>
# <a href="https://secure.adnxs.com/clktrb?id=734736" rel="nofollow" target="_blank">
# <img alt="Daily Updated Mobile Prices in Pakistan - Mobile Phone Prices Pakistan - What Mobile" src="m/sliderImages/PX.gif"/></a>
# </div>
# <div style="width:100%;text-align: right">
# <div style="width:178px; float:right; margin-right: 50px">
# <g:plusone></g:plusone>
# </div>
# </div>
# <!-- --> <img alt="Intro" border="0" height="1" src="http://ib.adnxs.com/imptr?id=49588&amp;t=2" width="1"/>
# </div>
# <div style="width:680px;display: inline-block">
# <section>
# <h1 class="style1">   Latest Mobile Phones &amp; Prices in Pakistan</h1>
# <ul class="product-list">
# <li class="product">
# <a href="/Oppo_Reno-2" title="Price USD 768">
# <img alt="Oppo Reno 2 Price" border="0" src="admin/images/Oppo/OppoReno2-s.jpg"/></a><br>
# <a class="BiggerText" href="/Oppo_Reno-2" style="text-decoration:none" title="Oppo Reno 2">
#                                                 Oppo<br>Reno 2<br/></br></a>
# <span class="PriceFont">Rs. 79,999</span>
# </br></li>
# <li class="product">
# <a href="/Vivo_V17-Pro" title="Price USD 643">
# <img alt="Vivo V17 Pro Price" border="0" src="admin/images/Vivo/VivoV17Pro-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Vivo_V17-Pro" style="text-decoration:none" title="Vivo V17 Pro">
#                                                 Vivo<br/>V17 Pro<br/></a>
# <span class="PriceFont">Rs. 66,999</span>
# </li>
# <li class="product">
# <a href="/Oppo_Reno-2F" title="Price USD 576">
# <img alt="Oppo Reno 2F Price" border="0" src="admin/images/Oppo/OppoReno2F-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Oppo_Reno-2F" style="text-decoration:none" title="Oppo Reno 2F">
#                                                 Oppo<br/>Reno 2F<br/></a>
# <span class="PriceFont">Rs. 59,999</span>
# </li>
# <li class="product">
# <a href="/Realme_XT" title="Price USD 528">
# <img alt="Realme XT Price" border="0" src="admin/images/Realme/RealmeXT-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Realme_XT" style="text-decoration:none" title="Realme XT">
#                                                 Realme<br/>XT<br/></a>
# <span class="PriceFont">Rs. 54,999</span>
# </li>
# <li class="product">
# <a href="/Samsung_Galaxy-A20s" title="Price USD 297">
# <img alt="Samsung Galaxy A20s Price" border="0" src="admin/images/Samsung/SamsungGalaxyA20s-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Samsung_Galaxy-A20s" style="text-decoration:none" title="Samsung Galaxy A20s">
#                                                 Samsung<br/>Galaxy A20s<br/></a>
# <span class="PriceFont">Rs. 30,999</span>
# </li>
# <li class="product">
# <a href="/Infinix_Hot-S5" title="Price USD 230">
# <img alt="Infinix Hot S5 Price" border="0" src="admin/images/Infinix/InfinixHotS5-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Infinix_Hot-S5" style="text-decoration:none" title="Infinix Hot S5">
#                                                 Infinix<br/>Hot S5<br/></a>
# <span class="PriceFont">Rs. 23,999</span>
# </li>
# </ul>
# </section>
# <hr/>
# <section>
# <h2 class="hdng" style="margin:0 0 0 16px; display:inline;"><a class="hdng" href="/50000_to_350001_Mobiles" style="text-decoration:none">Mobile phones Price in Pakistan &gt; 50,000 Rs.</a></h2>
# <a class="style1" href="50000_to_350001_Mobiles" style="float:right;margin-right: 16px">More&gt;&gt;</a>
# <ul class="product-list">
# <li class="product">
# <a href="/Xiaomi_Mi-9-Lite" title="Price USD 499">
# <img alt="Xiaomi Mi 9 Lite Price" border="0" src="admin/images/Xiaomi/XiaomiMi9Lite-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Xiaomi_Mi-9-Lite" style="text-decoration:none" title="Xiaomi Mi 9 Lite">
#                                                 Xiaomi<br/>Mi 9 Lite<br/></a>
# <span class="PriceFont">Rs. 51,999</span>
# </li>
# <li class="product">
# <a href="/Apple_iPhone-11" title="Price USD 1665">
# <img alt="Apple iPhone 11 Price" border="0" src="admin/images/Apple/AppleiPhone11-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Apple_iPhone-11" style="text-decoration:none" title="Apple iPhone 11">
#                                                 Apple<br/>iPhone 11<br/></a>
# <span class="PriceFont">Rs. 173,499</span>
# </li>
# <li class="product">
# <a href="/Apple_iPhone-11-Pro-Max" title="Price USD 2384">
# <img alt="Apple iPhone 11 Pro Max Price" border="0" src="admin/images/Apple/AppleiPhone11ProMax-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Apple_iPhone-11-Pro-Max" style="text-decoration:none" title="Apple iPhone 11 Pro Max">
#                                                 Apple<br/>iPhone 11 Pro Max<br/></a>
# <span class="PriceFont">Rs. 248,499</span>
# </li>
# <li class="product">
# <a href="/Apple_iPhone-11-Pro" title="Price USD 2207">
# <img alt="Apple iPhone 11 Pro Price" border="0" src="admin/images/Apple/AppleiPhone11Pro-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Apple_iPhone-11-Pro" style="text-decoration:none" title="Apple iPhone 11 Pro">
#                                                 Apple<br/>iPhone 11 Pro<br/></a>
# <span class="PriceFont">Rs. 229,999</span>
# </li>
# <li class="product">
# <a href="/Samsung_Galaxy-Note-10-Plus" title="Price USD 1880">
# <img alt="Samsung Galaxy Note 10 Plus Price" border="0" src="admin/images/Samsung/SamsungGalaxyNote10Plus-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Samsung_Galaxy-Note-10-Plus" style="text-decoration:none" title="Samsung Galaxy Note 10 Plus">
#                                                 Samsung<br/>Galaxy Note 10 Plus<br/></a>
# <span class="PriceFont">Rs. 195,999</span>
# </li>
# <li class="product">
# <a href="/Xiaomi_Mi-9T" title="Price USD 566">
# <img alt="Xiaomi Mi 9T Price" border="0" src="admin/images/Xiaomi/XiaomiMi9T-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Xiaomi_Mi-9T" style="text-decoration:none" title="Xiaomi Mi 9T">
#                                                 Xiaomi<br/>Mi 9T<br/></a>
# <span class="PriceFont">Rs. 58,999</span>
# </li>
# </ul>
# </section>
# <hr/>
# <section>
# <h2 class="hdng" style="margin:0 0 0 16px; display:inline;"><a class="hdng" href="/40000_to_50001_Mobiles" style="text-decoration:none">Mobile Prices Between 40,000 and 50,000 Rs.</a></h2>
# <a class="style1" href="/40000_to_50001_Mobiles" style="float:right;margin-right: 16px">More&gt;&gt;</a>
# <ul class="product-list">
# <li class="product">
# <a href="/Realme_5-Pro-8GB" title="Price USD 422">
# <img alt="Realme 5 Pro 8GB Price" border="0" src="admin/images/Realme/Realme5Pro8GB-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Realme_5-Pro-8GB" style="text-decoration:none" title="Realme 5 Pro 8GB">
#                                                 Realme<br/>5 Pro 8GB<br/></a>
# <span class="PriceFont">Rs. 43,999</span>
# </li>
# <li class="product">
# <a href="/Oppo_A9-2020" title="Price USD 441">
# <img alt="Oppo A9 2020 Price" border="0" src="admin/images/Oppo/OppoA92020-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Oppo_A9-2020" style="text-decoration:none" title="Oppo A9 2020">
#                                                 Oppo<br/>A9 2020<br/></a>
# <span class="PriceFont">Rs. 45,999</span>
# </li>
# <li class="product">
# <a href="/Nokia_7.2" title="Price USD 456">
# <img alt="Nokia 7.2 Price" border="0" src="admin/images/Nokia/Nokia7.2-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Nokia_7.2" style="text-decoration:none" title="Nokia 7.2">
#                                                 Nokia<br/>7.2<br/></a>
# <span class="PriceFont">Rs. 47,500</span>
# </li>
# <li class="product">
# <a href="/Vivo_S1" title="Price USD 480">
# <img alt="Vivo S1 Price" border="0" src="admin/images/Vivo/VivoS1-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Vivo_S1" style="text-decoration:none" title="Vivo S1">
#                                                 Vivo<br/>S1<br/></a>
# <span class="PriceFont">Rs. 49,999</span>
# </li>
# <li class="product">
# <a href="/Realme_2-Pro" title="Price USD 451">
# <img alt="Realme 2 Pro Price" border="0" src="admin/images/Realme/Realme2Pro-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Realme_2-Pro" style="text-decoration:none" title="Realme 2 Pro">
#                                                 Realme<br/>2 Pro<br/></a>
# <span class="PriceFont">Rs. 46,999</span>
# </li>
# <li class="product">
# <a href="/Samsung_Galaxy-A50" title="Price USD 470">
# <img alt="Samsung Galaxy A50 Price" border="0" src="admin/images/Samsung/SamsungGalaxyA50-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Samsung_Galaxy-A50" style="text-decoration:none" title="Samsung Galaxy A50">
#                                                 Samsung<br/>Galaxy A50<br/></a>
# <span class="PriceFont">Rs. 48,999</span>
# </li>
# </ul>
# </section>
# <hr/>
# <section>
# <h2 class="hdng" style="margin:0 0 0 16px; display:inline;"><a class="hdng" href="/30000_to_40001_Mobiles" style="text-decoration:none">Mobile Prices 30,000 - 40,000 Rs.</a></h2>
# <a class="style1" href="/30000_to_40001_Mobiles" style="float:right;margin-right: 16px">More&gt;&gt;</a>
# <ul class="product-list">
# <li class="product">
# <a href="/Vivo_S1-4GB" title="USD 345">
# <img alt="Vivo S1 4GB Price" border="0" src="admin/images/Vivo/VivoS14GB-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Vivo_S1-4GB" style="text-decoration:none" title="Vivo S1 4GB">
#                                                 Vivo<br/>S1 4GB<br/></a>
# <span class="PriceFont">Rs. 35,999</span>
# </li>
# <li class="product">
# <a href="/Oppo_A5-2020" title="USD 336">
# <img alt="Oppo A5 2020 Price" border="0" src="admin/images/Oppo/OppoA52020-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Oppo_A5-2020" style="text-decoration:none" title="Oppo A5 2020">
#                                                 Oppo<br/>A5 2020<br/></a>
# <span class="PriceFont">Rs. 34,999</span>
# </li>
# <li class="product">
# <a href="/Xiaomi_Redmi-Note-8-Pro" title="USD 384">
# <img alt="Xiaomi Redmi Note 8 Pro Price" border="0" src="admin/images/Xiaomi/XiaomiRedmiNote8Pro-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Xiaomi_Redmi-Note-8-Pro" style="text-decoration:none" title="Xiaomi Redmi Note 8 Pro">
#                                                 Xiaomi<br/>Redmi Note 8 Pro<br/></a>
# <span class="PriceFont">Rs. 39,999</span>
# </li>
# <li class="product">
# <a href="/Honor_10-Lite-128GB" title="USD 307">
# <img alt="Honor 10 Lite 128GB Price" border="0" src="admin/images/Honor/Honor10Lite128GB-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Honor_10-Lite-128GB" style="text-decoration:none" title="Honor 10 Lite 128GB">
#                                                 Honor<br/>10 Lite 128GB<br/></a>
# <span class="PriceFont">Rs. 31,999</span>
# </li>
# <li class="product">
# <a href="/Realme_5-Pro" title="USD 365">
# <img alt="Realme 5 Pro Price" border="0" src="admin/images/Realme/Realme5Pro-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Realme_5-Pro" style="text-decoration:none" title="Realme 5 Pro">
#                                                 Realme<br/>5 Pro<br/></a>
# <span class="PriceFont">Rs. 37,999</span>
# </li>
# <li class="product">
# <a href="/Samsung_Galaxy-A30s" title="USD 384">
# <img alt="Samsung Galaxy A30s Price" border="0" src="admin/images/Samsung/SamsungGalaxyA30s-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Samsung_Galaxy-A30s" style="text-decoration:none" title="Samsung Galaxy A30s">
#                                                 Samsung<br/>Galaxy A30s<br/></a>
# <span class="PriceFont">Rs. 39,999</span>
# </li>
# </ul>
# </section>
# <hr/>
# <section>
# <h2 class="hdng" style="margin:0 0 0 16px; display:inline;"><a class="hdng" href="/20000_to_30001_Mobiles" style="text-decoration:none">Mobile Prices 20,001 - 30,000 Rs.</a></h2>
# <a class="style1" href="/20000_to_30001_Mobiles" style="float:right;margin-right: 16px">More&gt;&gt;</a>
# <ul class="product-list">
# <li class="product">
# <a href="/Infinix_S5-6GB" title="Price USD 269">
# <img alt="Infinix S5 6GB Price" border="0" src="admin/images/Infinix/InfinixS56GB-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Infinix_S5-6GB" style="text-decoration:none" title="Infinix S5 6GB">
#                                                 Infinix<br/>S5 6GB<br/></a>
# <span class="PriceFont">Rs. 27,999</span><br/>
# </li>
# <li class="product">
# <a href="/Realme_C2-64GB" title="Price USD 211">
# <img alt="Realme C2 64GB Price" border="0" src="admin/images/Realme/RealmeC264GB-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Realme_C2-64GB" style="text-decoration:none" title="Realme C2 64GB">
#                                                 Realme<br/>C2 64GB<br/></a>
# <span class="PriceFont">Rs. 21,999</span><br/>
# </li>
# <li class="product">
# <a href="/Oppo_A5-2020-64GB" title="Price USD 269">
# <img alt="Oppo A5 2020 64GB Price" border="0" src="admin/images/Oppo/OppoA5202064GB-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Oppo_A5-2020-64GB" style="text-decoration:none" title="Oppo A5 2020 64GB">
#                                                 Oppo<br/>A5 2020 64GB<br/></a>
# <span class="PriceFont">Rs. 27,999</span><br/>
# </li>
# <li class="product">
# <a href="/Vivo_Y11" title="Price USD 230">
# <img alt="Vivo Y11 Price" border="0" src="admin/images/Vivo/VivoY112019-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Vivo_Y11" style="text-decoration:none" title="Vivo Y11">
#                                                 Vivo<br/>Y11<br/></a>
# <span class="PriceFont">Rs. 23,999</span><br/>
# </li>
# <li class="product">
# <a href="/Realme_5-128GB" title="Price USD 269">
# <img alt="Realme 5 128GB Price" border="0" src="admin/images/Realme/Realme5128GB-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Realme_5-128GB" style="text-decoration:none" title="Realme 5 128GB">
#                                                 Realme<br/>5 128GB<br/></a>
# <span class="PriceFont">Rs. 27,999</span><br/>
# </li>
# <li class="product">
# <a href="/Realme_5-3GB" title="Price USD 230">
# <img alt="Realme 5 3GB Price" border="0" src="admin/images/Realme/Realme53GB-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Realme_5-3GB" style="text-decoration:none" title="Realme 5 3GB">
#                                                 Realme<br/>5 3GB<br/></a>
# <span class="PriceFont">Rs. 23,999</span><br/>
# </li>
# </ul>
# </section>
# <hr/>
# <section>
# <h2 class="hdng" style="margin:0 0 0 16px; display:inline;"><a class="hdng" href="/10000_to_20001_Mobiles" style="text-decoration:none">Mobile Prices 10,001 - 20,000 Rs.</a></h2>
# <a class="style1" href="/10000_to_20001_Mobiles" style="float:right;margin-right: 16px">More&gt;&gt;</a>
# <ul class="product-list">
# <li class="product">
# <a href="/Infinix_Smart-4" title="Price USD 149">
# <img alt="Infinix Smart 4 Price" border="0" src="admin/images/Infinix/InfinixSmart4-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Infinix_Smart-4" style="text-decoration:none" title="Infinix Smart 4">
#                                                 Infinix<br/>Smart 4<br/></a>
# <span class="PriceFont">Rs. 15,499</span>
# </li>
# <li class="product">
# <a href="/Qmobile_QSmart-Hot-Pro-2" title="Price USD 110">
# <img alt="Qmobile QSmart Hot Pro 2 Price" border="0" src="admin/images/Qmobile/QmobileQSmartHotPro2-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Qmobile_QSmart-Hot-Pro-2" style="text-decoration:none" title="Qmobile QSmart Hot Pro 2">
#                                                 Qmobile<br/>QSmart Hot Pro 2<br/></a>
# <span class="PriceFont">Rs. 11,499</span>
# </li>
# <li class="product">
# <a href="/Infinix_Hot-8-Lite" title="Price USD 130">
# <img alt="Infinix Hot 8 Lite Price" border="0" src="admin/images/Infinix/InfinixHot8Lite-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Infinix_Hot-8-Lite" style="text-decoration:none" title="Infinix Hot 8 Lite">
#                                                 Infinix<br/>Hot 8 Lite<br/></a>
# <span class="PriceFont">Rs. 13,500</span>
# </li>
# <li class="product">
# <a href="/Infinix_Hot-8-4GB" title="Price USD 182">
# <img alt="Infinix Hot 8 4GB Price" border="0" src="admin/images/Infinix/InfinixHot84GB-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Infinix_Hot-8-4GB" style="text-decoration:none" title="Infinix Hot 8 4GB">
#                                                 Infinix<br/>Hot 8 4GB<br/></a>
# <span class="PriceFont">Rs. 18,999</span>
# </li>
# <li class="product">
# <a href="/Tecno_Spark-4" title="Price USD 153">
# <img alt="Tecno Spark 4 Price" border="0" src="admin/images/Tecno/TecnoSpark4-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Tecno_Spark-4" style="text-decoration:none" title="Tecno Spark 4">
#                                                 Tecno<br/>Spark 4<br/></a>
# <span class="PriceFont">Rs. 15,999</span>
# </li>
# <li class="product">
# <a href="/Realme_C2-3GB-32GB" title="Price USD 192">
# <img alt="Realme C2 3GB 32GB Price" border="0" src="admin/images/Realme/RealmeC23GB32GB-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Realme_C2-3GB-32GB" style="text-decoration:none" title="Realme C2 3GB 32GB">
#                                                 Realme<br/>C2 3GB 32GB<br/></a>
# <span class="PriceFont">Rs. 19,999</span>
# </li>
# </ul>
# </section>
# <hr/>
# <section>
# <h2 class="hdng" style="margin:0 0 0 16px; display:inline;"><a class="hdng" href="/1_to_10001_Mobiles" style="text-decoration:none">Mobile Prices under 10,000 in Pakistan</a></h2>
# <a class="style1" href="/1_to_10001_Mobiles" style="float:right;margin-right: 16px">More&gt;&gt;</a>
# <ul class="product-list">
# <li class="product">
# <a href="/Telenor_Infinity-i5" title="Price USD 86">
# <img alt="Telenor Infinity i5 Price" border="0" src="admin/images/Telenor/TelenorInfinityi5-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Telenor_Infinity-i5" style="text-decoration:none" title="Telenor Infinity i5">
#                                                 Telenor<br/>Infinity i5<br/></a>
# <span class="PriceFont">Rs. 9,000</span><br/>
# </li>
# <li class="product">
# <a href="/Tecno_Pop-2F" title="Price USD 77">
# <img alt="Tecno Pop 2F Price" border="0" src="admin/images/Tecno/TecnoPop2F-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Tecno_Pop-2F" style="text-decoration:none" title="Tecno Pop 2F">
#                                                 Tecno<br/>Pop 2F<br/></a>
# <span class="PriceFont">Rs. 7,999</span><br/>
# </li>
# <li class="product">
# <a href="/Nokia_110" title="Price USD 35">
# <img alt="Nokia 110 Price" border="0" src="admin/images/Nokia/Nokia110-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Nokia_110" style="text-decoration:none" title="Nokia 110">
#                                                 Nokia<br/>110<br/></a>
# <span class="PriceFont">Rs. 3,700</span><br/>
# </li>
# <li class="product">
# <a href="/Nokia_105-2019" title="Price USD 27">
# <img alt="Nokia 105 2019 Price" border="0" src="admin/images/Nokia/Nokia1052019-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Nokia_105-2019" style="text-decoration:none" title="Nokia 105 2019">
#                                                 Nokia<br/>105 2019<br/></a>
# <span class="PriceFont">Rs. 2,850</span><br/>
# </li>
# <li class="product">
# <a href="/Qmobile_QSmart-LT200" title="Price USD 77">
# <img alt="Qmobile QSmart LT200 Price" border="0" src="admin/images/Qmobile/QmobileQSmartLT200-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Qmobile_QSmart-LT200" style="text-decoration:none" title="Qmobile QSmart LT200">
#                                                 Qmobile<br/>QSmart LT200<br/></a>
# <span class="PriceFont">Rs. 7,999</span><br/>
# </li>
# <li class="product">
# <a href="/Tecno_Pop-2" title="Price USD 77">
# <img alt="Tecno Pop 2 Price" border="0" src="admin/images/Tecno/TecnoPop2-s.jpg"/></a><br/>
# <a class="BiggerText" href="/Tecno_Pop-2" style="text-decoration:none" title="Tecno Pop 2">
#                                                 Tecno<br/>Pop 2<br/></a>
# <span class="PriceFont">Rs. 7,999</span><br/>
# </li>
# </ul>
# </section>
# <hr/>
# </div>
# <div class="normText" style="width:680px; text-align: center;">
# <!-- Latest News -->
# <style>
# .news-item {
#     width: 208px;
#     float: left;
#     border: 1px solid #abc4e8;
#     padding: 5px;
#     margin: 5px;
#     margin-left:0;
#     overflow: hidden;
#     text-align: left;
# }
# .news-item img {
#     width: 100%;
# }
# .news-item .news-label {
#     height: 40px;
#     margin-top: 5px;
#     display: block;
#     text-decoration: none;
#     font-family: Arial, Helvetica, sans-serif;
#     font-size: 12px;
#     font-weight: normal;
# }
# .news-item h4 {
#     font-family: Arial, Helvetica, sans-serif;
#     font-size: 12px;
#     font-weight: normal;
#     margin: 0;
# }
# .line-clamp {
#   display: -webkit-box;
#   -webkit-line-clamp: 3;
#   -webkit-box-orient: vertical;
# }
# </style>
# <div style="text-align: left;margin-left: 16px;"><a class="hdng" href="news.php" style="text-decoration: none">Latest News</a></div><div style="width:100%;display:inline-block;"> <article class="news-item line-clamp">
# <a class="biggerText" href="https://www.whatmobile.com.pk/samsung-galaxy-s11-spotted-in-new-renders-release-date-display-and-camera-leaked-news-584" style="text-decoration: none" title="Samsung Galaxy S11 spotted in new renders: launch date, display, and camera details are out">
# <div class="cmp-vs-img">
# <img src="https://www.whatmobile.com.pk/control/news/assets/23112019/00bb1b29eeadcf4e0d1b07e7d5b8ff8c_thumb.jpg"/>
# </div>
# </a>
# <a class="news-label biggerText" href="https://www.whatmobile.com.pk/samsung-galaxy-s11-spotted-in-new-renders-release-date-display-and-camera-leaked-news-584" title="Samsung Galaxy S11 spotted in new renders: launch date, display, and camera details are out">
#                 Samsung Galaxy S11 spotted in new renders: launch date, display, and camera details are out            </a>
# </article>
# <article class="news-item line-clamp">
# <a class="biggerText" href="https://www.whatmobile.com.pk/huawei-y9s-2019-launches-in-pakistan-on-november-27-the-invites-are-in-news-583" style="text-decoration: none" title="Huawei Y9s 2019 launches in Pakistan on November 27, invites are in">
# <div class="cmp-vs-img">
# <img src="https://www.whatmobile.com.pk/control/news/assets/23112019/9879ff2507f5899203be53c990df9cda_thumb.jpg"/>
# </div>
# </a>
# <a class="news-label biggerText" href="https://www.whatmobile.com.pk/huawei-y9s-2019-launches-in-pakistan-on-november-27-the-invites-are-in-news-583" title="Huawei Y9s 2019 launches in Pakistan on November 27, invites are in">
#                 Huawei Y9s 2019 launches in Pakistan on November 27, invites are in            </a>
# </article>
# <article class="news-item line-clamp">
# <a class="biggerText" href="https://www.whatmobile.com.pk/samsung-galaxy-a71s-early-renders-leaked-korean-listing-also-confirms-the-battery-capacity-news-582" style="text-decoration: none" title="Samsung Galaxy A71's Early Renders leaked; Korean Listing also Confirms the Battery Capacity ">
# <div class="cmp-vs-img">
# <img src="https://www.whatmobile.com.pk/control/news/assets/22112019/3e7d846340d0c6b2912778b129517381_thumb.jpg"/>
# </div>
# </a>
# <a class="news-label biggerText" href="https://www.whatmobile.com.pk/samsung-galaxy-a71s-early-renders-leaked-korean-listing-also-confirms-the-battery-capacity-news-582" title="Samsung Galaxy A71's Early Renders leaked; Korean Listing also Confirms the Battery Capacity ">
#                 Samsung Galaxy A71's Early Renders leaked; Korean Listing also Confirms the Battery Capacity             </a>
# </article>
# <article class="news-item line-clamp">
# <a class="biggerText" href="https://www.whatmobile.com.pk/realme-x2-pro-and-realme-5s-arrive-in-india-signaling-an-imminent-launch-in-pakistan-news-581" style="text-decoration: none" title="Realme X2 Pro and Realme 5s arrive in India, signaling an imminent Launch in Pakistan">
# <div class="cmp-vs-img">
# <img src="https://www.whatmobile.com.pk/control/news/assets/21112019/9ad7408240e56f9d64acf625f0a37749_thumb.jpg"/>
# </div>
# </a>
# <a class="news-label biggerText" href="https://www.whatmobile.com.pk/realme-x2-pro-and-realme-5s-arrive-in-india-signaling-an-imminent-launch-in-pakistan-news-581" title="Realme X2 Pro and Realme 5s arrive in India, signaling an imminent Launch in Pakistan">
#                 Realme X2 Pro and Realme 5s arrive in India, signaling an imminent Launch in Pakistan            </a>
# </article>
# <article class="news-item line-clamp">
# <a class="biggerText" href="https://www.whatmobile.com.pk/vivo-s1-pro-with-diamond-quad-cameras-launched-in-philippines-coming-to-pakistan-in-december-news-578" style="text-decoration: none" title="Vivo S1 Pro with Diamond Quad Cameras Launched in the Philippines, Coming to Pakistan in December ">
# <div class="cmp-vs-img">
# <img src="https://www.whatmobile.com.pk/control/news/assets/21112019/5ada9e315c434650a981e12f52ac388b_thumb.jpg"/>
# </div>
# </a>
# <a class="news-label biggerText" href="https://www.whatmobile.com.pk/vivo-s1-pro-with-diamond-quad-cameras-launched-in-philippines-coming-to-pakistan-in-december-news-578" title="Vivo S1 Pro with Diamond Quad Cameras Launched in the Philippines, Coming to Pakistan in December ">
#                 Vivo S1 Pro with Diamond Quad Cameras Launched in the Philippines, Coming to Pakistan in December             </a>
# </article>
# <article class="news-item line-clamp">
# <a class="biggerText" href="https://www.whatmobile.com.pk/huawei-receives-its-third-temporary-reprieve-for-another-3-months-the-ban-continues-news-577" style="text-decoration: none" title="Huawei Receives its Third temporary Reprieve for another 3 Months">
# <div class="cmp-vs-img">
# <img src="https://www.whatmobile.com.pk/control/news/assets/20112019/41a2c61f2495fdd8547ce24caae79ca7_thumb.jpg"/>
# </div>
# </a>
# <a class="news-label biggerText" href="https://www.whatmobile.com.pk/huawei-receives-its-third-temporary-reprieve-for-another-3-months-the-ban-continues-news-577" title="Huawei Receives its Third temporary Reprieve for another 3 Months">
#                 Huawei Receives its Third temporary Reprieve for another 3 Months            </a>
# </article>
# </div><script type="text/javascript">
# document.addEventListener("DOMContentLoaded", function(event) {
#     var newsHeadings = $(".news-item h1");
#     if(newsHeadings) {
#         $(newsHeadings).each(function(index) {
#             $clamp(newsHeadings[index], {clamp: 3});
#         });
#     }
# });
# </script>
# <!-- end Latest News    --> </div>
# <br/>
# <div class="normText" style="width:680px; text-align: center;">
# <h2 class="biggerText" style="padding:0px; margin:0px; display:inline; font-weight:normal;">
#                             Mobile Phones Price in Pakistan</h2>
# <br/><br/>
# <table align="center" width="500">
# <thead>
# <tr>
# <th align="left" class="hdng" style="border-bottom:1px solid #e0e0e0">
#                                         Latest Mobile Phones Models
#                                     </th>
# <th align="left" class="hdng" style="border-bottom:1px solid #e0e0e0">Price</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="biggerText" style="border-bottom:1px solid #e0e0e0">
# <a class="BiggerText" href="Infinix_S5-6GB" rel="nofolow" style="text-decoration: none">Infinix S5 6GB</a>
# </td>
# <td class="PriceFont" style="border-bottom:1px solid #e0e0e0">Rs.
#                                         27999                                    </td>
# </tr>
# <tr>
# <td class="biggerText" style="border-bottom:1px solid #e0e0e0">
# <a class="BiggerText" href="Realme_C2-64GB" rel="nofolow" style="text-decoration: none">Realme C2 64GB</a>
# </td>
# <td class="PriceFont" style="border-bottom:1px solid #e0e0e0">Rs.
#                                         21999                                    </td>
# </tr>
# <tr>
# <td class="biggerText" style="border-bottom:1px solid #e0e0e0">
# <a class="BiggerText" href="Infinix_Smart-4" rel="nofolow" style="text-decoration: none">Infinix Smart 4</a>
# </td>
# <td class="PriceFont" style="border-bottom:1px solid #e0e0e0">Rs.
#                                         15499                                    </td>
# </tr>
# <tr>
# <td class="biggerText" style="border-bottom:1px solid #e0e0e0">
# <a class="BiggerText" href="Oppo_A5-2020-64GB" rel="nofolow" style="text-decoration: none">Oppo A5 2020 64GB</a>
# </td>
# <td class="PriceFont" style="border-bottom:1px solid #e0e0e0">Rs.
#                                         27999                                    </td>
# </tr>
# <tr>
# <td class="biggerText" style="border-bottom:1px solid #e0e0e0">
# <a class="BiggerText" href="Samsung_Galaxy-A30s-128GB" rel="nofolow" style="text-decoration: none">Samsung Galaxy A30s 128GB</a>
# </td>
# <td class="PriceFont" style="border-bottom:1px solid #e0e0e0">Rs.
#                                         42999                                    </td>
# </tr>
# <tr>
# <td class="biggerText" style="border-bottom:1px solid #e0e0e0">
# <a class="BiggerText" href="Vivo_Y11" rel="nofolow" style="text-decoration: none">Vivo Y11</a>
# </td>
# <td class="PriceFont" style="border-bottom:1px solid #e0e0e0">Rs.
#                                         23999                                    </td>
# </tr>
# <tr>
# <td class="biggerText" style="border-bottom:1px solid #e0e0e0">
# <a class="BiggerText" href="Qmobile_QSmart-Hot-Pro-2" rel="nofolow" style="text-decoration: none">Qmobile QSmart Hot Pro 2</a>
# </td>
# <td class="PriceFont" style="border-bottom:1px solid #e0e0e0">Rs.
#                                         11499                                    </td>
# </tr>
# <tr>
# <td class="biggerText" style="border-bottom:1px solid #e0e0e0">
# <a class="BiggerText" href="Xiaomi_Redmi-Note-8-Pro-128GB" rel="nofolow" style="text-decoration: none">Xiaomi Redmi Note 8 Pro 128GB</a>
# </td>
# <td class="PriceFont" style="border-bottom:1px solid #e0e0e0">Rs.
#                                         42999                                    </td>
# </tr>
# <tr>
# <td class="biggerText" style="border-bottom:1px solid #e0e0e0">
# <a class="BiggerText" href="Realme_5-128GB" rel="nofolow" style="text-decoration: none">Realme 5 128GB</a>
# </td>
# <td class="PriceFont" style="border-bottom:1px solid #e0e0e0">Rs.
#                                         27999                                    </td>
# </tr>
# <tr>
# <td class="biggerText" style="border-bottom:1px solid #e0e0e0">
# <a class="BiggerText" href="Realme_5-3GB" rel="nofolow" style="text-decoration: none">Realme 5 3GB</a>
# </td>
# <td class="PriceFont" style="border-bottom:1px solid #e0e0e0">Rs.
#                                         23999                                    </td>
# </tr>
# </tbody>
# </table>
# <br>
# <!-- Coming soon section -->
# <br/>
# <section style="width:100%; display: inline-block; text-align: left;">
# <h2 class="hdng" style="margin:0 0 0 16px; display:inline;"><a class="hdng" href="#" style="text-decoration:none">Coming Soon Mobiles Prices in Pakistan</a></h2>
# <!-- <a href="Comingsoon_Tecno_Mobiles_Prices" class="style1" style="float:right;margin-right: 16px">More&gt;&gt;</a> -->
# <ul class="product-list">
# <li class="product">
# <a href="/Vivo_Y19" title="Price USD 6716">
# <img alt="Vivo Y19 Price" border="0" src="admin/images/Vivo/VivoY19-s.jpg"/></a><br>
# <a class="BiggerText" href="/Vivo_Y19" style="text-decoration:none" title="Vivo Y19">
#                                                 Vivo<br>Y19<br/></br></a>
# <span class="PriceFont">
#                                                 Expected Price <br/>Rs. 32,999                                            </span>
# </br></li>
# <li class="product">
# <a href="/Huawei_Y9s-2019" title="Price USD 6716">
# <img alt="Huawei Y9s 2019 Price" border="0" src="admin/images/Huawei/HuaweiY9s2019-s.jpg"/></a><br>
# <a class="BiggerText" href="/Huawei_Y9s-2019" style="text-decoration:none" title="Huawei Y9s 2019">
#                                                 Huawei<br/>Y9s 2019<br/></a>
# <span class="PriceFont">
#                                                 Expected Price <br/>Rs. 42,999                                            </span>
# </br></li>
# <li class="product">
# <a href="/Samsung_Galaxy-A50s" title="Price USD 6716">
# <img alt="Samsung Galaxy A50s Price" border="0" src="admin/images/Samsung/SamsungGalaxyA50s-s.jpg"/></a><br>
# <a class="BiggerText" href="/Samsung_Galaxy-A50s" style="text-decoration:none" title="Samsung Galaxy A50s">
#                                                 Samsung<br/>Galaxy A50s<br/></a>
# <span class="PriceFont">
#                                                 Expected Price <br/>Rs. 56,999                                            </span>
# </br></li>
# <li class="product">
# <a href="/Honor_9X-Pro" title="Price USD 6716">
# <img alt="Honor 9X Pro Price" border="0" src="admin/images/Honor/Honor9XPro-s.jpg"/></a><br>
# <a class="BiggerText" href="/Honor_9X-Pro" style="text-decoration:none" title="Honor 9X Pro">
#                                                 Honor<br/>9X Pro<br/></a>
# <span class="PriceFont">
#                                                 Expected Price <br/>Rs. 55,999                                            </span>
# </br></li>
# <li class="product">
# <a href="/Samsung_Galaxy-A70S" title="Price USD 6716">
# <img alt="Samsung Galaxy A70S Price" border="0" src="admin/images/Samsung/SamsungGalaxyA70S-s.jpg"/></a><br>
# <a class="BiggerText" href="/Samsung_Galaxy-A70S" style="text-decoration:none" title="Samsung Galaxy A70S">
#                                                 Samsung<br/>Galaxy A70S<br/></a>
# <span class="PriceFont">
#                                                 Expected Price <br/>Rs. 69,999                                            </span>
# </br></li>
# <li class="product">
# <a href="/Vivo_S1-Pro" title="Price USD 6716">
# <img alt="Vivo S1 Pro Price" border="0" src="admin/images/Vivo/VivoS1Pro-s.jpg"/></a><br>
# <a class="BiggerText" href="/Vivo_S1-Pro" style="text-decoration:none" title="Vivo S1 Pro">
#                                                 Vivo<br/>S1 Pro<br/></a>
# <span class="PriceFont">
#                                                 Expected Price <br/>Rs. 54,999                                            </span>
# </br></li>
# </ul>
# </section>
# <hr/>
# <!-- End coming soon section -->
# <p align="center"><strong>Disclaimer.</strong> Mobile Phone Prices / price list is updated daily
#                             from local Mobile shops &amp; Mobile dealers in Pakistan but we can't guarantee that mobile
#                             prices / price list on this page is 100% correct (Human error is possible). Always visit
#                             your local shop for exact mobile prices. What Mobile Pakistan - <a class="normText" href="/Nokia_Mobiles_Prices" style="text-decoration:none">Nokia mobile
#                                 prices</a> / <a class="normText" href="/LG_Mobiles_Prices" style="text-decoration:none">LG mobile prices</a> / <a class="normText" href="/Samsung_Mobiles_Prices" style="text-decoration:none">Samsung mobile prices</a> / <a class="normText" href="/SonyEricsson_Mobiles_Prices" style="text-decoration:none">Sony
#                                 Ericsson mobile prices</a> / <a class="normText" href="/HTC_Mobiles_Prices" style="text-decoration:none">HTC mobile prices</a> - What Mobile Prices in Pakistan<br/>
# <!-- Place this tag where you want the widget to render. -->
# <div class="g-page" data-href="//plus.google.com/u/0/110427407992456144330" data-layout="landscape" data-rel="publisher" data-showtagline="false" data-width="273"></div>
# <!-- Place this tag after the last widget tag. -->
# <script type="text/javascript">
#                                 (function () {
#                                     var po = document.createElement('script');
#                                     po.type = 'text/javascript';
#                                     po.async = true;
#                                     po.src = 'https://apis.google.com/js/platform.js';
#                                     var s = document.getElementsByTagName('script')[0];
#                                     s.parentNode.insertBefore(po, s);
#                                 })();
#                             </script>
# </p>
# <p><br>
# </br></p>
# </br></div>
# </div>
# <div style="width: 155px; float:right">
# <style type="text/css">
#
#     <!--
#
#     .border {
#
#         border: 1px solid #D9DBDF;
#
#     }
#
#     .style5 {
#
#         font-family: Verdana, Arial, Helvetica, sans-serif;
#
#         font-size: 14px;
#
#     }
#
#     .upper {
#         background-image: url("images/upper.gif");
#     }
#
#     .verticalMenu {
#         background-image: url("images/shape16424016.gif");
#     }
#
#     .verticalMenu ul {
#         list-style-type: none;
#         margin: 0;
#         padding-top:1px;
#         padding-bottom: 1px;
#         padding-left: 10px;
#         padding-right: 9px;
#     }
#
#     .verticalMenu ul li {
#         text-align: left;
#         margin-left: 1px;
#         margin-top:1px;
#         margin-bottom: 2px;
#     }
#
#     .verticalMenu ul li.center {
#         text-align: center;
#     }
#
#     .heading {
#         display: block;
#         height:23px;
#         line-height: 23px;
#         margin: 0px;
#         text-align: center;
#         background-image: url("images/roundrect14918782.gif");
#         background-repeat: no-repeat;
#         background-position: center;
#     }
#
#     .verticalMenu ul li span {
#         vertical-align: middle;
#     }
#
#     -->
#
# </style>
# <div style="width:152px">
# <div>
# <img class="noBorder" height="16" src="images/upper.gif" width="152"/>
# </div>
# <div class="verticalMenu">
# <ul>
# <li class="center">
# <a class="lnk" href="StolenMobile.php" title="Block stolen mobile phones"><u>Block Stolen Mobile </u></a>
# </li>
# <li class="center">
# <a class="lnk" href="//www.whatmobile.com.pk/advanceSearch.php" title="Advance Search"><u>Advance Search</u></a>
# </li>
# <li class="center">
# <a class="lnk" href="VideoReviews.php" title="Mobile phone Video Reviews"><u>Video Reviews</u></a>
# </li>
# </ul>
# <section>
# <h3 class="heading Menue">Search by Network</h3>
# <ul>
# <li>
# <a class="lnk" href="Price-List-Of-All-3G_Mobile-Phones" title="3G mobile phones with prices">3G Mobile Prices</a>
# </li>
# <li>
# <a class="lnk" href="Price-List-Of-All-4G_Mobile-Phones" title="4G mobile phones with prices">4G Mobiles </a><img align="absbottom" height="17" src="images/new5.GIF" width="35"/>
# </li>
# </ul>
# </section>
# <section>
# <h3 class="heading Menue">Search by Brand</h3>
# <ul>
# <li>
# <a class="lnk" href="Samsung_Mobiles_Prices" title="Samsung mobile phones">Samsung Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Huawei_Mobiles_Prices" title="Huawei mobile phones">Huawei Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Vivo_Mobiles_Prices" title="Vivo mobile phones">Vivo</a>
# </li>
# <li>
# <a class="lnk" href="Honor_Mobiles_Prices" title="Honor mobile phones">Honor Mobile</a>
# </li>
# <li><a class="lnk" href="Oppo_Mobiles_Prices" title="OPPO mobile phones">OPPO Mobile</a></li>
# <li><a class="lnk" href="Realme_Mobiles_Prices" title="Realme mobile phones">Realme Mobile<img align="absbottom" height="17" src="images/new5.GIF" width="35"/></a></li>
# <li>
# <a class="lnk" href="Nokia_Mobiles_Prices" title="Nokia mobile phones">Nokia</a>
# </li>
# <li>
# <a class="lnk" href="Xiaomi_Mobiles_Prices" title="Xiaomi mobile phones">Xiaomi Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Infinix_Mobiles_Prices" title="Infinix mobile phones">Infinix Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Apple_Mobiles_Prices" title="Apple iphones">Apple iphone</a>
# </li>
# <li>
# <a class="lnk" href="Tecno_Mobiles_Prices" title="Tecno mobile phones">Tecno Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Qmobile_Mobiles_Prices" title="QMobile mobile phones">QMobile</a>
# </li>
# <li>
# <a class="lnk" href="Lenovo_Mobiles_Prices" title="Lenovo mobile phones">Lenovo Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Sony_Mobiles_Prices" title="Sony mobile phones">Sony</a>
# </li>
# <li>
# <a class="lnk" href="LG_Mobiles_Prices" title="LG mobile phones">LG Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Meizu_Mobiles_Prices" title="Meizu mobile phones">Meizu</a><img align="absbottom" height="17" src="images/new5.GIF" width="35"/>
# </li>
# <li>
# <a class="lnk" href="OnePlus_Mobiles_Prices" title="OnePlus mobile phones">OnePlus</a>
# </li>
# <li>
# <a class="lnk" href="Telenor_Mobiles_Prices" title="Telenor mobile phones">Telenor</a><img align="absbottom" height="17" src="images/new5.GIF" width="35"/>
# </li>
# <li>
# <a class="lnk" href="Alcatel_Mobiles_Prices" title="Alcatel mobile phones">Alcatel</a>
# </li>
# <li>
# <a class="lnk" href="HTC_Mobiles_Prices" title="HTC mobile phones">HTC</a>
# </li>
# <li>
# <a class="lnk" href="Microsoft_Mobiles_Prices" title="Microsoft mobile phones">Microsoft Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Rivo_Mobiles_Prices" title="Rivo mobile phones">Rivo</a>
# </li>
# <li>
# <a class="lnk" href="Haier_Mobiles_Prices" title="Haier mobile phones">Haier Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Mobilink_Mobiles_Prices" title="Mobilink Jazz X mobile phones">Mobilink JazzX</a>
# </li>
# <li>
# <a class="lnk" href="Motorola_Mobiles_Prices" title="Motorola mobile phones">Motorola</a>
# </li>
# <li>
# <a class="lnk" href="BlackBerry_Mobiles_Prices" title="Blackberry mobile phones">BlackBerry</a>
# </li>
# <li>
# <a class="lnk" href="Voice_Mobiles_Prices" title="Voice mobile phones">VOICE</a>
# </li>
# <li>
# <a class="lnk" href="iNew_Mobiles_Prices" title="iNew mobile phones">iNew</a>
# </li>
# <li>
# <a class="lnk" href="OPhone_Mobiles_Prices" title="Ophone mobile phones">OPhone</a>
# </li>
# <li>
# <a class="lnk" href="Calme_Mobiles_Prices" title="Calme mobile phones">Calme</a>
# </li>
# <li>
# <a class="lnk" href="GRight_Mobiles_Prices" title="Gright mobile phones">GRight</a>
# </li>
# <li>
# <a class="lnk" href="GFive_Mobiles_Prices" title="GFive mobile phones">G'Five</a>
# </li>
# <li>
# <a class="lnk" href="Club_Mobiles_Prices" title="Club mobile phones">Club Mobile</a>
# </li>
# <li>
# <a class="lnk" href="SonyEricsson_Mobiles_Prices" title="Sony Ericsson mobile phones">Sony Ericsson</a>
# </li>
# </ul>
# </section>
# <section>
# <h3 class="heading Menue">Search by Price</h3>
# <ul>
# <li>
# <a class="lnk" href="45000_to_250001_Mobiles" title="Mobile phones with prices greater than 45000">Prices  &gt; 45,000</a>
# </li>
# <li>
# <a class="lnk" href="35000_to_45001_Mobiles" title="Mobile phones in a price range of 35000 to 40000">35,001 - 45,000</a>
# </li>
# <li>
# <a class="lnk" href="25000_to_35001_Mobiles" title="Mobile phones in a price range of 25000 to 35000">25,001 - 35,000</a>
# </li>
# <li>
# <a class="lnk" href="15000_to_25001_Mobiles" title="Mobile phones in a price range of 15000 to 25000">15,001 - 25,000</a>
# </li>
# <li>
# <a class="lnk" href="10000_to_15001_Mobiles" title="Mobile phones in a price range of 10000 to 15000">10,001 - 15,000</a>
# </li>
# <li>
# <a class="lnk" href="5000_to_10001_Mobiles" title="Mobile phones in a price range of 5000 to 10000">5,001 - 10,000</a>
# </li>
# <li>
# <a class="lnk" href="0_to_5001_Mobiles" title="Mobile phones below 5000 Rupees">Prices &lt; 5000</a>
# </li>
# <li>
# <a class="lnk" href="0_to_150001_Mobiles" title="All mobile phones">All Mobile Prices</a>
# </li>
# </ul>
# </section>
# <section>
# <h3 class="heading Menue">Search by RAM<img align="absbottom" height="17" src="images/new5.GIF" width="30"/></h3>
# <ul>
# <li>
# <a class="lnk" href="256MB-RAM_Mobile-Phones" title="Mobile phones with 256MB RAM">256MB RAM</a>
# </li>
# <li>
# <a class="lnk" href="512MB-RAM_Mobile-Phones" title="Mobile phones with 512MB RAM">512MB RAM</a>
# </li>
# <li>
# <a class="lnk" href="1GB-RAM_Mobile-Phones" title="Mobile phones with 1GB RAM">1GB RAM</a>
# </li>
# <li>
# <a class="lnk" href="2GB-RAM_Mobile-Phones" title="Mobile phones with 2GB RAM">2GB RAM</a>
# </li>
# <li>
# <a class="lnk" href="3GB-RAM_Mobile-Phones" title="Mobile phones with 3GB RAM">3GB &amp; above RAM</a>
# </li>
# </ul>
# </section>
# <section>
# <h3 class="heading Menue">Search by Screen</h3>
# <ul>
# <li>
# <a class="lnk" href="1.0-To-2.9-inches-Display-Size_Mobile-Phones" title="Mobile phones with less than 3 inch display">Less Then 3 Inches</a>
# </li>
# <li>
# <a class="lnk" href="3.0-To-4.0-inches-Display-Size_Mobile-Phones" title="Mobile phones with 3 to 4 inch display">3.0 inch - 4.0 inch</a>
# </li>
# <li>
# <a class="lnk" href="4.1-To-4.9-inches-Display-Size_Mobile-Phones" title="Mobile phones with 4.1 to 4.9 inch display">4.1 inch - 4.9 inch</a>
# </li>
# <li>
# <a class="lnk" href="5.0-To-6.9-inches-Display-Size_Mobile-Phones" title="Mobile phones with 5 to 6.9 inch display">5.0 inch - 6.9 inch</a>
# </li>
# <li>
# <a class="lnk" href="7.0-To-8.9-inches-Display-Size_Mobile-Phones" title="Devices with 7 to 8.9 inch display">7.0 inch - 8.9 inch</a>
# </li>
# </ul>
# </section>
# <section>
# <h3 class="heading Menue">Search by Cam</h3>
# <ul>
# <li>
# <a class="lnk" href="13mp-Camera_Mobile-Phones" title="Mobile phones with 13MP Camera">13 MP Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="8mp-Camera_Mobile-Phones" title="Mobile phones with 8MP Camera">8 MP Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="5mp-Camera_Mobile-Phones" title="Mobile phones with 5MP Camera">5 MP Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="3mp-Camera_Mobile-Phones" title="Mobile phones with 3MP Camera">3 MP Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="2mp-Camera_Mobile-Phones" title="Mobile phones with 2MP Camera">2 MP Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="1mp-Camera_Mobile-Phones" title="Mobile phones with 1MP Camera">1 MP Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="VGA-Camera_Mobile-Phones" title="Mobile phones with VGA Camera">VGA Cam or less</a>
# </li>
# <li>
# <a class="lnk" href="Without-Camera_Mobile-Phones" title="Mobile phones without Camera">Without Camera</a>
# </li>
# </ul>
# </section>
# <section>
# <h3 class="heading Menue">Search by Type</h3>
# <ul>
# <li>
# <a class="lnk" href="Camera_Mobile-Phones" title="Mobile phones having a Camera">Camera Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="Video_Mobile-Phones" title="Mobile phones with video recording feature">Video Recording</a>
# </li>
# <li>
# <a class="lnk" href="Bluetooth_Mobile-Phones" title="Mobile phones with bluetooth">Bluetooth Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="DualSim_Mobile-Phones" title="Dual-Sim mobile phones">Dual Sim Phones</a>
# </li>
# <li>
# <a class="lnk" href="LAN_Mobile-Phones" title="Mobile phones with Wifi">Wireless LAN </a>
# </li>
# <li>
# <a class="lnk" href="MP3_Mobile-Phones" title="Mobile phones with MP3 playback">MP3 Playback </a>
# </li>
# <li>
# <a class="lnk" href="FM_Mobile-Phones" title="Mobile phones with FM Radio">FM Radio Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="MemoryCard_Mobile-Phones" title="Mobile phones having a card slot">Memory Card </a>
# </li>
# </ul>
# </section>
# <section>
# <h3 class="heading Menue">Search by OS<img align="absbottom" height="17" src="images/new5.GIF" width="30"/></h3>
# <ul>
# <li>
# <a class="lnk" href="Android_Mobile-Phones" title="All Android mobile phones">Android Phones </a>
# </li>
# <li>
# <a class="lnk" href="Symbian_Mobile-Phones" title="All Symbian mobile phones">Symbian Phones </a>
# </li>
# <li>
# <a class="lnk" href="Windows_Mobile-Phones" title="All Windows mobile phones">Windows Phones </a>
# </li>
# <li>
# <a class="lnk" href="Smartphone_Mobile-Phones" title="All Smartphones">All Smartphones </a>
# </li>
# </ul>
# </section>
# </div>
# <div>
# <img class="noBorder" height="19" src="images/bottom.gif" width="152"/>
# </div>
# </div>
# </div>
# </div>
# <br/>
# <div id="copyright" style="width: 100%;display:inline-block;text-align: center;">
# <div align="center" class="normText"><span id="Footer1_S21">  Copyright © 2019       www.whatmobile.com.pk. What Mobile Pakistan All Rights Reserved.</span><br/>
# <span id="Footer1_S21"><a href="Privacy.php" style="text-decoration:none">Privacy</a> | <a href="Advertise.php" style="text-decoration:none">Advertise</a> | <a href="feedback.php" style="text-decoration:none">Contact us</a>
#  | <a href="https://m.whatmobile.com.pk" rel="alternate" style="text-decoration:none"> Mobile Version</a></span>
# <div style="width:122px;">
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-3910358-1', 'auto');
#   ga('send', 'pageview');
#
# </script>
# </div>
# <script type="text/javascript"> <!--
#         ap_showWaitMessage('waitDiv', 0);
#     //--> </script>
# <script src="js/jquery.min.js" type="text/javascript"></script>
# <script src="js/search.top.js" type="text/javascript"></script>
# <script src="js/ajax.js" type="text/javascript"></script>
# <!-- Import and configure the Firebase SDK -->
# <script src="https://www.gstatic.com/firebasejs/5.6.0/firebase-app.js"></script>
# <script src="https://www.gstatic.com/firebasejs/5.6.0/firebase-messaging.js"></script>
# <script src="/js/fcm/init.js"></script>
# <script src="/js/fcm/wm-service.js"></script>
# <script src="/js/fcm/whatmobile-messaging.js"></script>
# </div> </div>
# </div>
# <!-- /1013266/home1x1 -->
# <div id="div-gpt-ad-1502454464110-0" style="height:1px; width:1px;">
# <script>
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1502454464110-0'); });
# </script>
# </div>
# </body></html>
# <!-- jQuery UI mouse draggable widget -->
# <script src="m5slider/js/jquery-ui.min.js"></script>
# <!-- Touch Event Support for jQuery UI -->
# <script src="m5slider/js/jquery.ui.touch-punch.min.js"></script>
# <!-- MA5 Slider -->
# <script src="m5slider/js/ma5slider.min.js"></script>
# <script>
#             $(window).on('load', function () {
#                 $('.ma5slider').ma5slider();
#
#                 setInterval(nextSlide, 3000);
#             });
#
#             function nextSlide(){
#                 $('.ma5slider').ma5slider('goToNext');
#             }
#         </script>
# <!-- Import and configure the Firebase SDK -->
# <!-- These scripts are made available when the app is served or deployed on Firebase Hosting -->
# <!-- If you do not serve/host your project using Firebase Hosting see https://firebase.google.com/docs/web/setup -->
# <!-- <script src="https://www.gstatic.com/firebasejs/5.6.0/firebase-app.js"></script>
#         <script src="https://www.gstatic.com/firebasejs/5.6.0/firebase-messaging.js"></script>
#         <script src="init.js?v=11"></script>
#         <script src="fcm/service.js"></script>
#         <script src="fcm/whatmobile-messaging.js"></script> -->

# %%
div = html_parse(url).find('div', {'class': 'verticalMenu'})

# %%
div
# Out:
# <div class="verticalMenu">
# <ul>
# <li class="center">
# <a class="lnk" href="StolenMobile.php" title="Block stolen mobile phones"><u>Block Stolen Mobile </u></a>
# </li>
# <li class="center">
# <a class="lnk" href="//www.whatmobile.com.pk/advanceSearch.php" title="Advance Search"><u>Advance Search</u></a>
# </li>
# <li class="center">
# <a class="lnk" href="VideoReviews.php" title="Mobile phone Video Reviews"><u>Video Reviews</u></a>
# </li>
# </ul>
# <section>
# <h3 class="heading Menue">Search by Network</h3>
# <ul>
# <li>
# <a class="lnk" href="Price-List-Of-All-3G_Mobile-Phones" title="3G mobile phones with prices">3G Mobile Prices</a>
# </li>
# <li>
# <a class="lnk" href="Price-List-Of-All-4G_Mobile-Phones" title="4G mobile phones with prices">4G Mobiles </a><img align="absbottom" height="17" src="images/new5.GIF" width="35"/>
# </li>
# </ul>
# </section>
# <section>
# <h3 class="heading Menue">Search by Brand</h3>
# <ul>
# <li>
# <a class="lnk" href="Samsung_Mobiles_Prices" title="Samsung mobile phones">Samsung Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Huawei_Mobiles_Prices" title="Huawei mobile phones">Huawei Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Vivo_Mobiles_Prices" title="Vivo mobile phones">Vivo</a>
# </li>
# <li>
# <a class="lnk" href="Honor_Mobiles_Prices" title="Honor mobile phones">Honor Mobile</a>
# </li>
# <li><a class="lnk" href="Oppo_Mobiles_Prices" title="OPPO mobile phones">OPPO Mobile</a></li>
# <li><a class="lnk" href="Realme_Mobiles_Prices" title="Realme mobile phones">Realme Mobile<img align="absbottom" height="17" src="images/new5.GIF" width="35"/></a></li>
# <li>
# <a class="lnk" href="Nokia_Mobiles_Prices" title="Nokia mobile phones">Nokia</a>
# </li>
# <li>
# <a class="lnk" href="Xiaomi_Mobiles_Prices" title="Xiaomi mobile phones">Xiaomi Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Infinix_Mobiles_Prices" title="Infinix mobile phones">Infinix Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Apple_Mobiles_Prices" title="Apple iphones">Apple iphone</a>
# </li>
# <li>
# <a class="lnk" href="Tecno_Mobiles_Prices" title="Tecno mobile phones">Tecno Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Qmobile_Mobiles_Prices" title="QMobile mobile phones">QMobile</a>
# </li>
# <li>
# <a class="lnk" href="Lenovo_Mobiles_Prices" title="Lenovo mobile phones">Lenovo Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Sony_Mobiles_Prices" title="Sony mobile phones">Sony</a>
# </li>
# <li>
# <a class="lnk" href="LG_Mobiles_Prices" title="LG mobile phones">LG Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Meizu_Mobiles_Prices" title="Meizu mobile phones">Meizu</a><img align="absbottom" height="17" src="images/new5.GIF" width="35"/>
# </li>
# <li>
# <a class="lnk" href="OnePlus_Mobiles_Prices" title="OnePlus mobile phones">OnePlus</a>
# </li>
# <li>
# <a class="lnk" href="Telenor_Mobiles_Prices" title="Telenor mobile phones">Telenor</a><img align="absbottom" height="17" src="images/new5.GIF" width="35"/>
# </li>
# <li>
# <a class="lnk" href="Alcatel_Mobiles_Prices" title="Alcatel mobile phones">Alcatel</a>
# </li>
# <li>
# <a class="lnk" href="HTC_Mobiles_Prices" title="HTC mobile phones">HTC</a>
# </li>
# <li>
# <a class="lnk" href="Microsoft_Mobiles_Prices" title="Microsoft mobile phones">Microsoft Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Rivo_Mobiles_Prices" title="Rivo mobile phones">Rivo</a>
# </li>
# <li>
# <a class="lnk" href="Haier_Mobiles_Prices" title="Haier mobile phones">Haier Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Mobilink_Mobiles_Prices" title="Mobilink Jazz X mobile phones">Mobilink JazzX</a>
# </li>
# <li>
# <a class="lnk" href="Motorola_Mobiles_Prices" title="Motorola mobile phones">Motorola</a>
# </li>
# <li>
# <a class="lnk" href="BlackBerry_Mobiles_Prices" title="Blackberry mobile phones">BlackBerry</a>
# </li>
# <li>
# <a class="lnk" href="Voice_Mobiles_Prices" title="Voice mobile phones">VOICE</a>
# </li>
# <li>
# <a class="lnk" href="iNew_Mobiles_Prices" title="iNew mobile phones">iNew</a>
# </li>
# <li>
# <a class="lnk" href="OPhone_Mobiles_Prices" title="Ophone mobile phones">OPhone</a>
# </li>
# <li>
# <a class="lnk" href="Calme_Mobiles_Prices" title="Calme mobile phones">Calme</a>
# </li>
# <li>
# <a class="lnk" href="GRight_Mobiles_Prices" title="Gright mobile phones">GRight</a>
# </li>
# <li>
# <a class="lnk" href="GFive_Mobiles_Prices" title="GFive mobile phones">G'Five</a>
# </li>
# <li>
# <a class="lnk" href="Club_Mobiles_Prices" title="Club mobile phones">Club Mobile</a>
# </li>
# <li>
# <a class="lnk" href="SonyEricsson_Mobiles_Prices" title="Sony Ericsson mobile phones">Sony Ericsson</a>
# </li>
# </ul>
# </section>
# <section>
# <h3 class="heading Menue">Search by Price</h3>
# <ul>
# <li>
# <a class="lnk" href="45000_to_250001_Mobiles" title="Mobile phones with prices greater than 45000">Prices  &gt; 45,000</a>
# </li>
# <li>
# <a class="lnk" href="35000_to_45001_Mobiles" title="Mobile phones in a price range of 35000 to 40000">35,001 - 45,000</a>
# </li>
# <li>
# <a class="lnk" href="25000_to_35001_Mobiles" title="Mobile phones in a price range of 25000 to 35000">25,001 - 35,000</a>
# </li>
# <li>
# <a class="lnk" href="15000_to_25001_Mobiles" title="Mobile phones in a price range of 15000 to 25000">15,001 - 25,000</a>
# </li>
# <li>
# <a class="lnk" href="10000_to_15001_Mobiles" title="Mobile phones in a price range of 10000 to 15000">10,001 - 15,000</a>
# </li>
# <li>
# <a class="lnk" href="5000_to_10001_Mobiles" title="Mobile phones in a price range of 5000 to 10000">5,001 - 10,000</a>
# </li>
# <li>
# <a class="lnk" href="0_to_5001_Mobiles" title="Mobile phones below 5000 Rupees">Prices &lt; 5000</a>
# </li>
# <li>
# <a class="lnk" href="0_to_150001_Mobiles" title="All mobile phones">All Mobile Prices</a>
# </li>
# </ul>
# </section>
# <section>
# <h3 class="heading Menue">Search by RAM<img align="absbottom" height="17" src="images/new5.GIF" width="30"/></h3>
# <ul>
# <li>
# <a class="lnk" href="256MB-RAM_Mobile-Phones" title="Mobile phones with 256MB RAM">256MB RAM</a>
# </li>
# <li>
# <a class="lnk" href="512MB-RAM_Mobile-Phones" title="Mobile phones with 512MB RAM">512MB RAM</a>
# </li>
# <li>
# <a class="lnk" href="1GB-RAM_Mobile-Phones" title="Mobile phones with 1GB RAM">1GB RAM</a>
# </li>
# <li>
# <a class="lnk" href="2GB-RAM_Mobile-Phones" title="Mobile phones with 2GB RAM">2GB RAM</a>
# </li>
# <li>
# <a class="lnk" href="3GB-RAM_Mobile-Phones" title="Mobile phones with 3GB RAM">3GB &amp; above RAM</a>
# </li>
# </ul>
# </section>
# <section>
# <h3 class="heading Menue">Search by Screen</h3>
# <ul>
# <li>
# <a class="lnk" href="1.0-To-2.9-inches-Display-Size_Mobile-Phones" title="Mobile phones with less than 3 inch display">Less Then 3 Inches</a>
# </li>
# <li>
# <a class="lnk" href="3.0-To-4.0-inches-Display-Size_Mobile-Phones" title="Mobile phones with 3 to 4 inch display">3.0 inch - 4.0 inch</a>
# </li>
# <li>
# <a class="lnk" href="4.1-To-4.9-inches-Display-Size_Mobile-Phones" title="Mobile phones with 4.1 to 4.9 inch display">4.1 inch - 4.9 inch</a>
# </li>
# <li>
# <a class="lnk" href="5.0-To-6.9-inches-Display-Size_Mobile-Phones" title="Mobile phones with 5 to 6.9 inch display">5.0 inch - 6.9 inch</a>
# </li>
# <li>
# <a class="lnk" href="7.0-To-8.9-inches-Display-Size_Mobile-Phones" title="Devices with 7 to 8.9 inch display">7.0 inch - 8.9 inch</a>
# </li>
# </ul>
# </section>
# <section>
# <h3 class="heading Menue">Search by Cam</h3>
# <ul>
# <li>
# <a class="lnk" href="13mp-Camera_Mobile-Phones" title="Mobile phones with 13MP Camera">13 MP Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="8mp-Camera_Mobile-Phones" title="Mobile phones with 8MP Camera">8 MP Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="5mp-Camera_Mobile-Phones" title="Mobile phones with 5MP Camera">5 MP Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="3mp-Camera_Mobile-Phones" title="Mobile phones with 3MP Camera">3 MP Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="2mp-Camera_Mobile-Phones" title="Mobile phones with 2MP Camera">2 MP Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="1mp-Camera_Mobile-Phones" title="Mobile phones with 1MP Camera">1 MP Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="VGA-Camera_Mobile-Phones" title="Mobile phones with VGA Camera">VGA Cam or less</a>
# </li>
# <li>
# <a class="lnk" href="Without-Camera_Mobile-Phones" title="Mobile phones without Camera">Without Camera</a>
# </li>
# </ul>
# </section>
# <section>
# <h3 class="heading Menue">Search by Type</h3>
# <ul>
# <li>
# <a class="lnk" href="Camera_Mobile-Phones" title="Mobile phones having a Camera">Camera Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="Video_Mobile-Phones" title="Mobile phones with video recording feature">Video Recording</a>
# </li>
# <li>
# <a class="lnk" href="Bluetooth_Mobile-Phones" title="Mobile phones with bluetooth">Bluetooth Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="DualSim_Mobile-Phones" title="Dual-Sim mobile phones">Dual Sim Phones</a>
# </li>
# <li>
# <a class="lnk" href="LAN_Mobile-Phones" title="Mobile phones with Wifi">Wireless LAN </a>
# </li>
# <li>
# <a class="lnk" href="MP3_Mobile-Phones" title="Mobile phones with MP3 playback">MP3 Playback </a>
# </li>
# <li>
# <a class="lnk" href="FM_Mobile-Phones" title="Mobile phones with FM Radio">FM Radio Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="MemoryCard_Mobile-Phones" title="Mobile phones having a card slot">Memory Card </a>
# </li>
# </ul>
# </section>
# <section>
# <h3 class="heading Menue">Search by OS<img align="absbottom" height="17" src="images/new5.GIF" width="30"/></h3>
# <ul>
# <li>
# <a class="lnk" href="Android_Mobile-Phones" title="All Android mobile phones">Android Phones </a>
# </li>
# <li>
# <a class="lnk" href="Symbian_Mobile-Phones" title="All Symbian mobile phones">Symbian Phones </a>
# </li>
# <li>
# <a class="lnk" href="Windows_Mobile-Phones" title="All Windows mobile phones">Windows Phones </a>
# </li>
# <li>
# <a class="lnk" href="Smartphone_Mobile-Phones" title="All Smartphones">All Smartphones </a>
# </li>
# </ul>
# </section>
# </div>

# %%
section_search_by_branch = div.find_all('section')
section_search_by_branch
# Out:
# [<section>
#  <h3 class="heading Menue">Search by Network</h3>
#  <ul>
#  <li>
#  <a class="lnk" href="Price-List-Of-All-3G_Mobile-Phones" title="3G mobile phones with prices">3G Mobile Prices</a>
#  </li>
#  <li>
#  <a class="lnk" href="Price-List-Of-All-4G_Mobile-Phones" title="4G mobile phones with prices">4G Mobiles </a><img align="absbottom" height="17" src="images/new5.GIF" width="35"/>
#  </li>
#  </ul>
#  </section>, <section>
#  <h3 class="heading Menue">Search by Brand</h3>
#  <ul>
#  <li>
#  <a class="lnk" href="Samsung_Mobiles_Prices" title="Samsung mobile phones">Samsung Mobile</a>
#  </li>
#  <li>
#  <a class="lnk" href="Huawei_Mobiles_Prices" title="Huawei mobile phones">Huawei Mobile</a>
#  </li>
#  <li>
#  <a class="lnk" href="Vivo_Mobiles_Prices" title="Vivo mobile phones">Vivo</a>
#  </li>
#  <li>
#  <a class="lnk" href="Honor_Mobiles_Prices" title="Honor mobile phones">Honor Mobile</a>
#  </li>
#  <li><a class="lnk" href="Oppo_Mobiles_Prices" title="OPPO mobile phones">OPPO Mobile</a></li>
#  <li><a class="lnk" href="Realme_Mobiles_Prices" title="Realme mobile phones">Realme Mobile<img align="absbottom" height="17" src="images/new5.GIF" width="35"/></a></li>
#  <li>
#  <a class="lnk" href="Nokia_Mobiles_Prices" title="Nokia mobile phones">Nokia</a>
#  </li>
#  <li>
#  <a class="lnk" href="Xiaomi_Mobiles_Prices" title="Xiaomi mobile phones">Xiaomi Mobile</a>
#  </li>
#  <li>
#  <a class="lnk" href="Infinix_Mobiles_Prices" title="Infinix mobile phones">Infinix Mobile</a>
#  </li>
#  <li>
#  <a class="lnk" href="Apple_Mobiles_Prices" title="Apple iphones">Apple iphone</a>
#  </li>
#  <li>
#  <a class="lnk" href="Tecno_Mobiles_Prices" title="Tecno mobile phones">Tecno Mobile</a>
#  </li>
#  <li>
#  <a class="lnk" href="Qmobile_Mobiles_Prices" title="QMobile mobile phones">QMobile</a>
#  </li>
#  <li>
#  <a class="lnk" href="Lenovo_Mobiles_Prices" title="Lenovo mobile phones">Lenovo Mobile</a>
#  </li>
#  <li>
#  <a class="lnk" href="Sony_Mobiles_Prices" title="Sony mobile phones">Sony</a>
#  </li>
#  <li>
#  <a class="lnk" href="LG_Mobiles_Prices" title="LG mobile phones">LG Mobile</a>
#  </li>
#  <li>
#  <a class="lnk" href="Meizu_Mobiles_Prices" title="Meizu mobile phones">Meizu</a><img align="absbottom" height="17" src="images/new5.GIF" width="35"/>
#  </li>
#  <li>
#  <a class="lnk" href="OnePlus_Mobiles_Prices" title="OnePlus mobile phones">OnePlus</a>
#  </li>
#  <li>
#  <a class="lnk" href="Telenor_Mobiles_Prices" title="Telenor mobile phones">Telenor</a><img align="absbottom" height="17" src="images/new5.GIF" width="35"/>
#  </li>
#  <li>
#  <a class="lnk" href="Alcatel_Mobiles_Prices" title="Alcatel mobile phones">Alcatel</a>
#  </li>
#  <li>
#  <a class="lnk" href="HTC_Mobiles_Prices" title="HTC mobile phones">HTC</a>
#  </li>
#  <li>
#  <a class="lnk" href="Microsoft_Mobiles_Prices" title="Microsoft mobile phones">Microsoft Mobile</a>
#  </li>
#  <li>
#  <a class="lnk" href="Rivo_Mobiles_Prices" title="Rivo mobile phones">Rivo</a>
#  </li>
#  <li>
#  <a class="lnk" href="Haier_Mobiles_Prices" title="Haier mobile phones">Haier Mobile</a>
#  </li>
#  <li>
#  <a class="lnk" href="Mobilink_Mobiles_Prices" title="Mobilink Jazz X mobile phones">Mobilink JazzX</a>
#  </li>
#  <li>
#  <a class="lnk" href="Motorola_Mobiles_Prices" title="Motorola mobile phones">Motorola</a>
#  </li>
#  <li>
#  <a class="lnk" href="BlackBerry_Mobiles_Prices" title="Blackberry mobile phones">BlackBerry</a>
#  </li>
#  <li>
#  <a class="lnk" href="Voice_Mobiles_Prices" title="Voice mobile phones">VOICE</a>
#  </li>
#  <li>
#  <a class="lnk" href="iNew_Mobiles_Prices" title="iNew mobile phones">iNew</a>
#  </li>
#  <li>
#  <a class="lnk" href="OPhone_Mobiles_Prices" title="Ophone mobile phones">OPhone</a>
#  </li>
#  <li>
#  <a class="lnk" href="Calme_Mobiles_Prices" title="Calme mobile phones">Calme</a>
#  </li>
#  <li>
#  <a class="lnk" href="GRight_Mobiles_Prices" title="Gright mobile phones">GRight</a>
#  </li>
#  <li>
#  <a class="lnk" href="GFive_Mobiles_Prices" title="GFive mobile phones">G'Five</a>
#  </li>
#  <li>
#  <a class="lnk" href="Club_Mobiles_Prices" title="Club mobile phones">Club Mobile</a>
#  </li>
#  <li>
#  <a class="lnk" href="SonyEricsson_Mobiles_Prices" title="Sony Ericsson mobile phones">Sony Ericsson</a>
#  </li>
#  </ul>
#  </section>, <section>
#  <h3 class="heading Menue">Search by Price</h3>
#  <ul>
#  <li>
#  <a class="lnk" href="45000_to_250001_Mobiles" title="Mobile phones with prices greater than 45000">Prices  &gt; 45,000</a>
#  </li>
#  <li>
#  <a class="lnk" href="35000_to_45001_Mobiles" title="Mobile phones in a price range of 35000 to 40000">35,001 - 45,000</a>
#  </li>
#  <li>
#  <a class="lnk" href="25000_to_35001_Mobiles" title="Mobile phones in a price range of 25000 to 35000">25,001 - 35,000</a>
#  </li>
#  <li>
#  <a class="lnk" href="15000_to_25001_Mobiles" title="Mobile phones in a price range of 15000 to 25000">15,001 - 25,000</a>
#  </li>
#  <li>
#  <a class="lnk" href="10000_to_15001_Mobiles" title="Mobile phones in a price range of 10000 to 15000">10,001 - 15,000</a>
#  </li>
#  <li>
#  <a class="lnk" href="5000_to_10001_Mobiles" title="Mobile phones in a price range of 5000 to 10000">5,001 - 10,000</a>
#  </li>
#  <li>
#  <a class="lnk" href="0_to_5001_Mobiles" title="Mobile phones below 5000 Rupees">Prices &lt; 5000</a>
#  </li>
#  <li>
#  <a class="lnk" href="0_to_150001_Mobiles" title="All mobile phones">All Mobile Prices</a>
#  </li>
#  </ul>
#  </section>, <section>
#  <h3 class="heading Menue">Search by RAM<img align="absbottom" height="17" src="images/new5.GIF" width="30"/></h3>
#  <ul>
#  <li>
#  <a class="lnk" href="256MB-RAM_Mobile-Phones" title="Mobile phones with 256MB RAM">256MB RAM</a>
#  </li>
#  <li>
#  <a class="lnk" href="512MB-RAM_Mobile-Phones" title="Mobile phones with 512MB RAM">512MB RAM</a>
#  </li>
#  <li>
#  <a class="lnk" href="1GB-RAM_Mobile-Phones" title="Mobile phones with 1GB RAM">1GB RAM</a>
#  </li>
#  <li>
#  <a class="lnk" href="2GB-RAM_Mobile-Phones" title="Mobile phones with 2GB RAM">2GB RAM</a>
#  </li>
#  <li>
#  <a class="lnk" href="3GB-RAM_Mobile-Phones" title="Mobile phones with 3GB RAM">3GB &amp; above RAM</a>
#  </li>
#  </ul>
#  </section>, <section>
#  <h3 class="heading Menue">Search by Screen</h3>
#  <ul>
#  <li>
#  <a class="lnk" href="1.0-To-2.9-inches-Display-Size_Mobile-Phones" title="Mobile phones with less than 3 inch display">Less Then 3 Inches</a>
#  </li>
#  <li>
#  <a class="lnk" href="3.0-To-4.0-inches-Display-Size_Mobile-Phones" title="Mobile phones with 3 to 4 inch display">3.0 inch - 4.0 inch</a>
#  </li>
#  <li>
#  <a class="lnk" href="4.1-To-4.9-inches-Display-Size_Mobile-Phones" title="Mobile phones with 4.1 to 4.9 inch display">4.1 inch - 4.9 inch</a>
#  </li>
#  <li>
#  <a class="lnk" href="5.0-To-6.9-inches-Display-Size_Mobile-Phones" title="Mobile phones with 5 to 6.9 inch display">5.0 inch - 6.9 inch</a>
#  </li>
#  <li>
#  <a class="lnk" href="7.0-To-8.9-inches-Display-Size_Mobile-Phones" title="Devices with 7 to 8.9 inch display">7.0 inch - 8.9 inch</a>
#  </li>
#  </ul>
#  </section>, <section>
#  <h3 class="heading Menue">Search by Cam</h3>
#  <ul>
#  <li>
#  <a class="lnk" href="13mp-Camera_Mobile-Phones" title="Mobile phones with 13MP Camera">13 MP Mobiles</a>
#  </li>
#  <li>
#  <a class="lnk" href="8mp-Camera_Mobile-Phones" title="Mobile phones with 8MP Camera">8 MP Mobiles</a>
#  </li>
#  <li>
#  <a class="lnk" href="5mp-Camera_Mobile-Phones" title="Mobile phones with 5MP Camera">5 MP Mobiles</a>
#  </li>
#  <li>
#  <a class="lnk" href="3mp-Camera_Mobile-Phones" title="Mobile phones with 3MP Camera">3 MP Mobiles</a>
#  </li>
#  <li>
#  <a class="lnk" href="2mp-Camera_Mobile-Phones" title="Mobile phones with 2MP Camera">2 MP Mobiles</a>
#  </li>
#  <li>
#  <a class="lnk" href="1mp-Camera_Mobile-Phones" title="Mobile phones with 1MP Camera">1 MP Mobiles</a>
#  </li>
#  <li>
#  <a class="lnk" href="VGA-Camera_Mobile-Phones" title="Mobile phones with VGA Camera">VGA Cam or less</a>
#  </li>
#  <li>
#  <a class="lnk" href="Without-Camera_Mobile-Phones" title="Mobile phones without Camera">Without Camera</a>
#  </li>
#  </ul>
#  </section>, <section>
#  <h3 class="heading Menue">Search by Type</h3>
#  <ul>
#  <li>
#  <a class="lnk" href="Camera_Mobile-Phones" title="Mobile phones having a Camera">Camera Mobiles</a>
#  </li>
#  <li>
#  <a class="lnk" href="Video_Mobile-Phones" title="Mobile phones with video recording feature">Video Recording</a>
#  </li>
#  <li>
#  <a class="lnk" href="Bluetooth_Mobile-Phones" title="Mobile phones with bluetooth">Bluetooth Mobiles</a>
#  </li>
#  <li>
#  <a class="lnk" href="DualSim_Mobile-Phones" title="Dual-Sim mobile phones">Dual Sim Phones</a>
#  </li>
#  <li>
#  <a class="lnk" href="LAN_Mobile-Phones" title="Mobile phones with Wifi">Wireless LAN </a>
#  </li>
#  <li>
#  <a class="lnk" href="MP3_Mobile-Phones" title="Mobile phones with MP3 playback">MP3 Playback </a>
#  </li>
#  <li>
#  <a class="lnk" href="FM_Mobile-Phones" title="Mobile phones with FM Radio">FM Radio Mobiles</a>
#  </li>
#  <li>
#  <a class="lnk" href="MemoryCard_Mobile-Phones" title="Mobile phones having a card slot">Memory Card </a>
#  </li>
#  </ul>
#  </section>, <section>
#  <h3 class="heading Menue">Search by OS<img align="absbottom" height="17" src="images/new5.GIF" width="30"/></h3>
#  <ul>
#  <li>
#  <a class="lnk" href="Android_Mobile-Phones" title="All Android mobile phones">Android Phones </a>
#  </li>
#  <li>
#  <a class="lnk" href="Symbian_Mobile-Phones" title="All Symbian mobile phones">Symbian Phones </a>
#  </li>
#  <li>
#  <a class="lnk" href="Windows_Mobile-Phones" title="All Windows mobile phones">Windows Phones </a>
#  </li>
#  <li>
#  <a class="lnk" href="Smartphone_Mobile-Phones" title="All Smartphones">All Smartphones </a>
#  </li>
#  </ul>
#  </section>]

# %%
section_search_by_branch = div.find_all('section')[1]
section_search_by_branch
# Out:
# <section>
# <h3 class="heading Menue">Search by Brand</h3>
# <ul>
# <li>
# <a class="lnk" href="Samsung_Mobiles_Prices" title="Samsung mobile phones">Samsung Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Huawei_Mobiles_Prices" title="Huawei mobile phones">Huawei Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Vivo_Mobiles_Prices" title="Vivo mobile phones">Vivo</a>
# </li>
# <li>
# <a class="lnk" href="Honor_Mobiles_Prices" title="Honor mobile phones">Honor Mobile</a>
# </li>
# <li><a class="lnk" href="Oppo_Mobiles_Prices" title="OPPO mobile phones">OPPO Mobile</a></li>
# <li><a class="lnk" href="Realme_Mobiles_Prices" title="Realme mobile phones">Realme Mobile<img align="absbottom" height="17" src="images/new5.GIF" width="35"/></a></li>
# <li>
# <a class="lnk" href="Nokia_Mobiles_Prices" title="Nokia mobile phones">Nokia</a>
# </li>
# <li>
# <a class="lnk" href="Xiaomi_Mobiles_Prices" title="Xiaomi mobile phones">Xiaomi Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Infinix_Mobiles_Prices" title="Infinix mobile phones">Infinix Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Apple_Mobiles_Prices" title="Apple iphones">Apple iphone</a>
# </li>
# <li>
# <a class="lnk" href="Tecno_Mobiles_Prices" title="Tecno mobile phones">Tecno Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Qmobile_Mobiles_Prices" title="QMobile mobile phones">QMobile</a>
# </li>
# <li>
# <a class="lnk" href="Lenovo_Mobiles_Prices" title="Lenovo mobile phones">Lenovo Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Sony_Mobiles_Prices" title="Sony mobile phones">Sony</a>
# </li>
# <li>
# <a class="lnk" href="LG_Mobiles_Prices" title="LG mobile phones">LG Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Meizu_Mobiles_Prices" title="Meizu mobile phones">Meizu</a><img align="absbottom" height="17" src="images/new5.GIF" width="35"/>
# </li>
# <li>
# <a class="lnk" href="OnePlus_Mobiles_Prices" title="OnePlus mobile phones">OnePlus</a>
# </li>
# <li>
# <a class="lnk" href="Telenor_Mobiles_Prices" title="Telenor mobile phones">Telenor</a><img align="absbottom" height="17" src="images/new5.GIF" width="35"/>
# </li>
# <li>
# <a class="lnk" href="Alcatel_Mobiles_Prices" title="Alcatel mobile phones">Alcatel</a>
# </li>
# <li>
# <a class="lnk" href="HTC_Mobiles_Prices" title="HTC mobile phones">HTC</a>
# </li>
# <li>
# <a class="lnk" href="Microsoft_Mobiles_Prices" title="Microsoft mobile phones">Microsoft Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Rivo_Mobiles_Prices" title="Rivo mobile phones">Rivo</a>
# </li>
# <li>
# <a class="lnk" href="Haier_Mobiles_Prices" title="Haier mobile phones">Haier Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Mobilink_Mobiles_Prices" title="Mobilink Jazz X mobile phones">Mobilink JazzX</a>
# </li>
# <li>
# <a class="lnk" href="Motorola_Mobiles_Prices" title="Motorola mobile phones">Motorola</a>
# </li>
# <li>
# <a class="lnk" href="BlackBerry_Mobiles_Prices" title="Blackberry mobile phones">BlackBerry</a>
# </li>
# <li>
# <a class="lnk" href="Voice_Mobiles_Prices" title="Voice mobile phones">VOICE</a>
# </li>
# <li>
# <a class="lnk" href="iNew_Mobiles_Prices" title="iNew mobile phones">iNew</a>
# </li>
# <li>
# <a class="lnk" href="OPhone_Mobiles_Prices" title="Ophone mobile phones">OPhone</a>
# </li>
# <li>
# <a class="lnk" href="Calme_Mobiles_Prices" title="Calme mobile phones">Calme</a>
# </li>
# <li>
# <a class="lnk" href="GRight_Mobiles_Prices" title="Gright mobile phones">GRight</a>
# </li>
# <li>
# <a class="lnk" href="GFive_Mobiles_Prices" title="GFive mobile phones">G'Five</a>
# </li>
# <li>
# <a class="lnk" href="Club_Mobiles_Prices" title="Club mobile phones">Club Mobile</a>
# </li>
# <li>
# <a class="lnk" href="SonyEricsson_Mobiles_Prices" title="Sony Ericsson mobile phones">Sony Ericsson</a>
# </li>
# </ul>
# </section>

# %%
brands = section_search_by_branch.find('ul').find_all('li')
brands
# Out:
# [<li>
#  <a class="lnk" href="Samsung_Mobiles_Prices" title="Samsung mobile phones">Samsung Mobile</a>
#  </li>, <li>
#  <a class="lnk" href="Huawei_Mobiles_Prices" title="Huawei mobile phones">Huawei Mobile</a>
#  </li>, <li>
#  <a class="lnk" href="Vivo_Mobiles_Prices" title="Vivo mobile phones">Vivo</a>
#  </li>, <li>
#  <a class="lnk" href="Honor_Mobiles_Prices" title="Honor mobile phones">Honor Mobile</a>
#  </li>, <li><a class="lnk" href="Oppo_Mobiles_Prices" title="OPPO mobile phones">OPPO Mobile</a></li>, <li><a class="lnk" href="Realme_Mobiles_Prices" title="Realme mobile phones">Realme Mobile<img align="absbottom" height="17" src="images/new5.GIF" width="35"/></a></li>, <li>
#  <a class="lnk" href="Nokia_Mobiles_Prices" title="Nokia mobile phones">Nokia</a>
#  </li>, <li>
#  <a class="lnk" href="Xiaomi_Mobiles_Prices" title="Xiaomi mobile phones">Xiaomi Mobile</a>
#  </li>, <li>
#  <a class="lnk" href="Infinix_Mobiles_Prices" title="Infinix mobile phones">Infinix Mobile</a>
#  </li>, <li>
#  <a class="lnk" href="Apple_Mobiles_Prices" title="Apple iphones">Apple iphone</a>
#  </li>, <li>
#  <a class="lnk" href="Tecno_Mobiles_Prices" title="Tecno mobile phones">Tecno Mobile</a>
#  </li>, <li>
#  <a class="lnk" href="Qmobile_Mobiles_Prices" title="QMobile mobile phones">QMobile</a>
#  </li>, <li>
#  <a class="lnk" href="Lenovo_Mobiles_Prices" title="Lenovo mobile phones">Lenovo Mobile</a>
#  </li>, <li>
#  <a class="lnk" href="Sony_Mobiles_Prices" title="Sony mobile phones">Sony</a>
#  </li>, <li>
#  <a class="lnk" href="LG_Mobiles_Prices" title="LG mobile phones">LG Mobile</a>
#  </li>, <li>
#  <a class="lnk" href="Meizu_Mobiles_Prices" title="Meizu mobile phones">Meizu</a><img align="absbottom" height="17" src="images/new5.GIF" width="35"/>
#  </li>, <li>
#  <a class="lnk" href="OnePlus_Mobiles_Prices" title="OnePlus mobile phones">OnePlus</a>
#  </li>, <li>
#  <a class="lnk" href="Telenor_Mobiles_Prices" title="Telenor mobile phones">Telenor</a><img align="absbottom" height="17" src="images/new5.GIF" width="35"/>
#  </li>, <li>
#  <a class="lnk" href="Alcatel_Mobiles_Prices" title="Alcatel mobile phones">Alcatel</a>
#  </li>, <li>
#  <a class="lnk" href="HTC_Mobiles_Prices" title="HTC mobile phones">HTC</a>
#  </li>, <li>
#  <a class="lnk" href="Microsoft_Mobiles_Prices" title="Microsoft mobile phones">Microsoft Mobile</a>
#  </li>, <li>
#  <a class="lnk" href="Rivo_Mobiles_Prices" title="Rivo mobile phones">Rivo</a>
#  </li>, <li>
#  <a class="lnk" href="Haier_Mobiles_Prices" title="Haier mobile phones">Haier Mobile</a>
#  </li>, <li>
#  <a class="lnk" href="Mobilink_Mobiles_Prices" title="Mobilink Jazz X mobile phones">Mobilink JazzX</a>
#  </li>, <li>
#  <a class="lnk" href="Motorola_Mobiles_Prices" title="Motorola mobile phones">Motorola</a>
#  </li>, <li>
#  <a class="lnk" href="BlackBerry_Mobiles_Prices" title="Blackberry mobile phones">BlackBerry</a>
#  </li>, <li>
#  <a class="lnk" href="Voice_Mobiles_Prices" title="Voice mobile phones">VOICE</a>
#  </li>, <li>
#  <a class="lnk" href="iNew_Mobiles_Prices" title="iNew mobile phones">iNew</a>
#  </li>, <li>
#  <a class="lnk" href="OPhone_Mobiles_Prices" title="Ophone mobile phones">OPhone</a>
#  </li>, <li>
#  <a class="lnk" href="Calme_Mobiles_Prices" title="Calme mobile phones">Calme</a>
#  </li>, <li>
#  <a class="lnk" href="GRight_Mobiles_Prices" title="Gright mobile phones">GRight</a>
#  </li>, <li>
#  <a class="lnk" href="GFive_Mobiles_Prices" title="GFive mobile phones">G'Five</a>
#  </li>, <li>
#  <a class="lnk" href="Club_Mobiles_Prices" title="Club mobile phones">Club Mobile</a>
#  </li>, <li>
#  <a class="lnk" href="SonyEricsson_Mobiles_Prices" title="Sony Ericsson mobile phones">Sony Ericsson</a>
#  </li>]

# %%
for i in brands:
    print(i)
    brand_list.append((i.find('a').string, i.find('a')['href']))
# Out:
# <li>
# <a class="lnk" href="Samsung_Mobiles_Prices" title="Samsung mobile phones">Samsung Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Huawei_Mobiles_Prices" title="Huawei mobile phones">Huawei Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Vivo_Mobiles_Prices" title="Vivo mobile phones">Vivo</a>
# </li>
# <li>
# <a class="lnk" href="Honor_Mobiles_Prices" title="Honor mobile phones">Honor Mobile</a>
# </li>
# <li><a class="lnk" href="Oppo_Mobiles_Prices" title="OPPO mobile phones">OPPO Mobile</a></li>
# <li><a class="lnk" href="Realme_Mobiles_Prices" title="Realme mobile phones">Realme Mobile<img align="absbottom" height="17" src="images/new5.GIF" width="35"/></a></li>
# <li>
# <a class="lnk" href="Nokia_Mobiles_Prices" title="Nokia mobile phones">Nokia</a>
# </li>
# <li>
# <a class="lnk" href="Xiaomi_Mobiles_Prices" title="Xiaomi mobile phones">Xiaomi Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Infinix_Mobiles_Prices" title="Infinix mobile phones">Infinix Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Apple_Mobiles_Prices" title="Apple iphones">Apple iphone</a>
# </li>
# <li>
# <a class="lnk" href="Tecno_Mobiles_Prices" title="Tecno mobile phones">Tecno Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Qmobile_Mobiles_Prices" title="QMobile mobile phones">QMobile</a>
# </li>
# <li>
# <a class="lnk" href="Lenovo_Mobiles_Prices" title="Lenovo mobile phones">Lenovo Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Sony_Mobiles_Prices" title="Sony mobile phones">Sony</a>
# </li>
# <li>
# <a class="lnk" href="LG_Mobiles_Prices" title="LG mobile phones">LG Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Meizu_Mobiles_Prices" title="Meizu mobile phones">Meizu</a><img align="absbottom" height="17" src="images/new5.GIF" width="35"/>
# </li>
# <li>
# <a class="lnk" href="OnePlus_Mobiles_Prices" title="OnePlus mobile phones">OnePlus</a>
# </li>
# <li>
# <a class="lnk" href="Telenor_Mobiles_Prices" title="Telenor mobile phones">Telenor</a><img align="absbottom" height="17" src="images/new5.GIF" width="35"/>
# </li>
# <li>
# <a class="lnk" href="Alcatel_Mobiles_Prices" title="Alcatel mobile phones">Alcatel</a>
# </li>
# <li>
# <a class="lnk" href="HTC_Mobiles_Prices" title="HTC mobile phones">HTC</a>
# </li>
# <li>
# <a class="lnk" href="Microsoft_Mobiles_Prices" title="Microsoft mobile phones">Microsoft Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Rivo_Mobiles_Prices" title="Rivo mobile phones">Rivo</a>
# </li>
# <li>
# <a class="lnk" href="Haier_Mobiles_Prices" title="Haier mobile phones">Haier Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Mobilink_Mobiles_Prices" title="Mobilink Jazz X mobile phones">Mobilink JazzX</a>
# </li>
# <li>
# <a class="lnk" href="Motorola_Mobiles_Prices" title="Motorola mobile phones">Motorola</a>
# </li>
# <li>
# <a class="lnk" href="BlackBerry_Mobiles_Prices" title="Blackberry mobile phones">BlackBerry</a>
# </li>
# <li>
# <a class="lnk" href="Voice_Mobiles_Prices" title="Voice mobile phones">VOICE</a>
# </li>
# <li>
# <a class="lnk" href="iNew_Mobiles_Prices" title="iNew mobile phones">iNew</a>
# </li>
# <li>
# <a class="lnk" href="OPhone_Mobiles_Prices" title="Ophone mobile phones">OPhone</a>
# </li>
# <li>
# <a class="lnk" href="Calme_Mobiles_Prices" title="Calme mobile phones">Calme</a>
# </li>
# <li>
# <a class="lnk" href="GRight_Mobiles_Prices" title="Gright mobile phones">GRight</a>
# </li>
# <li>
# <a class="lnk" href="GFive_Mobiles_Prices" title="GFive mobile phones">G'Five</a>
# </li>
# <li>
# <a class="lnk" href="Club_Mobiles_Prices" title="Club mobile phones">Club Mobile</a>
# </li>
# <li>
# <a class="lnk" href="SonyEricsson_Mobiles_Prices" title="Sony Ericsson mobile phones">Sony Ericsson</a>
# </li>

# %%
brand_list
# Out:
# [('Samsung Mobile', 'Samsung_Mobiles_Prices'),
#  ('Huawei Mobile', 'Huawei_Mobiles_Prices'),
#  ('Vivo', 'Vivo_Mobiles_Prices'),
#  ('Honor Mobile', 'Honor_Mobiles_Prices'),
#  ('OPPO Mobile', 'Oppo_Mobiles_Prices'),
#  (None, 'Realme_Mobiles_Prices'),
#  ('Nokia', 'Nokia_Mobiles_Prices'),
#  ('Xiaomi Mobile', 'Xiaomi_Mobiles_Prices'),
#  ('Infinix Mobile', 'Infinix_Mobiles_Prices'),
#  ('Apple iphone', 'Apple_Mobiles_Prices'),
#  ('Tecno Mobile', 'Tecno_Mobiles_Prices'),
#  ('QMobile', 'Qmobile_Mobiles_Prices'),
#  ('Lenovo Mobile', 'Lenovo_Mobiles_Prices'),
#  ('Sony', 'Sony_Mobiles_Prices'),
#  ('LG Mobile', 'LG_Mobiles_Prices'),
#  ('Meizu', 'Meizu_Mobiles_Prices'),
#  ('OnePlus', 'OnePlus_Mobiles_Prices'),
#  ('Telenor', 'Telenor_Mobiles_Prices'),
#  ('Alcatel', 'Alcatel_Mobiles_Prices'),
#  ('HTC', 'HTC_Mobiles_Prices'),
#  ('Microsoft Mobile', 'Microsoft_Mobiles_Prices'),
#  ('Rivo', 'Rivo_Mobiles_Prices'),
#  ('Haier Mobile', 'Haier_Mobiles_Prices'),
#  ('Mobilink JazzX', 'Mobilink_Mobiles_Prices'),
#  ('Motorola', 'Motorola_Mobiles_Prices'),
#  ('BlackBerry', 'BlackBerry_Mobiles_Prices'),
#  ('VOICE', 'Voice_Mobiles_Prices'),
#  ('iNew', 'iNew_Mobiles_Prices'),
#  ('OPhone', 'OPhone_Mobiles_Prices'),
#  ('Calme', 'Calme_Mobiles_Prices'),
#  ('GRight', 'GRight_Mobiles_Prices'),
#  ("G'Five", 'GFive_Mobiles_Prices'),
#  ('Club Mobile', 'Club_Mobiles_Prices'),
#  ('Sony Ericsson', 'SonyEricsson_Mobiles_Prices')]

# %%
dict = list(enumerate(brand_list))
dict
# Out:
# [(0, ('Samsung Mobile', 'Samsung_Mobiles_Prices')),
#  (1, ('Huawei Mobile', 'Huawei_Mobiles_Prices')),
#  (2, ('Vivo', 'Vivo_Mobiles_Prices')),
#  (3, ('Honor Mobile', 'Honor_Mobiles_Prices')),
#  (4, ('OPPO Mobile', 'Oppo_Mobiles_Prices')),
#  (5, (None, 'Realme_Mobiles_Prices')),
#  (6, ('Nokia', 'Nokia_Mobiles_Prices')),
#  (7, ('Xiaomi Mobile', 'Xiaomi_Mobiles_Prices')),
#  (8, ('Infinix Mobile', 'Infinix_Mobiles_Prices')),
#  (9, ('Apple iphone', 'Apple_Mobiles_Prices')),
#  (10, ('Tecno Mobile', 'Tecno_Mobiles_Prices')),
#  (11, ('QMobile', 'Qmobile_Mobiles_Prices')),
#  (12, ('Lenovo Mobile', 'Lenovo_Mobiles_Prices')),
#  (13, ('Sony', 'Sony_Mobiles_Prices')),
#  (14, ('LG Mobile', 'LG_Mobiles_Prices')),
#  (15, ('Meizu', 'Meizu_Mobiles_Prices')),
#  (16, ('OnePlus', 'OnePlus_Mobiles_Prices')),
#  (17, ('Telenor', 'Telenor_Mobiles_Prices')),
#  (18, ('Alcatel', 'Alcatel_Mobiles_Prices')),
#  (19, ('HTC', 'HTC_Mobiles_Prices')),
#  (20, ('Microsoft Mobile', 'Microsoft_Mobiles_Prices')),
#  (21, ('Rivo', 'Rivo_Mobiles_Prices')),
#  (22, ('Haier Mobile', 'Haier_Mobiles_Prices')),
#  (23, ('Mobilink JazzX', 'Mobilink_Mobiles_Prices')),
#  (24, ('Motorola', 'Motorola_Mobiles_Prices')),
#  (25, ('BlackBerry', 'BlackBerry_Mobiles_Prices')),
#  (26, ('VOICE', 'Voice_Mobiles_Prices')),
#  (27, ('iNew', 'iNew_Mobiles_Prices')),
#  (28, ('OPhone', 'OPhone_Mobiles_Prices')),
#  (29, ('Calme', 'Calme_Mobiles_Prices')),
#  (30, ('GRight', 'GRight_Mobiles_Prices')),
#  (31, ("G'Five", 'GFive_Mobiles_Prices')),
#  (32, ('Club Mobile', 'Club_Mobiles_Prices')),
#  (33, ('Sony Ericsson', 'SonyEricsson_Mobiles_Prices'))]

# %%
for i in dict:
    print(i[0], ':', i[1][0])
# Out:
# 0 : Samsung Mobile
# 1 : Huawei Mobile
# 2 : Vivo
# 3 : Honor Mobile
# 4 : OPPO Mobile
# 5 : None
# 6 : Nokia
# 7 : Xiaomi Mobile
# 8 : Infinix Mobile
# 9 : Apple iphone
# 10 : Tecno Mobile
# 11 : QMobile
# 12 : Lenovo Mobile
# 13 : Sony
# 14 : LG Mobile
# 15 : Meizu
# 16 : OnePlus
# 17 : Telenor
# 18 : Alcatel
# 19 : HTC
# 20 : Microsoft Mobile
# 21 : Rivo
# 22 : Haier Mobile
# 23 : Mobilink JazzX
# 24 : Motorola
# 25 : BlackBerry
# 26 : VOICE
# 27 : iNew
# 28 : OPhone
# 29 : Calme
# 30 : GRight
# 31 : G'Five
# 32 : Club Mobile
# 33 : Sony Ericsson

# %%
uri = url + brand_list[29][1]
print(uri)
# Out:
# https://www.whatmobile.com.pk/Calme_Mobiles_Prices

# %%
brand_list
# Out:
# [('Samsung Mobile', 'Samsung_Mobiles_Prices'),
#  ('Huawei Mobile', 'Huawei_Mobiles_Prices'),
#  ('Vivo', 'Vivo_Mobiles_Prices'),
#  ('Honor Mobile', 'Honor_Mobiles_Prices'),
#  ('OPPO Mobile', 'Oppo_Mobiles_Prices'),
#  (None, 'Realme_Mobiles_Prices'),
#  ('Nokia', 'Nokia_Mobiles_Prices'),
#  ('Xiaomi Mobile', 'Xiaomi_Mobiles_Prices'),
#  ('Infinix Mobile', 'Infinix_Mobiles_Prices'),
#  ('Apple iphone', 'Apple_Mobiles_Prices'),
#  ('Tecno Mobile', 'Tecno_Mobiles_Prices'),
#  ('QMobile', 'Qmobile_Mobiles_Prices'),
#  ('Lenovo Mobile', 'Lenovo_Mobiles_Prices'),
#  ('Sony', 'Sony_Mobiles_Prices'),
#  ('LG Mobile', 'LG_Mobiles_Prices'),
#  ('Meizu', 'Meizu_Mobiles_Prices'),
#  ('OnePlus', 'OnePlus_Mobiles_Prices'),
#  ('Telenor', 'Telenor_Mobiles_Prices'),
#  ('Alcatel', 'Alcatel_Mobiles_Prices'),
#  ('HTC', 'HTC_Mobiles_Prices'),
#  ('Microsoft Mobile', 'Microsoft_Mobiles_Prices'),
#  ('Rivo', 'Rivo_Mobiles_Prices'),
#  ('Haier Mobile', 'Haier_Mobiles_Prices'),
#  ('Mobilink JazzX', 'Mobilink_Mobiles_Prices'),
#  ('Motorola', 'Motorola_Mobiles_Prices'),
#  ('BlackBerry', 'BlackBerry_Mobiles_Prices'),
#  ('VOICE', 'Voice_Mobiles_Prices'),
#  ('iNew', 'iNew_Mobiles_Prices'),
#  ('OPhone', 'OPhone_Mobiles_Prices'),
#  ('Calme', 'Calme_Mobiles_Prices'),
#  ('GRight', 'GRight_Mobiles_Prices'),
#  ("G'Five", 'GFive_Mobiles_Prices'),
#  ('Club Mobile', 'Club_Mobiles_Prices'),
#  ('Sony Ericsson', 'SonyEricsson_Mobiles_Prices')]

# %%
td = html_parse(uri).find_all('td', {'class': 'BiggerText'})
td
# Out:
# [<td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S33" title="Calme Spark S33 mobiles support 5.0 inches display">
#  <img alt="Calme Spark S33 Price in Pakistan" border="0" src="admin/images/Calme/SparkS33s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S33" style="text-decoration:none" title="Calme Spark S33 price">
#                  Calme<br/>Spark S33<br/></a>
#  <span class="PriceFont">
#                      Rs. 8,300                    </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S20" title="Calme Spark S20 mobiles support 4.7 inches display">
#  <img alt="Calme Spark S20 Price in Pakistan" border="0" src="admin/images/Calme/SparkS20s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S20" style="text-decoration:none" title="Calme Spark S20 price">
#                  Calme<br/>Spark S20<br/></a>
#  <span class="PriceFont">
#                      Rs. 8,000                    </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S30" title="Calme Spark S30 mobiles support 5.0 inches display">
#  <img alt="Calme Spark S30 Price in Pakistan" border="0" src="admin/images/Calme/SparkS30s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S30" style="text-decoration:none" title="Calme Spark S30 price">
#                  Calme<br/>Spark S30<br/></a>
#  <span class="PriceFont">
#                      Rs. 7,999                    </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S8" title="Calme Spark S8 mobiles support 4.0 inches display">
#  <img alt="Calme Spark S8 Price in Pakistan" border="0" src="admin/images/Calme/SparkS8s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S8" style="text-decoration:none" title="Calme Spark S8 price">
#                  Calme<br/>Spark S8<br/></a>
#  <span class="PriceFont">
#                      Rs. 7,500                    </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S22" title="Calme Spark S22 mobiles support 4.5 inches display">
#  <img alt="Calme Spark S22 Price in Pakistan" border="0" src="admin/images/Calme/SparkS22s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S22" style="text-decoration:none" title="Calme Spark S22 price">
#                  Calme<br/>Spark S22<br/></a>
#  <span class="PriceFont">
#                      Rs. 7,500                    </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S9" title="Calme Spark S9 mobiles support 4.0 inches display">
#  <img alt="Calme Spark S9 Price in Pakistan" border="0" src="admin/images/Calme/SparkS9s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S9" style="text-decoration:none" title="Calme Spark S9 price">
#                  Calme<br/>Spark S9<br/></a>
#  <span class="PriceFont">
#                      Rs. 7,000                    </span><br/>
#  </td></td></td></td></td></td>,
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S20" title="Calme Spark S20 mobiles support 4.7 inches display">
#  <img alt="Calme Spark S20 Price in Pakistan" border="0" src="admin/images/Calme/SparkS20s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S20" style="text-decoration:none" title="Calme Spark S20 price">
#                  Calme<br/>Spark S20<br/></a>
#  <span class="PriceFont">
#                      Rs. 8,000                    </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S30" title="Calme Spark S30 mobiles support 5.0 inches display">
#  <img alt="Calme Spark S30 Price in Pakistan" border="0" src="admin/images/Calme/SparkS30s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S30" style="text-decoration:none" title="Calme Spark S30 price">
#                  Calme<br/>Spark S30<br/></a>
#  <span class="PriceFont">
#                      Rs. 7,999                    </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S8" title="Calme Spark S8 mobiles support 4.0 inches display">
#  <img alt="Calme Spark S8 Price in Pakistan" border="0" src="admin/images/Calme/SparkS8s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S8" style="text-decoration:none" title="Calme Spark S8 price">
#                  Calme<br/>Spark S8<br/></a>
#  <span class="PriceFont">
#                      Rs. 7,500                    </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S22" title="Calme Spark S22 mobiles support 4.5 inches display">
#  <img alt="Calme Spark S22 Price in Pakistan" border="0" src="admin/images/Calme/SparkS22s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S22" style="text-decoration:none" title="Calme Spark S22 price">
#                  Calme<br/>Spark S22<br/></a>
#  <span class="PriceFont">
#                      Rs. 7,500                    </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S9" title="Calme Spark S9 mobiles support 4.0 inches display">
#  <img alt="Calme Spark S9 Price in Pakistan" border="0" src="admin/images/Calme/SparkS9s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S9" style="text-decoration:none" title="Calme Spark S9 price">
#                  Calme<br/>Spark S9<br/></a>
#  <span class="PriceFont">
#                      Rs. 7,000                    </span><br/>
#  </td></td></td></td></td>,
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S30" title="Calme Spark S30 mobiles support 5.0 inches display">
#  <img alt="Calme Spark S30 Price in Pakistan" border="0" src="admin/images/Calme/SparkS30s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S30" style="text-decoration:none" title="Calme Spark S30 price">
#                  Calme<br/>Spark S30<br/></a>
#  <span class="PriceFont">
#                      Rs. 7,999                    </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S8" title="Calme Spark S8 mobiles support 4.0 inches display">
#  <img alt="Calme Spark S8 Price in Pakistan" border="0" src="admin/images/Calme/SparkS8s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S8" style="text-decoration:none" title="Calme Spark S8 price">
#                  Calme<br/>Spark S8<br/></a>
#  <span class="PriceFont">
#                      Rs. 7,500                    </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S22" title="Calme Spark S22 mobiles support 4.5 inches display">
#  <img alt="Calme Spark S22 Price in Pakistan" border="0" src="admin/images/Calme/SparkS22s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S22" style="text-decoration:none" title="Calme Spark S22 price">
#                  Calme<br/>Spark S22<br/></a>
#  <span class="PriceFont">
#                      Rs. 7,500                    </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S9" title="Calme Spark S9 mobiles support 4.0 inches display">
#  <img alt="Calme Spark S9 Price in Pakistan" border="0" src="admin/images/Calme/SparkS9s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S9" style="text-decoration:none" title="Calme Spark S9 price">
#                  Calme<br/>Spark S9<br/></a>
#  <span class="PriceFont">
#                      Rs. 7,000                    </span><br/>
#  </td></td></td></td>,
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S8" title="Calme Spark S8 mobiles support 4.0 inches display">
#  <img alt="Calme Spark S8 Price in Pakistan" border="0" src="admin/images/Calme/SparkS8s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S8" style="text-decoration:none" title="Calme Spark S8 price">
#                  Calme<br/>Spark S8<br/></a>
#  <span class="PriceFont">
#                      Rs. 7,500                    </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S22" title="Calme Spark S22 mobiles support 4.5 inches display">
#  <img alt="Calme Spark S22 Price in Pakistan" border="0" src="admin/images/Calme/SparkS22s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S22" style="text-decoration:none" title="Calme Spark S22 price">
#                  Calme<br/>Spark S22<br/></a>
#  <span class="PriceFont">
#                      Rs. 7,500                    </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S9" title="Calme Spark S9 mobiles support 4.0 inches display">
#  <img alt="Calme Spark S9 Price in Pakistan" border="0" src="admin/images/Calme/SparkS9s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S9" style="text-decoration:none" title="Calme Spark S9 price">
#                  Calme<br/>Spark S9<br/></a>
#  <span class="PriceFont">
#                      Rs. 7,000                    </span><br/>
#  </td></td></td>,
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S22" title="Calme Spark S22 mobiles support 4.5 inches display">
#  <img alt="Calme Spark S22 Price in Pakistan" border="0" src="admin/images/Calme/SparkS22s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S22" style="text-decoration:none" title="Calme Spark S22 price">
#                  Calme<br/>Spark S22<br/></a>
#  <span class="PriceFont">
#                      Rs. 7,500                    </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S9" title="Calme Spark S9 mobiles support 4.0 inches display">
#  <img alt="Calme Spark S9 Price in Pakistan" border="0" src="admin/images/Calme/SparkS9s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S9" style="text-decoration:none" title="Calme Spark S9 price">
#                  Calme<br/>Spark S9<br/></a>
#  <span class="PriceFont">
#                      Rs. 7,000                    </span><br/>
#  </td></td>,
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S9" title="Calme Spark S9 mobiles support 4.0 inches display">
#  <img alt="Calme Spark S9 Price in Pakistan" border="0" src="admin/images/Calme/SparkS9s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S9" style="text-decoration:none" title="Calme Spark S9 price">
#                  Calme<br/>Spark S9<br/></a>
#  <span class="PriceFont">
#                      Rs. 7,000                    </span><br/>
#  </td>,
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S10" title="Calme Spark S10 mobiles support 4.5 inches display">
#  <img alt="Calme Spark S10 Price in Pakistan" border="0" src="admin/images/Calme/SparkS10s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S10" style="text-decoration:none" title="Calme Spark S10 price">
#                  Calme<br/>Spark S10<br/></a>
#  <span class="PriceFont">
#                      Rs. 5,990                    </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S25" title="Calme Spark S25 mobiles support 4.0 inches display 768 x 480 pixels
#  Smartphone Sensors: proximity sensor">
#  <img alt="Calme Spark S25 Price in Pakistan" border="0" src="admin/images/Calme/SparkS25s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S25" style="text-decoration:none" title="Calme Spark S25 price">
#                  Calme<br/>Spark S25<br/></a>
#  <span class="PriceFont">
#                      Rs. 4,800                    </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S24" title="Calme Spark S24 mobiles support 4.0 inches display">
#  <img alt="Calme Spark S24 Price in Pakistan" border="0" src="admin/images/Calme/SparkS24s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S24" style="text-decoration:none" title="Calme Spark S24 price">
#                  Calme<br/>Spark S24<br/></a>
#  <span class="PriceFont">
#                      Rs. 4,800                    </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S15" title="Calme Spark S15 mobiles support 4.0 inches display 768 x 480 pixels
#  Smartphone Sensors: proximity sensor">
#  <img alt="Calme Spark S15 Price in Pakistan" border="0" src="admin/images/Calme/SparkS15s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S15" style="text-decoration:none" title="Calme Spark S15 price">
#                  Calme<br/>Spark S15<br/></a>
#  <span class="PriceFont">
#                      Rs. 4,500                    </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S12" title="Calme Spark S12 mobiles support N/a">
#  <img alt="Calme Spark S12 Price in Pakistan" border="0" src="admin/images/Calme/SparkS12s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S12" style="text-decoration:none" title="Calme Spark S12 price">
#                  Calme<br/>Spark S12<br/></a>
#  <span class="PriceFont">
#                      Rs. 4,200                    </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S7" title="Calme Spark S7 mobiles support 3.5 inches display">
#  <img alt="Calme Spark S7 Price in Pakistan" border="0" src="admin/images/Calme/SparkS7s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S7" style="text-decoration:none" title="Calme Spark S7 price">
#                  Calme<br/>Spark S7<br/></a>
#  <span class="PriceFont">
#                      Rs. 4,000                    </span><br/>
#  </td></td></td></td></td></td>,
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S25" title="Calme Spark S25 mobiles support 4.0 inches display 768 x 480 pixels
#  Smartphone Sensors: proximity sensor">
#  <img alt="Calme Spark S25 Price in Pakistan" border="0" src="admin/images/Calme/SparkS25s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S25" style="text-decoration:none" title="Calme Spark S25 price">
#                  Calme<br/>Spark S25<br/></a>
#  <span class="PriceFont">
#                      Rs. 4,800                    </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S24" title="Calme Spark S24 mobiles support 4.0 inches display">
#  <img alt="Calme Spark S24 Price in Pakistan" border="0" src="admin/images/Calme/SparkS24s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S24" style="text-decoration:none" title="Calme Spark S24 price">
#                  Calme<br/>Spark S24<br/></a>
#  <span class="PriceFont">
#                      Rs. 4,800                    </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S15" title="Calme Spark S15 mobiles support 4.0 inches display 768 x 480 pixels
#  Smartphone Sensors: proximity sensor">
#  <img alt="Calme Spark S15 Price in Pakistan" border="0" src="admin/images/Calme/SparkS15s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S15" style="text-decoration:none" title="Calme Spark S15 price">
#                  Calme<br/>Spark S15<br/></a>
#  <span class="PriceFont">
#                      Rs. 4,500                    </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S12" title="Calme Spark S12 mobiles support N/a">
#  <img alt="Calme Spark S12 Price in Pakistan" border="0" src="admin/images/Calme/SparkS12s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S12" style="text-decoration:none" title="Calme Spark S12 price">
#                  Calme<br/>Spark S12<br/></a>
#  <span class="PriceFont">
#                      Rs. 4,200                    </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S7" title="Calme Spark S7 mobiles support 3.5 inches display">
#  <img alt="Calme Spark S7 Price in Pakistan" border="0" src="admin/images/Calme/SparkS7s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S7" style="text-decoration:none" title="Calme Spark S7 price">
#                  Calme<br/>Spark S7<br/></a>
#  <span class="PriceFont">
#                      Rs. 4,000                    </span><br/>
#  </td></td></td></td></td>,
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S24" title="Calme Spark S24 mobiles support 4.0 inches display">
#  <img alt="Calme Spark S24 Price in Pakistan" border="0" src="admin/images/Calme/SparkS24s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S24" style="text-decoration:none" title="Calme Spark S24 price">
#                  Calme<br/>Spark S24<br/></a>
#  <span class="PriceFont">
#                      Rs. 4,800                    </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S15" title="Calme Spark S15 mobiles support 4.0 inches display 768 x 480 pixels
#  Smartphone Sensors: proximity sensor">
#  <img alt="Calme Spark S15 Price in Pakistan" border="0" src="admin/images/Calme/SparkS15s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S15" style="text-decoration:none" title="Calme Spark S15 price">
#                  Calme<br/>Spark S15<br/></a>
#  <span class="PriceFont">
#                      Rs. 4,500                    </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S12" title="Calme Spark S12 mobiles support N/a">
#  <img alt="Calme Spark S12 Price in Pakistan" border="0" src="admin/images/Calme/SparkS12s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S12" style="text-decoration:none" title="Calme Spark S12 price">
#                  Calme<br/>Spark S12<br/></a>
#  <span class="PriceFont">
#                      Rs. 4,200                    </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S7" title="Calme Spark S7 mobiles support 3.5 inches display">
#  <img alt="Calme Spark S7 Price in Pakistan" border="0" src="admin/images/Calme/SparkS7s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S7" style="text-decoration:none" title="Calme Spark S7 price">
#                  Calme<br/>Spark S7<br/></a>
#  <span class="PriceFont">
#                      Rs. 4,000                    </span><br/>
#  </td></td></td></td>,
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S15" title="Calme Spark S15 mobiles support 4.0 inches display 768 x 480 pixels
#  Smartphone Sensors: proximity sensor">
#  <img alt="Calme Spark S15 Price in Pakistan" border="0" src="admin/images/Calme/SparkS15s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S15" style="text-decoration:none" title="Calme Spark S15 price">
#                  Calme<br/>Spark S15<br/></a>
#  <span class="PriceFont">
#                      Rs. 4,500                    </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S12" title="Calme Spark S12 mobiles support N/a">
#  <img alt="Calme Spark S12 Price in Pakistan" border="0" src="admin/images/Calme/SparkS12s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S12" style="text-decoration:none" title="Calme Spark S12 price">
#                  Calme<br/>Spark S12<br/></a>
#  <span class="PriceFont">
#                      Rs. 4,200                    </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S7" title="Calme Spark S7 mobiles support 3.5 inches display">
#  <img alt="Calme Spark S7 Price in Pakistan" border="0" src="admin/images/Calme/SparkS7s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S7" style="text-decoration:none" title="Calme Spark S7 price">
#                  Calme<br/>Spark S7<br/></a>
#  <span class="PriceFont">
#                      Rs. 4,000                    </span><br/>
#  </td></td></td>,
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S12" title="Calme Spark S12 mobiles support N/a">
#  <img alt="Calme Spark S12 Price in Pakistan" border="0" src="admin/images/Calme/SparkS12s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S12" style="text-decoration:none" title="Calme Spark S12 price">
#                  Calme<br/>Spark S12<br/></a>
#  <span class="PriceFont">
#                      Rs. 4,200                    </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S7" title="Calme Spark S7 mobiles support 3.5 inches display">
#  <img alt="Calme Spark S7 Price in Pakistan" border="0" src="admin/images/Calme/SparkS7s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S7" style="text-decoration:none" title="Calme Spark S7 price">
#                  Calme<br/>Spark S7<br/></a>
#  <span class="PriceFont">
#                      Rs. 4,000                    </span><br/>
#  </td></td>,
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S7" title="Calme Spark S7 mobiles support 3.5 inches display">
#  <img alt="Calme Spark S7 Price in Pakistan" border="0" src="admin/images/Calme/SparkS7s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S7" style="text-decoration:none" title="Calme Spark S7 price">
#                  Calme<br/>Spark S7<br/></a>
#  <span class="PriceFont">
#                      Rs. 4,000                    </span><br/>
#  </td>,
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_Spark-S11" title="Calme Spark S11 mobiles support 3.5 inches display">
#  <img alt="Calme Spark S11 Price in Pakistan" border="0" src="admin/images/Calme/SparkS11s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_Spark-S11" style="text-decoration:none" title="Calme Spark S11 price">
#                  Calme<br/>Spark S11<br/></a>
#  <span class="PriceFont">
#                      Rs. 4,000                    </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_C540" title="Calme C540 mobiles support 2.6 inches display">
#  <img alt="Calme C540 Price in Pakistan" border="0" src="admin/images/Calme/C540s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_C540" style="text-decoration:none" title="Calme C540 price">
#                  Calme<br/>C540<br/></a>
#  <span class="PriceFont">
#                       Price N/A                     </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_C660" title="Calme C660 mobiles support 2.8 inches display">
#  <img alt="Calme C660 Price in Pakistan" border="0" src="admin/images/Calme/C660s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_C660" style="text-decoration:none" title="Calme C660 price">
#                  Calme<br/>C660<br/></a>
#  <span class="PriceFont">
#                       Price N/A                     </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_C790" title="Calme C790 mobiles support 2.4 inches display">
#  <img alt="Calme C790 Price in Pakistan" border="0" src="admin/images/Calme/C790s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_C790" style="text-decoration:none" title="Calme C790 price">
#                  Calme<br/>C790<br/></a>
#  <span class="PriceFont">
#                       Price N/A                     </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_C880" title="Calme C880 mobiles support 2.4 inches display">
#  <img alt="Calme C880 Price in Pakistan" border="0" src="admin/images/Calme/C880s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_C880" style="text-decoration:none" title="Calme C880 price">
#                  Calme<br/>C880<br/></a>
#  <span class="PriceFont">
#                       Price N/A                     </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_C882" title="Calme C882 mobiles support 2.4 inches display">
#  <img alt="Calme C882 Price in Pakistan" border="0" src="admin/images/Calme/C882s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_C882" style="text-decoration:none" title="Calme C882 price">
#                  Calme<br/>C882<br/></a>
#  <span class="PriceFont">
#                       Price N/A                     </span><br/>
#  </td></td></td></td></td></td>,
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_C540" title="Calme C540 mobiles support 2.6 inches display">
#  <img alt="Calme C540 Price in Pakistan" border="0" src="admin/images/Calme/C540s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_C540" style="text-decoration:none" title="Calme C540 price">
#                  Calme<br/>C540<br/></a>
#  <span class="PriceFont">
#                       Price N/A                     </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_C660" title="Calme C660 mobiles support 2.8 inches display">
#  <img alt="Calme C660 Price in Pakistan" border="0" src="admin/images/Calme/C660s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_C660" style="text-decoration:none" title="Calme C660 price">
#                  Calme<br/>C660<br/></a>
#  <span class="PriceFont">
#                       Price N/A                     </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_C790" title="Calme C790 mobiles support 2.4 inches display">
#  <img alt="Calme C790 Price in Pakistan" border="0" src="admin/images/Calme/C790s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_C790" style="text-decoration:none" title="Calme C790 price">
#                  Calme<br/>C790<br/></a>
#  <span class="PriceFont">
#                       Price N/A                     </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_C880" title="Calme C880 mobiles support 2.4 inches display">
#  <img alt="Calme C880 Price in Pakistan" border="0" src="admin/images/Calme/C880s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_C880" style="text-decoration:none" title="Calme C880 price">
#                  Calme<br/>C880<br/></a>
#  <span class="PriceFont">
#                       Price N/A                     </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_C882" title="Calme C882 mobiles support 2.4 inches display">
#  <img alt="Calme C882 Price in Pakistan" border="0" src="admin/images/Calme/C882s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_C882" style="text-decoration:none" title="Calme C882 price">
#                  Calme<br/>C882<br/></a>
#  <span class="PriceFont">
#                       Price N/A                     </span><br/>
#  </td></td></td></td></td>,
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_C660" title="Calme C660 mobiles support 2.8 inches display">
#  <img alt="Calme C660 Price in Pakistan" border="0" src="admin/images/Calme/C660s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_C660" style="text-decoration:none" title="Calme C660 price">
#                  Calme<br/>C660<br/></a>
#  <span class="PriceFont">
#                       Price N/A                     </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_C790" title="Calme C790 mobiles support 2.4 inches display">
#  <img alt="Calme C790 Price in Pakistan" border="0" src="admin/images/Calme/C790s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_C790" style="text-decoration:none" title="Calme C790 price">
#                  Calme<br/>C790<br/></a>
#  <span class="PriceFont">
#                       Price N/A                     </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_C880" title="Calme C880 mobiles support 2.4 inches display">
#  <img alt="Calme C880 Price in Pakistan" border="0" src="admin/images/Calme/C880s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_C880" style="text-decoration:none" title="Calme C880 price">
#                  Calme<br/>C880<br/></a>
#  <span class="PriceFont">
#                       Price N/A                     </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_C882" title="Calme C882 mobiles support 2.4 inches display">
#  <img alt="Calme C882 Price in Pakistan" border="0" src="admin/images/Calme/C882s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_C882" style="text-decoration:none" title="Calme C882 price">
#                  Calme<br/>C882<br/></a>
#  <span class="PriceFont">
#                       Price N/A                     </span><br/>
#  </td></td></td></td>,
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_C790" title="Calme C790 mobiles support 2.4 inches display">
#  <img alt="Calme C790 Price in Pakistan" border="0" src="admin/images/Calme/C790s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_C790" style="text-decoration:none" title="Calme C790 price">
#                  Calme<br/>C790<br/></a>
#  <span class="PriceFont">
#                       Price N/A                     </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_C880" title="Calme C880 mobiles support 2.4 inches display">
#  <img alt="Calme C880 Price in Pakistan" border="0" src="admin/images/Calme/C880s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_C880" style="text-decoration:none" title="Calme C880 price">
#                  Calme<br/>C880<br/></a>
#  <span class="PriceFont">
#                       Price N/A                     </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_C882" title="Calme C882 mobiles support 2.4 inches display">
#  <img alt="Calme C882 Price in Pakistan" border="0" src="admin/images/Calme/C882s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_C882" style="text-decoration:none" title="Calme C882 price">
#                  Calme<br/>C882<br/></a>
#  <span class="PriceFont">
#                       Price N/A                     </span><br/>
#  </td></td></td>,
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_C880" title="Calme C880 mobiles support 2.4 inches display">
#  <img alt="Calme C880 Price in Pakistan" border="0" src="admin/images/Calme/C880s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_C880" style="text-decoration:none" title="Calme C880 price">
#                  Calme<br/>C880<br/></a>
#  <span class="PriceFont">
#                       Price N/A                     </span><br/>
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_C882" title="Calme C882 mobiles support 2.4 inches display">
#  <img alt="Calme C882 Price in Pakistan" border="0" src="admin/images/Calme/C882s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_C882" style="text-decoration:none" title="Calme C882 price">
#                  Calme<br/>C882<br/></a>
#  <span class="PriceFont">
#                       Price N/A                     </span><br/>
#  </td></td>,
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_C882" title="Calme C882 mobiles support 2.4 inches display">
#  <img alt="Calme C882 Price in Pakistan" border="0" src="admin/images/Calme/C882s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_C882" style="text-decoration:none" title="Calme C882 price">
#                  Calme<br/>C882<br/></a>
#  <span class="PriceFont">
#                       Price N/A                     </span><br/>
#  </td>,
#  <td align="center" class="BiggerText" height="51" width="668">
#  <a href="/Calme_C340" title="Calme C340 mobiles support 2.4 inches display">
#  <img alt="Calme C340 Price in Pakistan" border="0" src="admin/images/Calme/C340s.jpg"/></a><br/>
#  <a class="BiggerText" href="/Calme_C340" style="text-decoration:none" title="Calme C340 price">
#                  Calme<br/>C340<br/></a>
#  <span class="PriceFont">
#                       Price N/A                     </span><br/>
#  </td>]

# %%
for i in td:
    brand_uri = url + i.find('a')['href']
    brand_uri_list.append(brand_uri)

# %%
brand_uri_list
# Out:
# ['https://www.whatmobile.com.pk//Calme_Spark-S33',
#  'https://www.whatmobile.com.pk//Calme_Spark-S20',
#  'https://www.whatmobile.com.pk//Calme_Spark-S30',
#  'https://www.whatmobile.com.pk//Calme_Spark-S8',
#  'https://www.whatmobile.com.pk//Calme_Spark-S22',
#  'https://www.whatmobile.com.pk//Calme_Spark-S9',
#  'https://www.whatmobile.com.pk//Calme_Spark-S10',
#  'https://www.whatmobile.com.pk//Calme_Spark-S25',
#  'https://www.whatmobile.com.pk//Calme_Spark-S24',
#  'https://www.whatmobile.com.pk//Calme_Spark-S15',
#  'https://www.whatmobile.com.pk//Calme_Spark-S12',
#  'https://www.whatmobile.com.pk//Calme_Spark-S7',
#  'https://www.whatmobile.com.pk//Calme_Spark-S11',
#  'https://www.whatmobile.com.pk//Calme_C540',
#  'https://www.whatmobile.com.pk//Calme_C660',
#  'https://www.whatmobile.com.pk//Calme_C790',
#  'https://www.whatmobile.com.pk//Calme_C880',
#  'https://www.whatmobile.com.pk//Calme_C882',
#  'https://www.whatmobile.com.pk//Calme_C340',
#  'https://www.whatmobile.com.pk//Calme_Spark-S33',
#  'https://www.whatmobile.com.pk//Calme_Spark-S20',
#  'https://www.whatmobile.com.pk//Calme_Spark-S30',
#  'https://www.whatmobile.com.pk//Calme_Spark-S8',
#  'https://www.whatmobile.com.pk//Calme_Spark-S22',
#  'https://www.whatmobile.com.pk//Calme_Spark-S9',
#  'https://www.whatmobile.com.pk//Calme_Spark-S10',
#  'https://www.whatmobile.com.pk//Calme_Spark-S25',
#  'https://www.whatmobile.com.pk//Calme_Spark-S24',
#  'https://www.whatmobile.com.pk//Calme_Spark-S15',
#  'https://www.whatmobile.com.pk//Calme_Spark-S12',
#  'https://www.whatmobile.com.pk//Calme_Spark-S7',
#  'https://www.whatmobile.com.pk//Calme_Spark-S11',
#  'https://www.whatmobile.com.pk//Calme_C540',
#  'https://www.whatmobile.com.pk//Calme_C660',
#  'https://www.whatmobile.com.pk//Calme_C790',
#  'https://www.whatmobile.com.pk//Calme_C880',
#  'https://www.whatmobile.com.pk//Calme_C882',
#  'https://www.whatmobile.com.pk//Calme_C340']

# %%
len(brand_uri_list)
# Out:
# 38

# %%
table = html_parse(brand_uri_list[0]).find('table', {'class': 'specs'})

# %%
table
# Out:
# <table border="0" cellpadding="0" cellspacing="0" class="specs" width="604">
# <tbody>
# <!--Main Category-->
# <tr class="RowBG2">
# <td class="hdngArial specs-mainHeading bottom-border-section" rowspan="4" style="text-align: left;vertical-align: top;">Build</td>
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">OS</th>
# <td class="fasla RowBG1 specs-value bottom-border" colspan="2">Android 4.2 (Jelly Bean)                                                     </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Dimensions</th>
# <td class="fasla specs-value bottom-border" colspan="2">
#                                                 N/a                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Weight</th>
# <td class="fasla specs-value bottom-border" colspan="2">
#                                                 N/a                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border-section">Colors</th>
# <td class="fasla specs-value bottom-border-section" colspan="2">
#                                                 Black, White                                                 </td>
# </tr>
# <!--Main Category-->
# <tr class="RowBG2">
# <td class="hdngArial specs-mainHeading bottom-border-section" rowspan="2" style="text-align: left;vertical-align: top;">Frequency</td>
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">2G Band</th>
# <td class="fasla RowBG1 specs-value bottom-border" colspan="2">GSM: 900 / 1800                                                     </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border-section">3G Band</th>
# <td class="fasla specs-value bottom-border-section" colspan="2">
#                                                 WCDMA / 2100                                                 </td>
# </tr>
# <!--Main Category-->
# <tr class="RowBG2">
# <td class="hdngArial specs-mainHeading bottom-border-section" rowspan="1" style="text-align: left;vertical-align: top;">Processor</td>
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border-section">CPU</th>
# <td class="fasla RowBG1 specs-value bottom-border-section" colspan="2"><b>1.2 GHZ Dual-Core</b>                                                     </td>
# </tr>
# <!--Main Category-->
# <tr class="RowBG2">
# <td class="hdngArial specs-mainHeading bottom-border-section" rowspan="2" style="text-align: left;vertical-align: top;">Display</td>
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Technology</th>
# <td class="fasla RowBG1 specs-value bottom-border" colspan="2"><b>FWVGA Screen</b>                                                     </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border-section">Size</th>
# <td class="fasla specs-value bottom-border-section" colspan="2">
#                                                 5.0 inches                                                 </td>
# </tr>
# <!--Main Category-->
# <tr class="RowBG2">
# <td class="hdngArial specs-mainHeading bottom-border-section" rowspan="2" style="text-align: left;vertical-align: top;">Memory</td>
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Built-in</th>
# <td class="fasla RowBG1 specs-value bottom-border" colspan="2"><b>4GB</b> built-in <b>512MB</b> RAM + <b>4GB Free </b>                                                      </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border-section">Card</th>
# <td class="fasla specs-value bottom-border-section" colspan="2">
# <b>4GB Free microSD Card</b> (supports up 64GB)                                                 </td>
# </tr>
# <!--Main Category-->
# <tr class="RowBG2">
# <td class="hdngArial specs-mainHeading bottom-border-section" rowspan="3" style="text-align: left;vertical-align: top;">Camera</td>
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Main</th>
# <td class="fasla RowBG1 specs-value bottom-border" colspan="2">3.0 MP, autofocus, Flash Light                                                     </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Features</th>
# <td class="fasla specs-value bottom-border" colspan="2">
#                                                 Video                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border-section">Front</th>
# <td class="fasla specs-value bottom-border-section" colspan="2">
#                                                 1.3 MP                                                 </td>
# </tr>
# <!--Main Category-->
# <tr class="RowBG2">
# <td class="hdngArial specs-mainHeading bottom-border-section" rowspan="7" style="text-align: left;vertical-align: top;">Connectivity</td>
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">WLAN</th>
# <td class="fasla RowBG1 specs-value bottom-border" colspan="2">Wi-Fi 802.11                                                     </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Bluetooth</th>
# <td class="fasla specs-value bottom-border" colspan="2">
#                                                 v3.0                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">GPS</th>
# <td class="fasla specs-value bottom-border" colspan="2">
#                                                 Yes                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Radio</th>
# <td class="fasla specs-value bottom-border" colspan="2">
#                                                 No                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">USB</th>
# <td class="fasla specs-value bottom-border" colspan="2">
#                                                 Yes                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">NFC</th>
# <td class="fasla specs-value bottom-border" colspan="2">
#                                                 No                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border-section">Data</th>
# <td class="fasla specs-value bottom-border-section" colspan="2">
# <font color="#000077"><b>GPRS</b></font>, <font color="#000077"><b>EDGE</b></font>, 3G                                                 </td>
# </tr>
# <!--Main Category-->
# <tr class="RowBG2">
# <td class="hdngArial specs-mainHeading bottom-border-section" rowspan="6" style="text-align: left;vertical-align: top;">Features</td>
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Audio</th>
# <td class="fasla RowBG1 specs-value bottom-border" colspan="2">3.5mm audio jack, Speakerphone                                                     </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Browser</th>
# <td class="fasla specs-value bottom-border" colspan="2">
#                                                 HTML5                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Messaging</th>
# <td class="fasla specs-value bottom-border" colspan="2">
#                                                 SMS, MMS, email                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Games</th>
# <td class="fasla specs-value bottom-border" colspan="2">
#                                                 built-in + downloadable                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Torch</th>
# <td class="fasla specs-value bottom-border" colspan="2">
#                                                 Yes                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border-section">Extra</th>
# <td class="fasla specs-value bottom-border-section" colspan="2">
#                                                 Google Search, Maps, Gmail, Facebook, Skype, Youtube, Twitter, Yahoo, * 3D Cambered surface Design, Speakerphone                                                 </td>
# </tr>
# <!--Main Category-->
# <tr class="RowBG2">
# <td class="hdngArial specs-mainHeading bottom-border-section" rowspan="1" style="text-align: left;vertical-align: top;">Battery</td>
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border-section">Capacity</th>
# <td class="fasla RowBG1 specs-value bottom-border-section" colspan="2">1950 mAh                                                     </td>
# </tr>
# </tbody>
# </table>

# %%
div_price = html_parse(brand_uri_list[0]).find('div', {'class': 'hdng3'})

# %%
div_price
# Out:
# <div class="hdng3" colspan="2" style="text-align:left; clear:both;">
# <span class="hdng"><g:plusone></g:plusone></span><br/>
# <span class="hdng">
#     Rs. 8,300            <br/>USD $62    </span></div>

# %%
price_text = div_price.text.replace(' ','').replace(',','').strip()
index_of_usd = price_text.index('U')
str_to_lst = list(price_text)
a = str_to_lst.insert(int(index_of_usd),',')
lst_to_str = ''.join(str_to_lst).split(',')

# %%
price_text
# Out:
# 'Rs.8300USD$62'

# %%
lst_to_str

# %%
 #Splitting dollars and rupees in seperate var
price_rs = lst_to_str[0].replace('Rs.','')
price_usd = lst_to_str[1].replace('USD$', '')

print(price_rs)
print(price_usd)
# Out:
# 8300
# 62

# %%
tr = table.find_all('tr')
tr
# Out:
# [<tr class="RowBG2">
#  <td class="hdngArial specs-mainHeading bottom-border-section" rowspan="4" style="text-align: left;vertical-align: top;">Build</td>
#  <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">OS</th>
#  <td class="fasla RowBG1 specs-value bottom-border" colspan="2">Android 4.2 (Jelly Bean)                                                     </td>
#  </tr>, <tr class="RowBG1">
#  <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Dimensions</th>
#  <td class="fasla specs-value bottom-border" colspan="2">
#                                                  N/a                                                 </td>
#  </tr>, <tr class="RowBG1">
#  <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Weight</th>
#  <td class="fasla specs-value bottom-border" colspan="2">
#                                                  N/a                                                 </td>
#  </tr>, <tr class="RowBG1">
#  <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border-section">Colors</th>
#  <td class="fasla specs-value bottom-border-section" colspan="2">
#                                                  Black, White                                                 </td>
#  </tr>, <tr class="RowBG2">
#  <td class="hdngArial specs-mainHeading bottom-border-section" rowspan="2" style="text-align: left;vertical-align: top;">Frequency</td>
#  <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">2G Band</th>
#  <td class="fasla RowBG1 specs-value bottom-border" colspan="2">GSM: 900 / 1800                                                     </td>
#  </tr>, <tr class="RowBG1">
#  <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border-section">3G Band</th>
#  <td class="fasla specs-value bottom-border-section" colspan="2">
#                                                  WCDMA / 2100                                                 </td>
#  </tr>, <tr class="RowBG2">
#  <td class="hdngArial specs-mainHeading bottom-border-section" rowspan="1" style="text-align: left;vertical-align: top;">Processor</td>
#  <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border-section">CPU</th>
#  <td class="fasla RowBG1 specs-value bottom-border-section" colspan="2"><b>1.2 GHZ Dual-Core</b>                                                     </td>
#  </tr>, <tr class="RowBG2">
#  <td class="hdngArial specs-mainHeading bottom-border-section" rowspan="2" style="text-align: left;vertical-align: top;">Display</td>
#  <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Technology</th>
#  <td class="fasla RowBG1 specs-value bottom-border" colspan="2"><b>FWVGA Screen</b>                                                     </td>
#  </tr>, <tr class="RowBG1">
#  <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border-section">Size</th>
#  <td class="fasla specs-value bottom-border-section" colspan="2">
#                                                  5.0 inches                                                 </td>
#  </tr>, <tr class="RowBG2">
#  <td class="hdngArial specs-mainHeading bottom-border-section" rowspan="2" style="text-align: left;vertical-align: top;">Memory</td>
#  <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Built-in</th>
#  <td class="fasla RowBG1 specs-value bottom-border" colspan="2"><b>4GB</b> built-in <b>512MB</b> RAM + <b>4GB Free </b>                                                      </td>
#  </tr>, <tr class="RowBG1">
#  <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border-section">Card</th>
#  <td class="fasla specs-value bottom-border-section" colspan="2">
#  <b>4GB Free microSD Card</b> (supports up 64GB)                                                 </td>
#  </tr>, <tr class="RowBG2">
#  <td class="hdngArial specs-mainHeading bottom-border-section" rowspan="3" style="text-align: left;vertical-align: top;">Camera</td>
#  <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Main</th>
#  <td class="fasla RowBG1 specs-value bottom-border" colspan="2">3.0 MP, autofocus, Flash Light                                                     </td>
#  </tr>, <tr class="RowBG1">
#  <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Features</th>
#  <td class="fasla specs-value bottom-border" colspan="2">
#                                                  Video                                                 </td>
#  </tr>, <tr class="RowBG1">
#  <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border-section">Front</th>
#  <td class="fasla specs-value bottom-border-section" colspan="2">
#                                                  1.3 MP                                                 </td>
#  </tr>, <tr class="RowBG2">
#  <td class="hdngArial specs-mainHeading bottom-border-section" rowspan="7" style="text-align: left;vertical-align: top;">Connectivity</td>
#  <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">WLAN</th>
#  <td class="fasla RowBG1 specs-value bottom-border" colspan="2">Wi-Fi 802.11                                                     </td>
#  </tr>, <tr class="RowBG1">
#  <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Bluetooth</th>
#  <td class="fasla specs-value bottom-border" colspan="2">
#                                                  v3.0                                                 </td>
#  </tr>, <tr class="RowBG1">
#  <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">GPS</th>
#  <td class="fasla specs-value bottom-border" colspan="2">
#                                                  Yes                                                 </td>
#  </tr>, <tr class="RowBG1">
#  <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Radio</th>
#  <td class="fasla specs-value bottom-border" colspan="2">
#                                                  No                                                 </td>
#  </tr>, <tr class="RowBG1">
#  <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">USB</th>
#  <td class="fasla specs-value bottom-border" colspan="2">
#                                                  Yes                                                 </td>
#  </tr>, <tr class="RowBG1">
#  <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">NFC</th>
#  <td class="fasla specs-value bottom-border" colspan="2">
#                                                  No                                                 </td>
#  </tr>, <tr class="RowBG1">
#  <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border-section">Data</th>
#  <td class="fasla specs-value bottom-border-section" colspan="2">
#  <font color="#000077"><b>GPRS</b></font>, <font color="#000077"><b>EDGE</b></font>, 3G                                                 </td>
#  </tr>, <tr class="RowBG2">
#  <td class="hdngArial specs-mainHeading bottom-border-section" rowspan="6" style="text-align: left;vertical-align: top;">Features</td>
#  <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Audio</th>
#  <td class="fasla RowBG1 specs-value bottom-border" colspan="2">3.5mm audio jack, Speakerphone                                                     </td>
#  </tr>, <tr class="RowBG1">
#  <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Browser</th>
#  <td class="fasla specs-value bottom-border" colspan="2">
#                                                  HTML5                                                 </td>
#  </tr>, <tr class="RowBG1">
#  <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Messaging</th>
#  <td class="fasla specs-value bottom-border" colspan="2">
#                                                  SMS, MMS, email                                                 </td>
#  </tr>, <tr class="RowBG1">
#  <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Games</th>
#  <td class="fasla specs-value bottom-border" colspan="2">
#                                                  built-in + downloadable                                                 </td>
#  </tr>, <tr class="RowBG1">
#  <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Torch</th>
#  <td class="fasla specs-value bottom-border" colspan="2">
#                                                  Yes                                                 </td>
#  </tr>, <tr class="RowBG1">
#  <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border-section">Extra</th>
#  <td class="fasla specs-value bottom-border-section" colspan="2">
#                                                  Google Search, Maps, Gmail, Facebook, Skype, Youtube, Twitter, Yahoo, * 3D Cambered surface Design, Speakerphone                                                 </td>
#  </tr>, <tr class="RowBG2">
#  <td class="hdngArial specs-mainHeading bottom-border-section" rowspan="1" style="text-align: left;vertical-align: top;">Battery</td>
#  <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border-section">Capacity</th>
#  <td class="fasla RowBG1 specs-value bottom-border-section" colspan="2">1950 mAh                                                     </td>
#  </tr>]

# %%
for j in tr:
    th = j.select('th')
    td = j.select('th+td')
    for k, brand_specs_list in zip(th, td):
        spec = k.text.strip()
        value = brand_specs_list.text.strip()
        brands_specs_dict[spec] = value

mobile = brand_uri_list[0].split('//')
brands_specs_dict['Brand'] = brand_selection
brands_specs_dict['Mobile'] = mobile[2]
brands_specs_dict['Price_RS'] = price_rs
brands_specs_dict['Price_USD'] = price_usd
brands_mobile_list.append(brands_specs_dict.copy())


print(mobile)
brands_mobile_list
# Out:
# ['https:', 'www.whatmobile.com.pk', 'Calme_Spark-S33']
# [{'OS': 'Android 4.2 (Jelly Bean)',
#   'Dimensions': 'N/a',
#   'Weight': 'N/a',
#   'Colors': 'Black, White',
#   '2G Band': 'GSM: 900 / 1800',
#   '3G Band': 'WCDMA / 2100',
#   'CPU': '1.2 GHZ Dual-Core',
#   'Technology': 'FWVGA Screen',
#   'Size': '5.0 inches',
#   'Built-in': '4GB built-in 512MB RAM + 4GB Free',
#   'Card': '4GB Free microSD Card (supports up 64GB)',
#   'Main': '3.0 MP, autofocus, Flash Light',
#   'Features': 'Video',
#   'Front': '1.3 MP',
#   'WLAN': 'Wi-Fi 802.11',
#   'Bluetooth': 'v3.0',
#   'GPS': 'Yes',
#   'Radio': 'No',
#   'USB': 'Yes',
#   'NFC': 'No',
#   'Data': 'GPRS, EDGE, 3G',
#   'Audio': '3.5mm audio jack, Speakerphone',
#   'Browser': 'HTML5',
#   'Messaging': 'SMS, MMS, email',
#   'Games': 'built-in + downloadable',
#   'Torch': 'Yes',
#   'Extra': 'Google Search, Maps, Gmail, Facebook, Skype, Youtube, Twitter, Yahoo, * 3D Cambered surface Design, Speakerphone',
#   'Capacity': '1950 mAh',
#   'Brand': 'Calme',
#   'Mobile': 'Calme_Spark-S33',
#   'Price_RS': '8300',
#   'Price_USD': '62'},
#  {'OS': 'Android 4.2.2 (Jelly Bean)',
#   'Dimensions': '139.9 x 69.9 x 65.3 x 9.1mm',
#   'Weight': 'N/a',
#   'Colors': 'Black, White, RED',
#   '2G Band': 'GSM: 900 / 1800',
#   '3G Band': 'WCDMA',
#   'CPU': '1.5 GHZ Quad-Core',
#   'Technology': 'QHD Screen With OGS, Multitouch',
#   'Size': '4.7 inches',
#   'Built-in': '4GB built-in 1GB RAM',
#   'Card': 'microSD Card (supports up 64GB)',
#   'Main': '8 MP, Flash Light',
#   'Features': 'Video',
#   'Front': '3 MP',
#   'WLAN': 'Wi-Fi 802.11',
#   'Bluetooth': 'v3.0',
#   'GPS': 'Yes',
#   'Radio': 'No',
#   'USB': 'Yes',
#   'NFC': 'No',
#   'Data': 'GPRS, EDGE, 3G',
#   'Audio': '3.5mm audio jack, Speakerphone',
#   'Browser': 'HTML5',
#   'Messaging': 'SMS, MMS, email',
#   'Games': 'built-in + downloadable',
#   'Torch': 'Yes',
#   'Extra': 'Google Search, Maps, Gmail, Facebook, Skype, Youtube, Twitter, Yahoo, * 3D Cambered surface Design, Speakerphone',
#   'Capacity': '1800 mAh',
#   'Brand': 'Calme',
#   'Mobile': 'Calme_Spark-S20',
#   'Price_RS': '8000',
#   'Price_USD': '60'},
#  {'OS': 'Android 4.2.2 (Jelly Bean)',
#   'Dimensions': '144 x 71 x 8.7mm',
#   'Weight': 'N/a',
#   'Colors': 'Black, White',
#   '2G Band': 'GSM: 900 / 1800',
#   '3G Band': 'WCDMA',
#   'CPU': '1.5 GHZ Quad-Core',
#   'Technology': 'QHD Screen With OGS, Multitouch',
#   'Size': '5.0 inches',
#   'Built-in': '4GB built-in 1GB RAM',
#   'Card': 'microSD Card (supports up 64GB)',
#   'Main': '8 MP, autofocus, Flash Light',
#   'Features': 'Video',
#   'Front': '3 MP',
#   'WLAN': 'Wi-Fi 802.11',
#   'Bluetooth': 'v3.0',
#   'GPS': 'Yes',
#   'Radio': 'No',
#   'USB': 'Yes',
#   'NFC': 'No',
#   'Data': 'GPRS, EDGE, 3G',
#   'Audio': '3.5mm audio jack, Speakerphone',
#   'Browser': 'HTML5',
#   'Messaging': 'SMS, MMS, email',
#   'Games': 'built-in + downloadable',
#   'Torch': 'Yes',
#   'Extra': 'Google Search, Maps, Gmail, Facebook, Skype, Youtube, Twitter, Yahoo, * 3D Cambered surface Design, Speakerphone',
#   'Capacity': '1900 mAh',
#   'Brand': 'Calme',
#   'Mobile': 'Calme_Spark-S30',
#   'Price_RS': '7999',
#   'Price_USD': '60'},
#  {'OS': 'Android 4.2.2 (Jelly Bean)',
#   'Dimensions': '125 x 64.2 x 9.2mm',
#   'Weight': 'N/a',
#   'Colors': 'Black, White',
#   '2G Band': 'GSM: 900 / 1800',
#   '3G Band': 'WCDMA',
#   'CPU': '1.2GHZ Dual-Core',
#   'Technology': 'IPS WVGA Screen',
#   'Size': '4.0 inches',
#   'Built-in': '4GB built-in 512MB RAM',
#   'Card': 'microSD Card (supports up 64GB)',
#   'Main': '5.0 MP, autofocus, LED Flash',
#   'Features': 'Video',
#   'Front': 'No',
#   'WLAN': 'Wi-Fi 802.11',
#   'Bluetooth': 'Yes',
#   'GPS': 'Yes',
#   'Radio': 'No',
#   'USB': 'Yes',
#   'NFC': 'No',
#   'Data': 'GPRS, EDGE',
#   'Audio': '3.5mm audio jack, Speakerphone',
#   'Browser': 'HTML5',
#   'Messaging': 'SMS, MMS, email',
#   'Games': 'built-in + downloadable',
#   'Torch': 'Yes',
#   'Extra': 'Google Search, Maps, Gmail, * Facebook, Skype, Youtube, Speakerphone',
#   'Capacity': '1470 mAh',
#   'Brand': 'Calme',
#   'Mobile': 'Calme_Spark-S8',
#   'Price_RS': '7500',
#   'Price_USD': '56'},
#  {'OS': 'Android 4.2 (Jelly Bean)',
#   'Dimensions': 'N/a',
#   'Weight': 'N/a',
#   'Colors': 'Black, White',
#   '2G Band': 'GSM: 900 / 1800',
#   '3G Band': 'WCDMA / 2100',
#   'CPU': '1.2GHZ Dual-Core',
#   'Technology': 'FWVGA Screen',
#   'Size': '4.5 inches',
#   'Built-in': '4GB built-in 512MB RAM + 4GB Free',
#   'Card': '4GB Free microSD Card (supports up 64GB)',
#   'Main': '3.0 MP, autofocus, Flash Light',
#   'Features': 'Video',
#   'Front': '1.3 MP',
#   'WLAN': 'Wi-Fi 802.11',
#   'Bluetooth': 'v3.0',
#   'GPS': 'Yes',
#   'Radio': 'No',
#   'USB': 'Yes',
#   'NFC': 'No',
#   'Data': 'GPRS, EDGE, 3G',
#   'Audio': '3.5mm audio jack, Speakerphone',
#   'Browser': 'HTML5',
#   'Messaging': 'SMS, MMS, email',
#   'Games': 'built-in + downloadable',
#   'Torch': 'Yes',
#   'Extra': 'Google Search, Maps, Gmail, Facebook, Skype, Youtube, Twitter, Yahoo, * 3D Cambered surface Design, Speakerphone',
#   'Capacity': '1750mAh',
#   'Brand': 'Calme',
#   'Mobile': 'Calme_Spark-S22',
#   'Price_RS': '7500',
#   'Price_USD': '56'},
#  {'OS': 'Android 4.2.2 (Jelly Bean)',
#   'Dimensions': '125 x 64.2 x 9.0mm',
#   'Weight': 'N/a',
#   'Colors': 'Black, White, Coffee',
#   '2G Band': 'GSM: 900 / 1800',
#   '3G Band': 'WCDMA / 2100',
#   'CPU': '1.2GHZ Dual-Core',
#   'Technology': 'IPS WVGA Screen',
#   'Size': '4.0 inches',
#   'Built-in': '4GB built-in 512MB RAM',
#   'Card': 'microSD Card (supports up 64GB)',
#   'Main': '5.0 MP, autofocus, LED Flash',
#   'Features': 'Video',
#   'Front': 'VGA camera',
#   'WLAN': 'Wi-Fi 802.11',
#   'Bluetooth': 'v3.0',
#   'GPS': 'Yes',
#   'Radio': 'No',
#   'USB': 'Yes',
#   'NFC': 'No',
#   'Data': 'GPRS, EDGE',
#   'Audio': '3.5mm audio jack, Speakerphone',
#   'Browser': 'HTML5',
#   'Messaging': 'SMS, MMS, email',
#   'Games': 'built-in + downloadable',
#   'Torch': 'Yes',
#   'Extra': 'Google Search, Maps, Gmail, * Facebook, Skype, Youtube, Speakerphone',
#   'Capacity': '1470mAh',
#   'Brand': 'Calme',
#   'Mobile': 'Calme_Spark-S9',
#   'Price_RS': '7000',
#   'Price_USD': '52'},
#  {'OS': 'Android 4.2.2 (Jelly Bean)',
#   'Dimensions': '133 x 65.3 x 9.0mm',
#   'Weight': 'N/a',
#   'Colors': 'Black',
#   '2G Band': 'GSM: 900 / 1800',
#   '3G Band': 'WCDMA',
#   'CPU': '1.2GHZ Quad-Core',
#   'Technology': 'IPS QHD Screen With OGS',
#   'Size': '4.5 inches',
#   'Built-in': '4GB built-in 1GB RAM',
#   'Card': 'microSD Card (supports up 64GB)',
#   'Main': '8.0 MP, autofocus, LED Flash',
#   'Features': 'Panorama, Video',
#   'Front': '2 MP',
#   'WLAN': 'Wi-Fi 802.11',
#   'Bluetooth': 'v3.0',
#   'GPS': 'Yes',
#   'Radio': 'No',
#   'USB': 'Yes',
#   'NFC': 'No',
#   'Data': 'GPRS, EDGE, 3G',
#   'Audio': '3.5mm audio jack, Speakerphone',
#   'Browser': 'HTML5',
#   'Messaging': 'SMS, MMS, email',
#   'Games': 'built-in + downloadable',
#   'Torch': 'Yes',
#   'Extra': 'Google Search, Maps, Gmail, Facebook, Skype, Youtube, Twitter, Google Talk, Speakerphone',
#   'Capacity': '1670 mAh',
#   'Brand': 'Calme',
#   'Mobile': 'Calme_Spark-S10',
#   'Price_RS': '5990',
#   'Price_USD': '45'},
#  {'OS': 'Android 4.4.2( Kit Kat)',
#   'Dimensions': '125.9 x 65.4 x 11.2 mm',
#   'Weight': 'N/a',
#   'Colors': 'white, Black, Golden',
#   '2G Band': 'SIM1 850/ 900 / 1800 / 1900\nSIM2 850/ 900 / 1800 / 1900',
#   '3G Band': 'WCDMA 850 / 2100',
#   'CPU': '1.5 GHz Dual core',
#   'Technology': 'IPS WVGA Touch Display',
#   'Size': '4.0 inches',
#   'Built-in': '4GB built-in 512MB RAM',
#   'Card': 'microSD Card (supports up to 32GB)',
#   'Main': '3 MP, Auto Focus, LED Flash',
#   'Features': 'Video',
#   'Front': '1.0 MP Camera',
#   'WLAN': 'Wi-Fi 802.11',
#   'Bluetooth': 'Yes',
#   'GPS': 'Yes',
#   'Radio': 'FM Radio',
#   'USB': 'microUSB',
#   'NFC': 'No',
#   'Data': 'GPRS, EDGE, 3G',
#   'Audio': '3.5mm audio jack, Speakerphone',
#   'Browser': 'HTML5',
#   'Messaging': 'SMS, MMS, email',
#   'Games': 'Built-in + downloadable',
#   'Torch': 'Yes',
#   'Extra': 'Maps, Gmail, Facebook, Skype, Youtube, Twitter, Yahoo, * 3D Cambered surface Design, Video player, audio player, Google Android Market',
#   'Capacity': '1500 mAh',
#   'Brand': 'Calme',
#   'Mobile': 'Calme_Spark-S25',
#   'Price_RS': '4800',
#   'Price_USD': '36',
#   'SIM': 'Dual-SIM',
#   'Resolution': '768 x 480 pixels',
#   'Sensors': 'proximity sensor'},
#  {'OS': 'Android 4.4 (Kit Kat)',
#   'Dimensions': '127.4 x 63.8 x 9.1 mm',
#   'Weight': 'N/a',
#   'Colors': 'Black, White',
#   '2G Band': 'GSM: 900 / 1800 / 2100',
#   '3G Band': 'WCDMA',
#   'CPU': '1.5GHZ Dual-Core',
#   'Technology': 'IPS WVGA Touch Display',
#   'Size': '4.0 Inches',
#   'Built-in': '4GB built-in, 512MB RAM',
#   'Card': 'microSD Card (supports up 64GB)',
#   'Main': '5 MP, autofocus, Flash Light',
#   'Features': 'Video',
#   'Front': '1.3 MP Camera',
#   'WLAN': 'Wi-Fi 802.11',
#   'Bluetooth': 'v3.0',
#   'GPS': 'Yes',
#   'Radio': 'No',
#   'USB': 'Yes',
#   'NFC': 'No',
#   'Data': 'GPRS, EDGE, 3G',
#   'Audio': '3.5mm audio jack, Speakerphone',
#   'Browser': 'HTML5',
#   'Messaging': 'SMS, MMS, email',
#   'Games': 'built-in + downloadable',
#   'Torch': 'Yes',
#   'Extra': 'Google Search, Maps, Gmail, Facebook, Skype, Youtube, Twitter, Yahoo, Speakerphone',
#   'Capacity': '1400 mAh',
#   'Brand': 'Calme',
#   'Mobile': 'Calme_Spark-S24',
#   'Price_RS': '4800',
#   'Price_USD': '36',
#   'SIM': 'Dual-SIM',
#   'Resolution': '768 x 480 pixels',
#   'Sensors': 'proximity sensor'},
#  {'OS': 'Android 4.4.2( Kit Kat)',
#   'Dimensions': 'N/a',
#   'Weight': 'N/a',
#   'Colors': 'white, Black, Golden',
#   '2G Band': 'SIM1 850/ 900 / 1800 / 1900\nSIM2 850/ 900 / 1800 / 1900',
#   '3G Band': 'WCDMA 850 / 2100',
#   'CPU': '1.5 GHz Dual-Core',
#   'Technology': 'WVGA Display',
#   'Size': '4.0 inches',
#   'Built-in': '4GB built-in 512MB RAM',
#   'Card': 'microSD card (supports up to 32GB)',
#   'Main': '3.0 MP, Auto Focus, LED Flash',
#   'Features': 'Video',
#   'Front': '1.0 MP Camera',
#   'WLAN': 'Wi-Fi 802.11',
#   'Bluetooth': 'Yes',
#   'GPS': 'Yes',
#   'Radio': 'FM Radio',
#   'USB': 'microUSB',
#   'NFC': 'No',
#   'Data': 'GPRS, EDGE, 3G',
#   'Audio': '3.5mm audio jack, Speakerphone',
#   'Browser': 'HTML5',
#   'Messaging': 'SMS, MMS, email',
#   'Games': 'Built-in + downloadable',
#   'Torch': 'Yes',
#   'Extra': 'Maps, Gmail, Facebook, Skype, Youtube, Twitter, Yahoo, * 3D Cambered surface Design, Video player, audio player, Google Android Market',
#   'Capacity': 'N/a',
#   'Brand': 'Calme',
#   'Mobile': 'Calme_Spark-S15',
#   'Price_RS': '4500',
#   'Price_USD': '34',
#   'SIM': 'Dual-SIM',
#   'Resolution': '768 x 480 pixels',
#   'Sensors': 'proximity sensor'},
#  {'OS': 'Android 4.4.2 (kitkat)',
#   'Dimensions': '127.4 x 63.8 x 9.1mm',
#   'Weight': 'N/a',
#   'Colors': 'Black, White',
#   '2G Band': 'SIM1 GSM: 900 / 1800\nSIM2 GSM: 900 / 1800',
#   '3G Band': 'WCDMA',
#   'CPU': '1.2GHZ Dual-Core',
#   'Technology': 'Touch Screen',
#   'Size': 'N/a',
#   'Built-in': '4GB built-in 512MB RAM',
#   'Card': 'microSD Card (supports up 32GB)',
#   'Main': '3.0 MP',
#   'Features': 'Video',
#   'Front': '1.3 MP Camera',
#   'WLAN': 'No',
#   'Bluetooth': 'Yes',
#   'GPS': 'Yes',
#   'Radio': 'FM Radio',
#   'USB': 'Yes',
#   'NFC': 'No',
#   'Data': 'GPRS, EDGE, 3G',
#   'Audio': '3.5mm audio jack, Speakerphone',
#   'Browser': 'HTML5',
#   'Messaging': 'SMS, MMS, email',
#   'Games': 'built-in + downloadable',
#   'Torch': 'No',
#   'Extra': 'Google Search, Maps, Gmail, Youtube, Yahoo, Speakerphone',
#   'Capacity': '1300 mAh',
#   'Brand': 'Calme',
#   'Mobile': 'Calme_Spark-S12',
#   'Price_RS': '4200',
#   'Price_USD': '31',
#   'SIM': 'Dual-SIM',
#   'Resolution': '768 x 480 pixels',
#   'Sensors': 'proximity sensor'},
#  {'OS': 'Android 4.2.2 (Jelly Bean)',
#   'Dimensions': '117 x 61.8 x 12.9mm',
#   'Weight': 'N/a',
#   'Colors': 'Black, White',
#   '2G Band': 'GSM: 900 / 1800',
#   '3G Band': 'WCDMA',
#   'CPU': '1.2GHZ Dual-Core',
#   'Technology': 'WVGA Touch Screen',
#   'Size': '3.5 inches',
#   'Built-in': '512MB built-in 256MB RAM',
#   'Card': 'microSD Card (supports up 32GB)',
#   'Main': '3.0 MP, LED Flash',
#   'Features': 'Video',
#   'Front': '2.0 MP',
#   'WLAN': 'Wi-Fi 802.11',
#   'Bluetooth': 'v3.0',
#   'GPS': 'Yes',
#   'Radio': 'No',
#   'USB': 'Yes',
#   'NFC': 'No',
#   'Data': 'GPRS, EDGE',
#   'Audio': '3.5mm audio jack, Speakerphone',
#   'Browser': 'HTML5',
#   'Messaging': 'SMS, MMS, email',
#   'Games': 'built-in + downloadable',
#   'Torch': 'Yes',
#   'Extra': 'Google Search, Maps, Gmail, Facebook, Skype, Youtube, Twitter, Yahoo, Speakerphone',
#   'Capacity': '1300 mAh',
#   'Brand': 'Calme',
#   'Mobile': 'Calme_Spark-S7',
#   'Price_RS': '4000',
#   'Price_USD': '30',
#   'SIM': 'Dual-SIM',
#   'Resolution': '768 x 480 pixels',
#   'Sensors': 'proximity sensor'},
#  {'OS': 'Android 4.2.2 (Jelly Bean)',
#   'Dimensions': 'N/a',
#   'Weight': 'N/a',
#   'Colors': 'Black',
#   '2G Band': 'GSM: 900 / 1800',
#   '3G Band': 'WCDMA',
#   'CPU': '1.5 GHZ Dual-Core',
#   'Technology': 'HVGA Touch Screen',
#   'Size': '3.5 inches',
#   'Built-in': '4GB built-in 512MB RAM',
#   'Card': 'microSD Card (supports up 32GB)',
#   'Main': '2.0 MP, Flash Light',
#   'Features': 'Video',
#   'Front': '1.3 MP',
#   'WLAN': 'Wi-Fi 802.11',
#   'Bluetooth': 'v3.0',
#   'GPS': 'Yes',
#   'Radio': 'No',
#   'USB': 'Yes',
#   'NFC': 'No',
#   'Data': 'GPRS, EDGE, 3G',
#   'Audio': '3.5mm audio jack, Speakerphone',
#   'Browser': 'HTML5',
#   'Messaging': 'SMS, MMS, email',
#   'Games': 'built-in + downloadable',
#   'Torch': 'Yes',
#   'Extra': 'Google Search, Maps, Gmail, Facebook, Skype, Youtube, Twitter, Yahoo, Speakerphone',
#   'Capacity': '1350 mAh',
#   'Brand': 'Calme',
#   'Mobile': 'Calme_Spark-S11',
#   'Price_RS': '4000',
#   'Price_USD': '30',
#   'SIM': 'Dual-SIM',
#   'Resolution': '768 x 480 pixels',
#   'Sensors': 'proximity sensor'},
#  {'OS': 'Android 4.2.2 (Jelly Bean)',
#   'Dimensions': 'N/a',
#   'Weight': 'N/a',
#   'Colors': 'Black',
#   '2G Band': 'GSM: 900 / 1800',
#   '3G Band': 'WCDMA',
#   'CPU': '1.5 GHZ Dual-Core',
#   'Technology': 'HVGA Touch Screen',
#   'Size': '2.6 inches',
#   'Built-in': '4GB built-in 512MB RAM',
#   'Card': 'microSD Card (supports up 32GB)',
#   'Main': '2.0 MP, Flash Light',
#   'Features': '3.5mm audio jack, Speakerphone',
#   'Front': 'No',
#   'WLAN': 'Wi-Fi 802.11',
#   'Bluetooth': 'Yes',
#   'GPS': 'No',
#   'Radio': 'FM radio',
#   'USB': 'Yes',
#   'NFC': 'No',
#   'Data': 'GPRS, EDGE',
#   'Audio': '3.5mm audio jack, Speakerphone',
#   'Browser': 'Opera Mini',
#   'Messaging': 'SMS, MMS',
#   'Games': 'built-in',
#   'Torch': 'No',
#   'Extra': 'Support Auto timing recording, Whatsapp, Facebook, Torch light, Privacy Protection, Speakerphone',
#   'Capacity': '1350 mAh',
#   'Brand': 'Calme',
#   'Mobile': 'Calme_C540',
#   'Price_RS': 'Discontinued',
#   'Price_USD': '0',
#   'SIM': 'Dual-SIM, Dual Standby',
#   'Resolution': '768 x 480 pixels',
#   'Sensors': 'proximity sensor',
#   'Whats New': "Calme C540 - Keep Calm and Carry on!\r\n\r\nCalme brings us C540, a brand new release for 2014 thats packed in a sleek and sophisticated handset with a huge 2.4 inches high definition screen. Calme C540 also includes an awesome Digital Camera, an FM Radio, and both Audio and Video players so that you can groove to your preferred Dj. Calme's C540 also gives you a chance to capture your special holiday moments on film. so that you can experience them again and again.\r\nCalme C540's bar phone is the ultimate decision for busy pros who always ought to look for a neat and compact mobile phone, the Calme Mobile C540 model is extremely lightweight, yet it has all the features you need to stay connected throughout the day. This modern mobile handset C540 includes a Dual Band GSM, a durable 1600mAh battery that offers plenty of talk-time plus standby time so that you wont have to sit near the socket all the time. C540 ensures a large memory that can store up to 5000 contacts and 3000 SMS messages at any given time. Other exciting features of the brand new C540 Mobile Phone include Facebook and Whatsapp applications, 3.5mm earphones with microphone and a built-in torch. C540 also has privacy protection to protect your contacts list and private messages, and an easy to use camera that will allow you take those all-important \x91selfies\x92 at any time, any day. At just RS 2,200, C540 by Calme offers exceptional value for your hard earned money, and if you are looking for a well-priced handset with a long list of never ending features, it could become the perfect cell phone for you as you have already seen that Calme C540 rocks in every department.",
#   'Build': 'N/a',
#   'Frequency': 'SIM1:GSM 900/1800\nSIM2:GSM 900/1800',
#   'Display': 'QVGA Screen',
#   'Memory': 'No',
#   'Contacts': '5000 entries',
#   'SMS': '3000 SMS Memory',
#   'Camera': 'VGA',
#   'Connectivity': 'No',
#   'Battery': '1600 mAh',
#   'Standby': 'up to 12 days',
#   'Talktime': 'up to 8 hrs',
#   'Price': 'Price in Rs: Discontinued \xa0\xa0\xa0Price in USD: $0',
#   'Ratings': 'Average Rating is 4 stars - based on 20 user reviews.'},
#  {'OS': 'Android 4.2.2 (Jelly Bean)',
#   'Dimensions': 'N/a',
#   'Weight': 'N/a',
#   'Colors': 'Black',
#   '2G Band': 'GSM: 900 / 1800',
#   '3G Band': 'WCDMA',
#   'CPU': '1.5 GHZ Dual-Core',
#   'Technology': 'HVGA Touch Screen',
#   'Size': '2.8 inches',
#   'Built-in': '4GB built-in 512MB RAM',
#   'Card': 'microSD Card (supports up 32GB)',
#   'Main': '2.0 MP, Flash Light',
#   'Features': '3.5mm audio jack, Speakerphone',
#   'Front': 'No',
#   'WLAN': 'Wi-Fi 802.11',
#   'Bluetooth': 'Yes',
#   'GPS': 'No',
#   'Radio': 'FM radio',
#   'USB': 'Yes',
#   'NFC': 'No',
#   'Data': 'GPRS, EDGE',
#   'Audio': '3.5mm audio jack, Speakerphone',
#   'Browser': 'Opera mini',
#   'Messaging': 'SMS, MMS',
#   'Games': 'built-in',
#   'Torch': 'No',
#   'Extra': 'Google, Yahoo, Facebook, Auto Call recording, Speakerphone',
#   'Capacity': '1350 mAh',
#   'Brand': 'Calme',
#   'Mobile': 'Calme_C660',
#   'Price_RS': 'Discontinued',
#   'Price_USD': '0',
#   'SIM': 'Dual-SIM, Dual Standby',
#   'Resolution': '768 x 480 pixels',
#   'Sensors': 'proximity sensor',
#   'Whats New': "Calme C660 - And the Fun Goes On!\r\n\r\nAfter a long pause Calme gives you C660 Mobile Phone, a robust and reliable modern handset with a large 2.8 QVGA TFT screen and an advanced and reliable Dual SIM standby feature. Calme C660 is also equipped with a cool 1.3 Megapixel digital camera for capturing those special moments that you want to keep with you forever. Calme E739's large and ergonomically designed bubbled alphanumeric keypad ensures fast dialling and effortless texting. A fantastic mobile phone for daily use, Calme's C660 is very well priced despite having enormous features along with a powerful 1400 mAh battery that can go on continuously for several hours of talktime. Calme model C660 can live up to 2 weeks of uninterrupted standby time on a single charge. The phone book is also quite large in comparison with other bar phones, this calme can store up to 500 phone contacts inside C660 and about 100 text messages. The phone also supports a range of audio options including FM Radio, MP3, MP4 and 3GP, so you can access your favourite tunes on C660 throughout the day using your own headphones thanks to the most commonly used 3.5mm audio jack provided on top. Supporting GPRS and multimedia messaging on the go, C660 is equipped with all the social apps, including Facebook, Google and Yahoo applications, so that you can connect and share anything you want on your favourite social media outlets. The new C660 lets you do all this without the fear of risking your identity thanks to the privacy protection settings. A great value mobile phone for everyday use, the C660 bu Alme Mobile Phone combines brilliant entertainment features with the latest cell phone technology just to keep you connected with your friends, colleagues and family, without breaking your budget. and that is exactly what Calme C660 stands for.",
#   'Build': 'N/a',
#   'Frequency': 'SIM1:GSM 900/1800\nSIM2:GSM 900/1800',
#   'Display': 'QVGA Screen',
#   'Memory': 'No',
#   'Contacts': '500 entries',
#   'SMS': '100 SMS Memory',
#   'Camera': '1.3 MP',
#   'Connectivity': 'No',
#   'Battery': '1400 mAh',
#   'Standby': 'up to 12 days',
#   'Talktime': 'up to 8 hrs',
#   'Price': 'Price in Rs: Discontinued \xa0\xa0\xa0Price in USD: $0',
#   'Ratings': 'Average Rating is 5 stars - based on 1 user reviews.'},
#  {'OS': 'Android 4.2.2 (Jelly Bean)',
#   'Dimensions': 'N/a',
#   'Weight': 'N/a',
#   'Colors': 'Black',
#   '2G Band': 'GSM: 900 / 1800',
#   '3G Band': 'WCDMA',
#   'CPU': '1.5 GHZ Dual-Core',
#   'Technology': 'HVGA Touch Screen',
#   'Size': '2.4 inches',
#   'Built-in': '4GB built-in 512MB RAM',
#   'Card': 'No',
#   'Main': '2.0 MP, Flash Light',
#   'Features': '3.5mm audio jack, Speakerphone',
#   'Front': 'No',
#   'WLAN': 'Wi-Fi 802.11',
#   'Bluetooth': 'Yes',
#   'GPS': 'No',
#   'Radio': 'Wireless FM radio',
#   'USB': 'Yes',
#   'NFC': 'No',
#   'Data': 'GPRS, EDGE',
#   'Audio': '3.5mm audio jack, Speakerphone',
#   'Browser': 'Opera Mini',
#   'Messaging': 'SMS, MMS',
#   'Games': 'built-in',
#   'Torch': 'No',
#   'Extra': 'Google, Yahoo, Whatsapp, Auto Call recording, Privacy Protection, Big Speaker',
#   'Capacity': '1350 mAh',
#   'Brand': 'Calme',
#   'Mobile': 'Calme_C790',
#   'Price_RS': 'Discontinued',
#   'Price_USD': '0',
#   'SIM': 'Dual-SIM, Dual Standby',
#   'Resolution': '768 x 480 pixels',
#   'Sensors': 'proximity sensor',
#   'Whats New': "Calme C790 - Ab Maza Ayega!\r\n\r\nCalme presents modern C790, an excellent handset for business professionals and college students who are in search of a lightweight companion at an affordable price, the Calme C790 bar mobile phone is a fantastic choice at the beginning of a new year to fulfill your goals in 2015. Neat and compact in a stylish design, Calme's C790 Mobile Handset will fit into anything that is meant to carry or keep your precious things, and it comes with everything you could possibly need to stay connected, such as Calme C790's Dual GSM bands, Wireless Stereo with FM Radio and a Digital Camera for taking pictures and \x91selfies\x92 throughout the day. Loaded with a huge 2050mAh Battery Calme model C790 offers 20 hours of continuous talk time and up to 25 days of enormous standby time. Apart from being equipped with a torch, this new handset from Calme comes with a wide range of useful features. C790 literally makes you feel like a prince if not a king, with features such as auto call forwarding, an audio / video player option, and moreover C790 also supports 3.5mm earphones along with the  microphone support for added convenience and entertainment value so that you can also chat on skype and WeChat without any worries. the C790 mobile phone can support a SD Card of up to 32GB too, so there is plenty of space for storing your favourite music downloads and photos on this stylish C790 so that you can enjoy watching these later on with your friends and family. Bluetooth and GPRS Connectivity come as standard with the C790 by Calme so you can stay on top of your business, in touch with friends and family, and up-to-date with the very latest music trends \x96 all from your very own Calme E739!",
#   'Build': 'N/a',
#   'Frequency': 'SIM1:GSM 900 / 1800\nSIM2:GSM 900 / 1800',
#   'Display': 'QVGA Screen',
#   'Memory': 'N/a',
#   'Contacts': '500 entries',
#   'SMS': '100 SMS Memory',
#   'Camera': 'VGA',
#   'Connectivity': 'No',
#   'Battery': '2050 mAh',
#   'Standby': 'up to 25 days',
#   'Talktime': 'up to 20 hrs',
#   'Price': 'Price in Rs: Discontinued \xa0\xa0\xa0Price in USD: $0',
#   'Ratings': 'Average Rating is 3 stars - based on 4 user reviews.'},
#  {'OS': 'Android 4.2.2 (Jelly Bean)',
#   'Dimensions': 'N/a',
#   'Weight': 'N/a',
#   'Colors': 'Black, REd, Blue',
#   '2G Band': 'GSM: 900 / 1800',
#   '3G Band': 'WCDMA',
#   'CPU': '1.5 GHZ Dual-Core',
#   'Technology': 'HVGA Touch Screen',
#   'Size': '2.4 inches',
#   'Built-in': '4GB built-in 512MB RAM',
#   'Card': 'No',
#   'Main': '2.0 MP, Flash Light',
#   'Features': '3.5mm audio jack, Speakerphone',
#   'Front': 'No',
#   'WLAN': 'Wi-Fi 802.11',
#   'Bluetooth': 'Yes',
#   'GPS': 'No',
#   'Radio': 'Wireless FM Radio with auto recording',
#   'USB': 'microUSB',
#   'NFC': 'No',
#   'Data': 'GPRS',
#   'Audio': '3.5mm audio jack, Speakerphone',
#   'Browser': 'WAp',
#   'Messaging': 'SMS, MMS',
#   'Games': 'Built-in',
#   'Torch': 'No',
#   'Extra': 'MP3 Player, Video Player',
#   'Capacity': '1350 mAh',
#   'Brand': 'Calme',
#   'Mobile': 'Calme_C880',
#   'Price_RS': 'Discontinued',
#   'Price_USD': '0',
#   'SIM': 'Dual-SIM, Dual Standby',
#   'Resolution': '768 x 480 pixels',
#   'Sensors': 'proximity sensor',
#   'Whats New': 'Calme C880 - Decentness classified \r\nPakistani company Calme has introduced C880, a neat, compact and handy bar phone designed for daily rough and tough usage that a normal smartphone can not sustain. hitting the market with all new sizzling features, the Calme C880 is great for individuals who are looking for features in lowest price in a steady design. featuring a 2.4 inch QVGA screen, Calme\x92s C880 comes with a rear facing digital camera, Bluetooth connectivity and dual GPRS Support so that you can snap, view and share pictures in an instant. Features of the Calme C880\x92s mobile includes an Open FM Radio, MP3 and MP4 connectivity, a 3.5mm Stereo Audio Jack, Bluetooth and an integrated video player to keep you entertained on the go. Calme designed C880 to keep you connected 24/7 and that\x92s why a powerful 1600mAh big battery was introduced offering hours of talktime, it supports SD Memory Card up to 32GB. While it may not have all the expensive features but Calme has equipped phones with social apps and new C880 also comes with improved social networking applications so that you can stay connected online via GRPS support.  Coming with classic black and bright blue color variant so that users can choose C880 color that suits them best and company provides one year advance telecom warranty and nationwide customer support. Digital camera is equipped on back of C880 alongside speakers while company logo stays at the bottom. The phone is designed specifically to provide entertainment and social networking in a single package and C880 provides you with these at its best. 3.5MM stereo Jack describes universal audio support and enhanced Bluetooth allows data sharing and PAN networking with multiple users in seconds. C880 by Calme equips a bumped up 1600mAh battery to make phone go on for several days and provide standby of over a week. The phone has embedded games to turn the boring time into fun time and Calme C880 comes with a great OS for enhanced texting as well.',
#   'Build': 'N/a',
#   'Frequency': 'SIM1:GSM 900/1800\nSIM2:GSM 900/1800',
#   'Display': 'HD Screen',
#   'Memory': 'microSD Card (supports up to 32GB)',
#   'Contacts': '500 entries',
#   'SMS': '100 SMS Memory',
#   'Camera': 'VGA',
#   'Connectivity': 'No',
#   'Battery': '1600 mAh',
#   'Standby': 'up to 25 days',
#   'Talktime': 'up to 20 hrs',
#   'Price': 'Price in Rs: Discontinued \xa0\xa0\xa0Price in USD: $0',
#   'Ratings': 'Average Rating is 5 stars - based on 1 user reviews.'},
#  {'OS': 'Android 4.2.2 (Jelly Bean)',
#   'Dimensions': 'N/a',
#   'Weight': 'N/a',
#   'Colors': 'Black',
#   '2G Band': 'GSM: 900 / 1800',
#   '3G Band': 'WCDMA',
#   'CPU': '1.5 GHZ Dual-Core',
#   'Technology': 'HVGA Touch Screen',
#   'Size': '2.4 inches',
#   'Built-in': '4GB built-in 512MB RAM',
#   'Card': 'No',
#   'Main': '2.0 MP, Flash Light',
#   'Features': '3.5mm audio jack, Speakerphone',
#   'Front': 'No',
#   'WLAN': 'Wi-Fi 802.11',
#   'Bluetooth': 'Yes',
#   'GPS': 'No',
#   'Radio': 'Wireless FM radio',
#   'USB': 'Yes',
#   'NFC': 'No',
#   'Data': 'GPRS, EDGE',
#   'Audio': '3.5mm audio jack, Speakerphone',
#   'Browser': 'Opera Mini',
#   'Messaging': 'SMS, MMS',
#   'Games': 'built-in',
#   'Torch': 'No',
#   'Extra': 'Mobile tracker, Whatsapp, Facebook, Torch light, Privacy Protection, Speakerphone',
#   'Capacity': '1350 mAh',
#   'Brand': 'Calme',
#   'Mobile': 'Calme_C882',
#   'Price_RS': 'Discontinued',
#   'Price_USD': '0',
#   'SIM': 'Dual-SIM',
#   'Resolution': '768 x 480 pixels',
#   'Sensors': 'proximity sensor',
#   'Whats New': "Calme C882 - A Long List of Modern Specs!\n\nThe latest Calme Mobile Phone C882 is all set to be one of the company's best-sellers in 2015. And with its long list of specifications based on the latest technology, Calme C882 is a sure shot smartphone for anyone who is looking for a well-priced handset that is bursting with features. Like most of the mobile phones in the Calme lightweight series of mobile collection, the all new C882 phone has a complete entertainment system for your enjoyment, with 3.5mm earphone and mic having an audio/video player for your favourite movies and tunes, Calme's C882 has a big speaker for sound clarity - even in noisy environments, and a front and rear digital camera for those impromptu selfies and family shots. Calme C882's design has simply outclassed others. As you would expect from a mobile phone of this category, the Calme Bar C882 handset has a good sized 2.4 inch screen and a big battery (2050mAh) that can last up to 25-days on a single charge. The new C882 is a Dual-SIM phone that can hold up to 500 contacts in its built-in memory at any one time. When it comes to security features, C882 Mobile Phone doesn\x92t lack these either, it comes with complete privacy protection to safeguard your contacts, SMS messages and emails. C882 also has a mobile tracker to ensure that if your mobile phone does get stolen or lost, you will be able to find it by simply logging on to the net. C882 by Calme gets its finish in classic black while the smartphone also has Bluetooth and WIFI so you can connect to the internet for free. Calme C882 keep you connected to your friends and family throughout the day.",
#   'Build': 'N/a',
#   'Frequency': 'SIM1: GSM 900 / 1800\nSIM2: GSM 900 / 1800',
#   'Display': 'HD Display',
#   'Memory': 'No',
#   'Contacts': '500 entries',
#   'SMS': '100 SMS Memory',
#   'Camera': 'VGA',
#   'Connectivity': 'No',
#   'Battery': '2050 mAh',
#   'Standby': 'Up to 25 days',
#   'Talktime': 'up to 20 hrs',
#   'Price': 'Price in Rs: Discontinued \xa0\xa0\xa0Price in USD: $0',
#   'Ratings': 'Average Rating is 5 stars - based on 1 user reviews.'},
#  {'OS': 'Android 4.2.2 (Jelly Bean)',
#   'Dimensions': 'N/a',
#   'Weight': 'N/a',
#   'Colors': 'Black',
#   '2G Band': 'GSM: 900 / 1800',
#   '3G Band': 'WCDMA',
#   'CPU': '1.5 GHZ Dual-Core',
#   'Technology': 'HVGA Touch Screen',
#   'Size': '2.4 inches',
#   'Built-in': '4GB built-in 512MB RAM',
#   'Card': 'No',
#   'Main': '2.0 MP, Flash Light',
#   'Features': '3.5mm audio jack, Speakerphone',
#   'Front': 'No',
#   'WLAN': 'Wi-Fi 802.11',
#   'Bluetooth': 'Yes',
#   'GPS': 'No',
#   'Radio': 'Wireless FM radio',
#   'USB': 'Yes',
#   'NFC': 'No',
#   'Data': 'GPRS',
#   'Audio': '3.5mm audio jack, Speakerphone',
#   'Browser': 'N/a',
#   'Messaging': 'SMS, MMS',
#   'Games': 'built-in',
#   'Torch': 'Yes',
#   'Extra': 'Support Auto timing recording, Torch light, Speakerphone',
#   'Capacity': '1350 mAh',
#   'Brand': 'Calme',
#   'Mobile': 'Calme_C340',
#   'Price_RS': 'Discontinued',
#   'Price_USD': '0',
#   'SIM': 'Dual-SIM, Dual Standby',
#   'Resolution': '768 x 480 pixels',
#   'Sensors': 'proximity sensor',
#   'Whats New': "Calme C340 - Your Pleasure Partner!\r\nCalme announced new C340, a brand new phone with exciting new features including a 2.4 inch LCD Screen and a stunning Digital Camera.  Calme C340 also has a 3.5mm Earphone socket compatible with any latest earpiece along with a built-in FM Radio. Calme's C340 is the perfect choice of busy professionals who are looking for a quality mobile phone at an affordable price, Calme C340's Handset looks as good as it performs, and as it can hold two SIM cards, you can use this quality Calme Mobile C340 for both business and pleasure. Equipped with a large 1600mAh battery, Phone offers plenty of talk-time and standby time, and as this Calme mobile has both Bluetooth Connectivity and MP4 compatibility, C340 lets you listen to all of your preferred stations and your favourite tunes at any given time of the day. C340 handset measures just 145 x 90 x 53mm, so it is small enough to fit anywhere, no matter you have the same sized pockets or not. and as C340 includes privacy protection, your contact list and SMS/MMS messages will remain secure and confidential.\r\nThis new slim and sleek C340 is a brand new addition to the company's shiningly ever-growing bar phone collection so don't forget to check it out. C340 by Calme is an impressive phone with everything you could possibly need to stay connected to friends, family and business associates. Calme C340 is made the best you could live better.",
#   'Build': 'N/a',
#   'Frequency': 'SIM1:GSM 900/1800\nSIM2:GSM 900/1800',
#   'Display': 'HD Screen',
#   'Memory': 'MicroSd card Support (Up to 32 GB)',
#   'Contacts': '500 entries',
#   'SMS': '100 SMS Memory',
#   'Camera': 'VGA, Flash',
#   'Connectivity': 'No',
#   'Battery': '1600 mAh',
#   'Standby': 'up to 15 days',
#   'Talktime': 'up to 7 hrs',
#   'Price': 'Price in Rs: Discontinued \xa0\xa0\xa0Price in USD: $0',
#   'Ratings': 'Average Rating is 2.2 stars - based on 2 user reviews.'},
#  {'OS': 'Android 4.2 (Jelly Bean)',
#   'Dimensions': 'N/a',
#   'Weight': 'N/a',
#   'Colors': 'Black, White',
#   '2G Band': 'GSM: 900 / 1800',
#   '3G Band': 'WCDMA / 2100',
#   'CPU': '1.2 GHZ Dual-Core',
#   'Technology': 'FWVGA Screen',
#   'Size': '5.0 inches',
#   'Built-in': '4GB built-in 512MB RAM + 4GB Free',
#   'Card': '4GB Free microSD Card (supports up 64GB)',
#   'Main': '3.0 MP, autofocus, Flash Light',
#   'Features': 'Video',
#   'Front': '1.3 MP',
#   'WLAN': 'Wi-Fi 802.11',
#   'Bluetooth': 'v3.0',
#   'GPS': 'Yes',
#   'Radio': 'No',
#   'USB': 'Yes',
#   'NFC': 'No',
#   'Data': 'GPRS, EDGE, 3G',
#   'Audio': '3.5mm audio jack, Speakerphone',
#   'Browser': 'HTML5',
#   'Messaging': 'SMS, MMS, email',
#   'Games': 'built-in + downloadable',
#   'Torch': 'Yes',
#   'Extra': 'Google Search, Maps, Gmail, Facebook, Skype, Youtube, Twitter, Yahoo, * 3D Cambered surface Design, Speakerphone',
#   'Capacity': '1950 mAh',
#   'Brand': 'Calme',
#   'Mobile': 'Calme_Spark-S33',
#   'Price_RS': '8300',
#   'Price_USD': '62',
#   'SIM': 'Dual-SIM, Dual Standby',
#   'Resolution': '768 x 480 pixels',
#   'Sensors': 'proximity sensor',
#   'Whats New': "Calme C340 - Your Pleasure Partner!\r\nCalme announced new C340, a brand new phone with exciting new features including a 2.4 inch LCD Screen and a stunning Digital Camera.  Calme C340 also has a 3.5mm Earphone socket compatible with any latest earpiece along with a built-in FM Radio. Calme's C340 is the perfect choice of busy professionals who are looking for a quality mobile phone at an affordable price, Calme C340's Handset looks as good as it performs, and as it can hold two SIM cards, you can use this quality Calme Mobile C340 for both business and pleasure. Equipped with a large 1600mAh battery, Phone offers plenty of talk-time and standby time, and as this Calme mobile has both Bluetooth Connectivity and MP4 compatibility, C340 lets you listen to all of your preferred stations and your favourite tunes at any given time of the day. C340 handset measures just 145 x 90 x 53mm, so it is small enough to fit anywhere, no matter you have the same sized pockets or not. and as C340 includes privacy protection, your contact list and SMS/MMS messages will remain secure and confidential.\r\nThis new slim and sleek C340 is a brand new addition to the company's shiningly ever-growing bar phone collection so don't forget to check it out. C340 by Calme is an impressive phone with everything you could possibly need to stay connected to friends, family and business associates. Calme C340 is made the best you could live better.",
#   'Build': 'N/a',
#   'Frequency': 'SIM1:GSM 900/1800\nSIM2:GSM 900/1800',
#   'Display': 'HD Screen',
#   'Memory': 'MicroSd card Support (Up to 32 GB)',
#   'Contacts': '500 entries',
#   'SMS': '100 SMS Memory',
#   'Camera': 'VGA, Flash',
#   'Connectivity': 'No',
#   'Battery': '1600 mAh',
#   'Standby': 'up to 15 days',
#   'Talktime': 'up to 7 hrs',
#   'Price': 'Price in Rs: Discontinued \xa0\xa0\xa0Price in USD: $0',
#   'Ratings': 'Average Rating is 2.2 stars - based on 2 user reviews.'}]
